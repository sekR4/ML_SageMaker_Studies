# %% [markdown]
# # Detecting Payment Card Fraud
#
# In this section, we'll look at a credit card fraud detection dataset, and build a binary classification model that can identify transactions as either fraudulent or valid, based on provided, *historical* data. In a [2016 study](https://nilsonreport.com/upload/content_promo/The_Nilson_Report_10-17-2016.pdf), it was estimated that credit card fraud was responsible for over 20 billion dollars in loss, worldwide. Accurately detecting cases of fraud is an ongoing area of research.
#
# <img src=notebook_ims/fraud_detection.png width=50% />
#
# ### Labeled Data
#
# The payment fraud data set (Dal Pozzolo et al. 2015) was downloaded from [Kaggle](https://www.kaggle.com/mlg-ulb/creditcardfraud/data). This has features and labels for thousands of credit card transactions, each of which is labeled as fraudulent or valid. In this notebook, we'd like to train a model based on the features of these transactions so that we can predict risky or fraudulent transactions in the future.
#
# ### Binary Classification
#
# Since we have true labels to aim for, we'll take a **supervised learning** approach and train a binary classifier to sort data into one of our two transaction classes: fraudulent or valid.  We'll train a model on training data and see how well it generalizes on some test data.
#
# The notebook will be broken down into a few steps:
# * Loading and exploring the data
# * Splitting the data into train/test sets
# * Defining and training a LinearLearner, binary classifier
# * Making improvements on the model
# * Evaluating and comparing model test performance
#
# ### Making Improvements
#
# A lot of this notebook will focus on making improvements, as discussed in [this SageMaker blog post](https://aws.amazon.com/blogs/machine-learning/train-faster-more-flexible-models-with-amazon-sagemaker-linear-learner/). Specifically, we'll address techniques for:
#
# 1. **Tuning a model's hyperparameters** and aiming for a specific metric, such as high recall or precision.
# 2. **Managing class imbalance**, which is when we have many more training examples in one class than another (in this case, many more valid transactions than fraudulent).
#
# ---

# %% [markdown]
# First, import the usual resources.

# %%
import io
import os
import matplotlib.pyplot as plt
import numpy as np 
import pandas as pd
from sklearn.model_selection import train_test_split

import boto3
import sagemaker
from sagemaker import get_execution_role

# %matplotlib inline

# %% [markdown]
# I'm storing my **SageMaker variables** in the next cell:
# * sagemaker_session: The SageMaker session we'll use for training models.
# * bucket: The name of the default S3 bucket that we'll use for data storage.
# * role: The IAM role that defines our data and model permissions.

# %%
kernel_name = None

# %%
# %%javascript
#
# // If you're running this on SageMaker,
# // make sure using the correct kernel for mxnet
#
# var kernel = Jupyter.notebook.kernel
# kernel.execute('kernel_name = ' + '"' + kernel.name + '"')

# %%
kernel_name
# Out:
# 'conda_mxnet_p36'

# %%
# sagemaker session, role
sagemaker_session = sagemaker.Session()

if kernel_name:
    role = sagemaker.get_execution_role()

# S3 bucket name
bucket = sagemaker_session.default_bucket()

# %% [markdown]
# ## Loading and Exploring the Data
#
# Next, I am loading the data and unzipping the data in the file `creditcardfraud.zip`. This directory will hold one csv file of all the transaction data, `creditcard.csv`.
#
# As in previous notebooks, it's important to look at the distribution of data since this will inform how we develop a fraud detection model. We'll want to know: How many data points we have to work with, the number and type of features, and finally, the distribution of data over the classes (valid or fraudulent).

# %% [raw]
# # only have to run once
# url = "https://s3.amazonaws.com/video.udacity-data.com/topher/2019/January/5c534768_creditcardfraud/creditcardfraud.zip"
# !wget $url &> /dev/null
# !unzip creditcardfraud &> /dev/null

# %%
# read in the csv file
local_data = 'creditcard.csv'

# print out some data
transaction_df = pd.read_csv(local_data)
print('Data shape (rows, cols): ', transaction_df.shape)
print()
transaction_df.head()
# Out:
# Data shape (rows, cols):  (284807, 31)
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62      0
# 1  0.125895 -0.008983  0.014724    2.69      0
# 2 -0.139097 -0.055353 -0.059752  378.66      0
# 3 -0.221929  0.062723  0.061458  123.50      0
# 4  0.502292  0.219422  0.215153   69.99      0
#
# [5 rows x 31 columns]

# %% [markdown]
# ### EXERCISE: Calculate the percentage of fraudulent data
#
# Take a look at the distribution of this transaction data over the classes, valid and fraudulent.
#
# Complete the function `fraudulent_percentage`, below. Count up the number of data points in each class and calculate the *percentage* of the data points that are fraudulent.

# %%
# Calculate the fraction of data points that are fraudulent
def fraudulent_percentage(transaction_df):
    '''Calculate the fraction of all data points that have a 'Class' label of 1; fraudulent.
       :param transaction_df: Dataframe of all transaction data points; has a column 'Class'
       :return: A fractional percentage of fraudulent data points/all points
    '''
    return transaction_df["Class"].mean()

# %% [markdown]
# Test out your code by calling your function and printing the result.

# %%
# call the function to calculate the fraud percentage
fraud_percentage = fraudulent_percentage(transaction_df)

print('Fraudulent percentage = ', fraud_percentage*100, "%")
print('Total # of fraudulent pts: ', fraud_percentage*transaction_df.shape[0])
print('Out of (total) pts: ', transaction_df.shape[0])
# Out:
# Fraudulent percentage =  0.1727485630620034 %
# Total # of fraudulent pts:  492.0
# Out of (total) pts:  284807

# %% [markdown]
# ### EXERCISE: Split into train/test datasets
#
# In this example, we'll want to evaluate the performance of a fraud classifier; training it on some training data and testing it on *test data* that it did not see during the training process. So, we'll need to split the data into separate training and test sets.
#
# Complete the `train_test_split` function, below. This function should:
# * Shuffle the transaction data, randomly
# * Split it into two sets according to the parameter `train_frac`
# * Get train/test features and labels
# * Return the tuples: (train_features, train_labels), (test_features, test_labels)

# %%
# split into train/test
def split_data(transaction_df, test_size= 0.3, random_state=1):
    '''Shuffle the data and randomly split into train and test sets;
       separate the class labels (the column in transaction_df) from the features.
       :param df: Dataframe of all credit card transaction data
       :param train_frac: The decimal fraction of data that should be training data
       :param seed: Random seed for shuffling and reproducibility, default = 1
       :return: train_features, train_labels test_features, test_labels
       '''
    
    # shuffle and split the data
    
    train_features,test_features, train_labels, test_labels = train_test_split(
        transaction_df.iloc[:,:-1], 
        transaction_df.iloc[:,-1], 
        test_size=test_size, 
        random_state=random_state,
        shuffle=True
    )
    
    return train_features, test_features, train_labels, test_labels

# %% [markdown]
# ### Test Cell
#
# In the cells below, I'm creating the train/test data and checking to see that result makes sense. The tests below test that the above function splits the data into the expected number of points and that the labels are indeed, class labels (0, 1).

# %%
# get train/test data
train_features, test_features, train_labels, test_labels = split_data(transaction_df, test_size=0.3, random_state=1)

# %%
# manual test

# for a split of 0.7:0.3 there should be ~2.33x as many training as test pts
print('Training data pts: ', len(train_features))
print('Test data pts: ', len(test_features))
print()

# take a look at first item and see that it aligns with first row of data
print('First item: \n', train_features.iloc[:,0])
print('Label: ', train_labels[0])
print()

# test split
assert len(train_features) > 2.333*len(test_features), \
        'Unexpected number of train/test points for a train_frac=0.7'
# test labels
assert np.all(train_labels)== 0 or np.all(train_labels)== 1, \
        'Train labels should be 0s or 1s.'
assert np.all(test_labels)== 0 or np.all(test_labels)== 1, \
        'Test labels should be 0s or 1s.'
print('Tests passed!')
# Out:
# Training data pts:  199364
# Test data pts:  85443
#
# First item:
#  191125    129124.0
# 153710     99901.0
# 261216    159917.0
# 190724    128961.0
# 127492     78349.0
#             ...
# 21440      31666.0
# 117583     74729.0
# 73349      55095.0
# 267336    162728.0
# 128037     78576.0
# Name: Time, Length: 199364, dtype: float64
# Label:  0
#
# Tests passed!

# %% [markdown]
# ---
# # Modeling
#
# Now that you've uploaded your training data, it's time to define and train a model!
#
# In this notebook, you'll define and train the SageMaker, built-in algorithm, [LinearLearner](https://sagemaker.readthedocs.io/en/stable/linear_learner.html).
#
# A LinearLearner has two main applications:
# 1. For regression tasks in which a linear line is fit to some data points, and you want to produce a predicted output value given some data point (example: predicting house prices given square area).
# 2. For binary classification, in which a line is separating two classes of data and effectively outputs labels; either 1 for data that falls above the line or 0 for points that fall on or below the line.
#
# <img src='notebook_ims/linear_separator.png' width=50% />
#
# In this case, we'll be using it for case 2, and we'll train it to separate data into our two classes: valid or fraudulent.

# %% [markdown]
# ### EXERCISE: Create a LinearLearner Estimator
#
# You've had some practice instantiating built-in models in SageMaker. All estimators require some constructor arguments to be passed in. See if you can complete this task, instantiating a LinearLearner estimator, using only the [LinearLearner documentation](https://sagemaker.readthedocs.io/en/stable/linear_learner.html) as a resource. This takes in a lot of arguments, but not all are required. My suggestion is to start with a simple model, utilizing default values where applicable. Later, we will discuss some specific hyperparameters and their use cases.
#
# #### Instance Types
#
# It is suggested that you use instances that are available in the free tier of usage: `'ml.c4.xlarge'` for training and `'ml.t2.medium'` for deployment.

# %%
prefix = 'fraud'
output_path='s3://{}/{}/'.format(bucket, prefix)
print(f'Training artifacts will be uploaded to: \n{output_path}')
# Out:
# Training artifacts will be uploaded to:
# s3://sagemaker-eu-central-1-092764612399/fraud/

# %%
# import LinearLearner
from sagemaker import LinearLearner

# instantiate LinearLearner
LinLearner = LinearLearner(role=role,
                           instance_count=1,
                           instance_type="ml.p3.8xlarge",
                           predictor_type="binary_classifier",
                           epochs=10,
                           output_path=output_path,
                           sagemaker_session=sagemaker_session)
# Out:
# Training artifacts will be uploaded to:
# s3://sagemaker-eu-central-1-092764612399/fraud/

# %% [markdown]
# ### EXERCISE: Convert data into a RecordSet format
#
# Next, prepare the data for a built-in model by converting the train features and labels into numpy array's of float values. Then you can use the [record_set function](https://sagemaker.readthedocs.io/en/stable/linear_learner.html#sagemaker.LinearLearner.record_set) to format the data as a RecordSet and prepare it for training!

# %%
# create RecordSet of training data
formatted_train_data = LinLearner.record_set(
    train=train_features.astype('float32').to_numpy(),
    labels=train_labels.astype('float32').to_numpy()
)

# %% [markdown]
# ### EXERCISE: Train the Estimator
#
# After instantiating your estimator, train it with a call to `.fit()`, passing in the formatted training data.

# %%
# %%time 
# train the estimator on formatted training data
LinLearner.fit(formatted_train_data)
# Out:
# Defaulting to the only supported framework/algorithm version: 1. Ignoring framework/algorithm version: 1.
# 2021-09-20 10:26:07 Starting - Starting the training job...
# 2021-09-20 10:26:30 Starting - Launching requested ML instancesProfilerReport-1632133567: InProgress
# .........
# 2021-09-20 10:27:51 Starting - Preparing the instances for training......
# 2021-09-20 10:28:51 Downloading - Downloading input data...
# 2021-09-20 10:29:31 Training - Training image download completed. Training in progress.Docker entrypoint called with argument(s): train
# Running default environment configuration script
# [09/20/2021 10:29:31 INFO 140321942804288] Reading default configuration from /opt/amazon/lib/python3.7/site-packages/algorithm/resources/default-input.json: {'mini_batch_size': '1000', 'epochs': '15', 'feature_dim': 'auto', 'use_bias': 'true', 'binary_classifier_model_selection_criteria': 'accuracy', 'f_beta': '1.0', 'target_recall': '0.8', 'target_precision': '0.8', 'num_models': 'auto', 'num_calibration_samples': '10000000', 'init_method': 'uniform', 'init_scale': '0.07', 'init_sigma': '0.01', 'init_bias': '0.0', 'optimizer': 'auto', 'loss': 'auto', 'margin': '1.0', 'quantile': '0.5', 'loss_insensitivity': '0.01', 'huber_delta': '1.0', 'num_classes': '1', 'accuracy_top_k': '3', 'wd': 'auto', 'l1': 'auto', 'momentum': 'auto', 'learning_rate': 'auto', 'beta_1': 'auto', 'beta_2': 'auto', 'bias_lr_mult': 'auto', 'bias_wd_mult': 'auto', 'use_lr_scheduler': 'true', 'lr_scheduler_step': 'auto', 'lr_scheduler_factor': 'auto', 'lr_scheduler_minimum_lr': 'auto', 'positive_example_weight_mult': '1.0', 'balance_multiclass_weights': 'false', 'normalize_data': 'true', 'normalize_label': 'auto', 'unbias_data': 'auto', 'unbias_label': 'auto', 'num_point_for_scaler': '10000', '_kvstore': 'auto', '_num_gpus': 'auto', '_num_kv_servers': 'auto', '_log_level': 'info', '_tuning_objective_metric': '', 'early_stopping_patience': '3', 'early_stopping_tolerance': '0.001', '_enable_profiler': 'false'}
# [09/20/2021 10:29:31 INFO 140321942804288] Merging with provided configuration from /opt/ml/input/config/hyperparameters.json: {'feature_dim': '30', 'predictor_type': 'binary_classifier', 'epochs': '10', 'mini_batch_size': '1000'}
# [09/20/2021 10:29:31 INFO 140321942804288] Final configuration: {'mini_batch_size': '1000', 'epochs': '10', 'feature_dim': '30', 'use_bias': 'true', 'binary_classifier_model_selection_criteria': 'accuracy', 'f_beta': '1.0', 'target_recall': '0.8', 'target_precision': '0.8', 'num_models': 'auto', 'num_calibration_samples': '10000000', 'init_method': 'uniform', 'init_scale': '0.07', 'init_sigma': '0.01', 'init_bias': '0.0', 'optimizer': 'auto', 'loss': 'auto', 'margin': '1.0', 'quantile': '0.5', 'loss_insensitivity': '0.01', 'huber_delta': '1.0', 'num_classes': '1', 'accuracy_top_k': '3', 'wd': 'auto', 'l1': 'auto', 'momentum': 'auto', 'learning_rate': 'auto', 'beta_1': 'auto', 'beta_2': 'auto', 'bias_lr_mult': 'auto', 'bias_wd_mult': 'auto', 'use_lr_scheduler': 'true', 'lr_scheduler_step': 'auto', 'lr_scheduler_factor': 'auto', 'lr_scheduler_minimum_lr': 'auto', 'positive_example_weight_mult': '1.0', 'balance_multiclass_weights': 'false', 'normalize_data': 'true', 'normalize_label': 'auto', 'unbias_data': 'auto', 'unbias_label': 'auto', 'num_point_for_scaler': '10000', '_kvstore': 'auto', '_num_gpus': 'auto', '_num_kv_servers': 'auto', '_log_level': 'info', '_tuning_objective_metric': '', 'early_stopping_patience': '3', 'early_stopping_tolerance': '0.001', '_enable_profiler': 'false', 'predictor_type': 'binary_classifier'}
# [09/20/2021 10:29:31 WARNING 140321942804288] Loggers have already been setup.
# Process 1 is a worker.
# [09/20/2021 10:29:31 INFO 140321942804288] Using default worker.
# [09/20/2021 10:29:31 INFO 140321942804288] Checkpoint loading and saving are disabled.
# [2021-09-20 10:29:31.261] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 0, "duration": 19, "num_examples": 1, "num_bytes": 168000}
# [09/20/2021 10:29:31 INFO 140321942804288] Create Store: local
# [2021-09-20 10:29:31.378] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 1, "duration": 116, "num_examples": 11, "num_bytes": 1848000}
# [09/20/2021 10:29:31 INFO 140321942804288] Scaler algorithm parameters
#  <algorithm.scaler.ScalerAlgorithmStable object at 0x7f9eb2076590>
# [09/20/2021 10:29:31 INFO 140321942804288] Scaling model computed with parameters:
#  {'stdev_label': None, 'stdev_weight':
# [4.7823008e+04 1.8987731e+00 1.5821997e+00 1.5291911e+00 1.4364978e+00
#  1.3388461e+00 1.2955806e+00 1.1771069e+00 1.2127448e+00 1.0843055e+00
#  1.0475702e+00 1.0230465e+00 1.0090139e+00 1.0057642e+00 9.5122164e-01
#  9.2613727e-01 8.7072927e-01 8.6057234e-01 8.3151484e-01 8.2762748e-01
#  7.1313608e-01 7.3347980e-01 7.2524083e-01 5.6213826e-01 6.0201687e-01
#  5.1174247e-01 4.8000538e-01 3.7595215e-01 2.7081874e-01 2.3656270e+02]
# <NDArray 30 @cpu(0)>, 'mean_label': None, 'mean_weight':
# [ 9.4275984e+04 -1.7378727e-02  1.5538026e-02  2.5005125e-02
#   3.3166975e-02  1.8197566e-02  1.7799012e-03  6.9396999e-03
#   9.8540336e-03 -3.0757964e-02 -1.2736557e-02  4.0434714e-04
#  -1.4243029e-02  1.6704608e-02  2.2619881e-02 -9.6982103e-03
#  -4.7834702e-03 -1.6767335e-04 -9.0120723e-03 -3.0407687e-03
#   4.6031545e-03 -4.0078526e-03 -1.2586080e-04  1.2784966e-03
#   3.7617318e-03 -3.1254767e-03 -8.2200055e-04  3.4045519e-03
#  -1.0332187e-03  8.7559837e+01]
# <NDArray 30 @cpu(0)>}
# [09/20/2021 10:29:31 INFO 140321942804288] nvidia-smi: took 0.056 seconds to run.
# [09/20/2021 10:29:31 INFO 140321942804288] nvidia-smi identified 4 GPUs.
# [09/20/2021 10:29:31 INFO 140321942804288] Number of GPUs being used: 4
# #metrics {"StartTime": 1632133787.8769295, "EndTime": 1632133787.8769906, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "Meta": "init_train_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 12000.0, "count": 1, "min": 12000, "max": 12000}, "Total Batches Seen": {"sum": 12.0, "count": 1, "min": 12, "max": 12}, "Max Records Seen Between Resets": {"sum": 11000.0, "count": 1, "min": 11000, "max": 11000}, "Max Batches Seen Between Resets": {"sum": 11.0, "count": 1, "min": 11, "max": 11}, "Reset Count": {"sum": 2.0, "count": 1, "min": 2, "max": 2}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
#
# [2021-09-20 10:30:17.475] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 3, "duration": 29596, "num_examples": 200, "num_bytes": 33493152}
# #metrics {"StartTime": 1632133817.4755397, "EndTime": 1632133817.4756024, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 0}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.1202384072979491, "count": 1, "min": 0.1202384072979491, "max": 0.1202384072979491}}}
#
# #metrics {"StartTime": 1632133817.4756837, "EndTime": 1632133817.4756978, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 1}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.11756252731150718, "count": 1, "min": 0.11756252731150718, "max": 0.11756252731150718}}}
#
# #metrics {"StartTime": 1632133817.4757545, "EndTime": 1632133817.4757662, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 2}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.12012009826497216, "count": 1, "min": 0.12012009826497216, "max": 0.12012009826497216}}}
#
# #metrics {"StartTime": 1632133817.4758074, "EndTime": 1632133817.4758172, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 3}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.11766779355427727, "count": 1, "min": 0.11766779355427727, "max": 0.11766779355427727}}}
#
# #metrics {"StartTime": 1632133817.4758463, "EndTime": 1632133817.4758546, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 4}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.012220082487059223, "count": 1, "min": 0.012220082487059223, "max": 0.012220082487059223}}}
#
# #metrics {"StartTime": 1632133817.4758887, "EndTime": 1632133817.4758978, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 5}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.01217558026043277, "count": 1, "min": 0.01217558026043277, "max": 0.01217558026043277}}}
#
# #metrics {"StartTime": 1632133817.4759247, "EndTime": 1632133817.4759328, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 6}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.012201708267335241, "count": 1, "min": 0.012201708267335241, "max": 0.012201708267335241}}}
#
# #metrics {"StartTime": 1632133817.475958, "EndTime": 1632133817.4759655, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 7}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.012345535695206505, "count": 1, "min": 0.012345535695206505, "max": 0.012345535695206505}}}
#
# #metrics {"StartTime": 1632133817.4759984, "EndTime": 1632133817.4760075, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 8}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.12014251559942811, "count": 1, "min": 0.12014251559942811, "max": 0.12014251559942811}}}
#
# #metrics {"StartTime": 1632133817.4760404, "EndTime": 1632133817.4760492, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 9}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.11776210112068522, "count": 1, "min": 0.11776210112068522, "max": 0.11776210112068522}}}
#
# #metrics {"StartTime": 1632133817.4760785, "EndTime": 1632133817.4760864, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 10}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.12038166165711292, "count": 1, "min": 0.12038166165711292, "max": 0.12038166165711292}}}
#
# #metrics {"StartTime": 1632133817.4761186, "EndTime": 1632133817.4761271, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 11}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.1177079151766983, "count": 1, "min": 0.1177079151766983, "max": 0.1177079151766983}}}
#
# #metrics {"StartTime": 1632133817.47616, "EndTime": 1632133817.4761686, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 12}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.012612578637958808, "count": 1, "min": 0.012612578637958808, "max": 0.012612578637958808}}}
#
# #metrics {"StartTime": 1632133817.4762018, "EndTime": 1632133817.4762104, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 13}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.012488340914647221, "count": 1, "min": 0.012488340914647221, "max": 0.012488340914647221}}}
#
# #metrics {"StartTime": 1632133817.4762433, "EndTime": 1632133817.4762518, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 14}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.012396600629586783, "count": 1, "min": 0.012396600629586783, "max": 0.012396600629586783}}}
#
# #metrics {"StartTime": 1632133817.476282, "EndTime": 1632133817.4762893, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 15}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.012499406318816745, "count": 1, "min": 0.012499406318816745, "max": 0.012499406318816745}}}
#
# #metrics {"StartTime": 1632133817.4763212, "EndTime": 1632133817.47633, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 16}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.12282504722940263, "count": 1, "min": 0.12282504722940263, "max": 0.12282504722940263}}}
#
# #metrics {"StartTime": 1632133817.4763632, "EndTime": 1632133817.476372, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 17}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.12008383033503241, "count": 1, "min": 0.12008383033503241, "max": 0.12008383033503241}}}
#
# #metrics {"StartTime": 1632133817.4764009, "EndTime": 1632133817.4764085, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 18}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.12283358869121302, "count": 1, "min": 0.12283358869121302, "max": 0.12283358869121302}}}
#
# #metrics {"StartTime": 1632133817.4764407, "EndTime": 1632133817.4764493, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 19}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.12025849870700932, "count": 1, "min": 0.12025849870700932, "max": 0.12025849870700932}}}
#
# #metrics {"StartTime": 1632133817.4764802, "EndTime": 1632133817.476488, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 20}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.0199439034713479, "count": 1, "min": 0.0199439034713479, "max": 0.0199439034713479}}}
#
# #metrics {"StartTime": 1632133817.476521, "EndTime": 1632133817.4765294, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 21}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.01993385882793584, "count": 1, "min": 0.01993385882793584, "max": 0.01993385882793584}}}
#
# #metrics {"StartTime": 1632133817.4765573, "EndTime": 1632133817.476565, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 22}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.01998765197312038, "count": 1, "min": 0.01998765197312038, "max": 0.01998765197312038}}}
#
# #metrics {"StartTime": 1632133817.476597, "EndTime": 1632133817.4766057, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 23}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.019844267460756265, "count": 1, "min": 0.019844267460756265, "max": 0.019844267460756265}}}
#
# #metrics {"StartTime": 1632133817.4766386, "EndTime": 1632133817.476647, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 24}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.12367209566058825, "count": 1, "min": 0.12367209566058825, "max": 0.12367209566058825}}}
#
# #metrics {"StartTime": 1632133817.47668, "EndTime": 1632133817.4766884, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 25}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.12108522278819252, "count": 1, "min": 0.12108522278819252, "max": 0.12108522278819252}}}
#
# #metrics {"StartTime": 1632133817.4767175, "EndTime": 1632133817.4767253, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 26}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.12374423367773468, "count": 1, "min": 0.12374423367773468, "max": 0.12374423367773468}}}
#
# #metrics {"StartTime": 1632133817.47675, "EndTime": 1632133817.4767573, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 27}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.12116944743880076, "count": 1, "min": 0.12116944743880076, "max": 0.12116944743880076}}}
#
# #metrics {"StartTime": 1632133817.476782, "EndTime": 1632133817.4767897, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 28}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.021039976484053324, "count": 1, "min": 0.021039976484053324, "max": 0.021039976484053324}}}
#
# #metrics {"StartTime": 1632133817.4768224, "EndTime": 1632133817.4768307, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 29}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.020920196507790655, "count": 1, "min": 0.020920196507790655, "max": 0.020920196507790655}}}
#
# #metrics {"StartTime": 1632133817.4768643, "EndTime": 1632133817.4768724, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 30}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.021012824368986053, "count": 1, "min": 0.021012824368986053, "max": 0.021012824368986053}}}
#
# #metrics {"StartTime": 1632133817.476899, "EndTime": 1632133817.4769065, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 31}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.02103140465546418, "count": 1, "min": 0.02103140465546418, "max": 0.02103140465546418}}}
#
# [09/20/2021 10:30:17 INFO 140321942804288] #quality_metric: host=algo-1, epoch=0, train binary_classification_cross_entropy_objective <loss>=0.1202384072979491
# [09/20/2021 10:30:17 INFO 140321942804288] #early_stopping_criteria_metric: host=algo-1, epoch=0, criteria=binary_classification_cross_entropy_objective, value=0.01217558026043277
# [09/20/2021 10:30:17 INFO 140321942804288] Epoch 0: Loss improved. Updating best model
# [09/20/2021 10:30:17 INFO 140321942804288] Saving model for epoch: 0
# [09/20/2021 10:30:17 INFO 140321942804288] Saved checkpoint to "/tmp/tmpq0dbm05_/mx-mod-0000.params"
# [09/20/2021 10:30:17 INFO 140321942804288] #progress_metric: host=algo-1, completed 10.0 % of epochs
# #metrics {"StartTime": 1632133787.8773026, "EndTime": 1632133817.5039828, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 211364.0, "count": 1, "min": 211364, "max": 211364}, "Total Batches Seen": {"sum": 212.0, "count": 1, "min": 212, "max": 212}, "Max Records Seen Between Resets": {"sum": 199364.0, "count": 1, "min": 199364, "max": 199364}, "Max Batches Seen Between Resets": {"sum": 200.0, "count": 1, "min": 200, "max": 200}, "Reset Count": {"sum": 3.0, "count": 1, "min": 3, "max": 3}, "Number of Records Since Last Reset": {"sum": 199364.0, "count": 1, "min": 199364, "max": 199364}, "Number of Batches Since Last Reset": {"sum": 200.0, "count": 1, "min": 200, "max": 200}}}
#
# [09/20/2021 10:30:17 INFO 140321942804288] #throughput_metric: host=algo-1, train throughput=6729.179843021818 records/second
# [2021-09-20 10:30:47.125] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 5, "duration": 29621, "num_examples": 200, "num_bytes": 33493152}
# #metrics {"StartTime": 1632133847.125696, "EndTime": 1632133847.1257563, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 0}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.016883339488925647, "count": 1, "min": 0.016883339488925647, "max": 0.016883339488925647}}}
#
# #metrics {"StartTime": 1632133847.1258307, "EndTime": 1632133847.1258445, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 1}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.014893327731582987, "count": 1, "min": 0.014893327731582987, "max": 0.014893327731582987}}}
#
# #metrics {"StartTime": 1632133847.125879, "EndTime": 1632133847.125888, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 2}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.016874810682469276, "count": 1, "min": 0.016874810682469276, "max": 0.016874810682469276}}}
#
# #metrics {"StartTime": 1632133847.1259236, "EndTime": 1632133847.1259332, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 3}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.014889016261052846, "count": 1, "min": 0.014889016261052846, "max": 0.014889016261052846}}}
#
# #metrics {"StartTime": 1632133847.1259634, "EndTime": 1632133847.1259706, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 4}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.005409128546864543, "count": 1, "min": 0.005409128546864543, "max": 0.005409128546864543}}}
#
# #metrics {"StartTime": 1632133847.1259968, "EndTime": 1632133847.126005, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 5}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.00559416226288257, "count": 1, "min": 0.00559416226288257, "max": 0.00559416226288257}}}
#
# #metrics {"StartTime": 1632133847.1260366, "EndTime": 1632133847.1260455, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 6}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.0055170558129236024, "count": 1, "min": 0.0055170558129236024, "max": 0.0055170558129236024}}}
#
# #metrics {"StartTime": 1632133847.1260746, "EndTime": 1632133847.126083, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 7}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.0055664076106295216, "count": 1, "min": 0.0055664076106295216, "max": 0.0055664076106295216}}}
#
# #metrics {"StartTime": 1632133847.1261153, "EndTime": 1632133847.1261244, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 8}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.017040394183978364, "count": 1, "min": 0.017040394183978364, "max": 0.017040394183978364}}}
#
# #metrics {"StartTime": 1632133847.1261575, "EndTime": 1632133847.1261678, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 9}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.015086053429536485, "count": 1, "min": 0.015086053429536485, "max": 0.015086053429536485}}}
#
# #metrics {"StartTime": 1632133847.1262248, "EndTime": 1632133847.1262352, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 10}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.017052275439602645, "count": 1, "min": 0.017052275439602645, "max": 0.017052275439602645}}}
#
# #metrics {"StartTime": 1632133847.1262844, "EndTime": 1632133847.1262999, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 11}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.015078011933882631, "count": 1, "min": 0.015078011933882631, "max": 0.015078011933882631}}}
#
# #metrics {"StartTime": 1632133847.1263602, "EndTime": 1632133847.1263769, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 12}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.005623061836963922, "count": 1, "min": 0.005623061836963922, "max": 0.005623061836963922}}}
#
# #metrics {"StartTime": 1632133847.126441, "EndTime": 1632133847.126458, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 13}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.005685889038383661, "count": 1, "min": 0.005685889038383661, "max": 0.005685889038383661}}}
#
# #metrics {"StartTime": 1632133847.1265187, "EndTime": 1632133847.1265345, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 14}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.005619973801525693, "count": 1, "min": 0.005619973801525693, "max": 0.005619973801525693}}}
#
# #metrics {"StartTime": 1632133847.1265972, "EndTime": 1632133847.1266148, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 15}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.005672148282429082, "count": 1, "min": 0.005672148282429082, "max": 0.005672148282429082}}}
#
# #metrics {"StartTime": 1632133847.1266727, "EndTime": 1632133847.126682, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 16}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.021269874167801746, "count": 1, "min": 0.021269874167801746, "max": 0.021269874167801746}}}
#
# #metrics {"StartTime": 1632133847.1267316, "EndTime": 1632133847.126747, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 17}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.019476390371370556, "count": 1, "min": 0.019476390371370556, "max": 0.019476390371370556}}}
#
# #metrics {"StartTime": 1632133847.1268096, "EndTime": 1632133847.1268265, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 18}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.021271081124118824, "count": 1, "min": 0.021271081124118824, "max": 0.021271081124118824}}}
#
# #metrics {"StartTime": 1632133847.126891, "EndTime": 1632133847.1269069, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 19}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.019488520303563257, "count": 1, "min": 0.019488520303563257, "max": 0.019488520303563257}}}
#
# #metrics {"StartTime": 1632133847.126972, "EndTime": 1632133847.126988, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 20}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.012074755961421746, "count": 1, "min": 0.012074755961421746, "max": 0.012074755961421746}}}
#
# #metrics {"StartTime": 1632133847.1270428, "EndTime": 1632133847.127058, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 21}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.012111119677822793, "count": 1, "min": 0.012111119677822793, "max": 0.012111119677822793}}}
#
# #metrics {"StartTime": 1632133847.1271102, "EndTime": 1632133847.127126, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 22}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.012079157429274602, "count": 1, "min": 0.012079157429274602, "max": 0.012079157429274602}}}
#
# #metrics {"StartTime": 1632133847.12719, "EndTime": 1632133847.1272068, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 23}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.012108201941503352, "count": 1, "min": 0.012108201941503352, "max": 0.012108201941503352}}}
#
# #metrics {"StartTime": 1632133847.1272686, "EndTime": 1632133847.1272848, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 24}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.02229813467677514, "count": 1, "min": 0.02229813467677514, "max": 0.02229813467677514}}}
#
# #metrics {"StartTime": 1632133847.1273398, "EndTime": 1632133847.1273546, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 25}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.020528923723565875, "count": 1, "min": 0.020528923723565875, "max": 0.020528923723565875}}}
#
# #metrics {"StartTime": 1632133847.1274157, "EndTime": 1632133847.1274307, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 26}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.02230176045307562, "count": 1, "min": 0.02230176045307562, "max": 0.02230176045307562}}}
#
# #metrics {"StartTime": 1632133847.1274955, "EndTime": 1632133847.1275127, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 27}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.020534939849796006, "count": 1, "min": 0.020534939849796006, "max": 0.020534939849796006}}}
#
# #metrics {"StartTime": 1632133847.1275725, "EndTime": 1632133847.127588, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 28}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.013144132435321807, "count": 1, "min": 0.013144132435321807, "max": 0.013144132435321807}}}
#
# #metrics {"StartTime": 1632133847.1276388, "EndTime": 1632133847.1276536, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 29}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.013147845989196145, "count": 1, "min": 0.013147845989196145, "max": 0.013147845989196145}}}
#
# #metrics {"StartTime": 1632133847.1277049, "EndTime": 1632133847.12772, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 30}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.013144269544575083, "count": 1, "min": 0.013144269544575083, "max": 0.013144269544575083}}}
#
# #metrics {"StartTime": 1632133847.1278217, "EndTime": 1632133847.1278408, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 31}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.013148174451823211, "count": 1, "min": 0.013148174451823211, "max": 0.013148174451823211}}}
#
# [09/20/2021 10:30:47 INFO 140321942804288] #quality_metric: host=algo-1, epoch=1, train binary_classification_cross_entropy_objective <loss>=0.016883339488925647
# [09/20/2021 10:30:47 INFO 140321942804288] #early_stopping_criteria_metric: host=algo-1, epoch=1, criteria=binary_classification_cross_entropy_objective, value=0.005409128546864543
# [09/20/2021 10:30:47 INFO 140321942804288] Epoch 1: Loss improved. Updating best model
# [09/20/2021 10:30:47 INFO 140321942804288] Saving model for epoch: 1
# [09/20/2021 10:30:47 INFO 140321942804288] Saved checkpoint to "/tmp/tmp22kpq2tq/mx-mod-0000.params"
# [09/20/2021 10:30:47 INFO 140321942804288] #progress_metric: host=algo-1, completed 20.0 % of epochs
# #metrics {"StartTime": 1632133817.504206, "EndTime": 1632133847.1444554, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 410728.0, "count": 1, "min": 410728, "max": 410728}, "Total Batches Seen": {"sum": 412.0, "count": 1, "min": 412, "max": 412}, "Max Records Seen Between Resets": {"sum": 199364.0, "count": 1, "min": 199364, "max": 199364}, "Max Batches Seen Between Resets": {"sum": 200.0, "count": 1, "min": 200, "max": 200}, "Reset Count": {"sum": 4.0, "count": 1, "min": 4, "max": 4}, "Number of Records Since Last Reset": {"sum": 199364.0, "count": 1, "min": 199364, "max": 199364}, "Number of Batches Since Last Reset": {"sum": 200.0, "count": 1, "min": 200, "max": 200}}}
#
# [09/20/2021 10:30:47 INFO 140321942804288] #throughput_metric: host=algo-1, train throughput=6726.101226665159 records/second
# [2021-09-20 10:31:16.888] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 7, "duration": 29743, "num_examples": 200, "num_bytes": 33493152}
# #metrics {"StartTime": 1632133876.888046, "EndTime": 1632133876.8881047, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 0}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.010249469649851621, "count": 1, "min": 0.010249469649851621, "max": 0.010249469649851621}}}
#
# #metrics {"StartTime": 1632133876.88818, "EndTime": 1632133876.8881936, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 1}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.008671593240158043, "count": 1, "min": 0.008671593240158043, "max": 0.008671593240158043}}}
#
# #metrics {"StartTime": 1632133876.888228, "EndTime": 1632133876.888237, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 2}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.010244106330464233, "count": 1, "min": 0.010244106330464233, "max": 0.010244106330464233}}}
#
# #metrics {"StartTime": 1632133876.8882735, "EndTime": 1632133876.8882825, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 3}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.008672056543767152, "count": 1, "min": 0.008672056543767152, "max": 0.008672056543767152}}}
#
# #metrics {"StartTime": 1632133876.8883119, "EndTime": 1632133876.8883197, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 4}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.004918119254049344, "count": 1, "min": 0.004918119254049344, "max": 0.004918119254049344}}}
#
# #metrics {"StartTime": 1632133876.888353, "EndTime": 1632133876.8883615, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 5}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.0056512911585183, "count": 1, "min": 0.0056512911585183, "max": 0.0056512911585183}}}
#
# #metrics {"StartTime": 1632133876.8883905, "EndTime": 1632133876.8883986, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 6}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.004927347601714296, "count": 1, "min": 0.004927347601714296, "max": 0.004927347601714296}}}
#
# #metrics {"StartTime": 1632133876.8884242, "EndTime": 1632133876.8884318, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 7}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.005514238939812435, "count": 1, "min": 0.005514238939812435, "max": 0.005514238939812435}}}
#
# #metrics {"StartTime": 1632133876.8884583, "EndTime": 1632133876.8884656, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 8}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.010515944311966249, "count": 1, "min": 0.010515944311966249, "max": 0.010515944311966249}}}
#
# #metrics {"StartTime": 1632133876.8884993, "EndTime": 1632133876.8885076, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 9}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.009003221600498986, "count": 1, "min": 0.009003221600498986, "max": 0.009003221600498986}}}
#
# #metrics {"StartTime": 1632133876.888536, "EndTime": 1632133876.8885438, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 10}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.010521823818959183, "count": 1, "min": 0.010521823818959183, "max": 0.010521823818959183}}}
#
# #metrics {"StartTime": 1632133876.8885732, "EndTime": 1632133876.8885806, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 11}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.008999886714034344, "count": 1, "min": 0.008999886714034344, "max": 0.008999886714034344}}}
#
# #metrics {"StartTime": 1632133876.8886132, "EndTime": 1632133876.8886216, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 12}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.005593624009708664, "count": 1, "min": 0.005593624009708664, "max": 0.005593624009708664}}}
#
# #metrics {"StartTime": 1632133876.8886552, "EndTime": 1632133876.8886635, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 13}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.005721277655219313, "count": 1, "min": 0.005721277655219313, "max": 0.005721277655219313}}}
#
# #metrics {"StartTime": 1632133876.888692, "EndTime": 1632133876.8886995, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 14}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.0055466306109224735, "count": 1, "min": 0.0055466306109224735, "max": 0.0055466306109224735}}}
#
# #metrics {"StartTime": 1632133876.8887327, "EndTime": 1632133876.888741, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 15}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.00571299303513975, "count": 1, "min": 0.00571299303513975, "max": 0.00571299303513975}}}
#
# #metrics {"StartTime": 1632133876.888767, "EndTime": 1632133876.8887744, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 16}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.015533093286519075, "count": 1, "min": 0.015533093286519075, "max": 0.015533093286519075}}}
#
# #metrics {"StartTime": 1632133876.8888044, "EndTime": 1632133876.8888118, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 17}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.014290418466730933, "count": 1, "min": 0.014290418466730933, "max": 0.014290418466730933}}}
#
# #metrics {"StartTime": 1632133876.8888443, "EndTime": 1632133876.8888528, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 18}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.015534086321466533, "count": 1, "min": 0.015534086321466533, "max": 0.015534086321466533}}}
#
# #metrics {"StartTime": 1632133876.888881, "EndTime": 1632133876.8888884, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 19}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.014295967544742565, "count": 1, "min": 0.014295967544742565, "max": 0.014295967544742565}}}
#
# #metrics {"StartTime": 1632133876.8889203, "EndTime": 1632133876.8889287, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 20}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.01207214400711371, "count": 1, "min": 0.01207214400711371, "max": 0.01207214400711371}}}
#
# #metrics {"StartTime": 1632133876.8889623, "EndTime": 1632133876.8889709, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 21}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.012130517083346544, "count": 1, "min": 0.012130517083346544, "max": 0.012130517083346544}}}
#
# #metrics {"StartTime": 1632133876.8889997, "EndTime": 1632133876.889007, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 22}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.012072038061504987, "count": 1, "min": 0.012072038061504987, "max": 0.012072038061504987}}}
#
# #metrics {"StartTime": 1632133876.8890367, "EndTime": 1632133876.8890438, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 23}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.01212600906410409, "count": 1, "min": 0.01212600906410409, "max": 0.01212600906410409}}}
#
# #metrics {"StartTime": 1632133876.8890762, "EndTime": 1632133876.8890843, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 24}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.016575735966763903, "count": 1, "min": 0.016575735966763903, "max": 0.016575735966763903}}}
#
# #metrics {"StartTime": 1632133876.8891182, "EndTime": 1632133876.8891263, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 25}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.015361840303818784, "count": 1, "min": 0.015361840303818784, "max": 0.015361840303818784}}}
#
# #metrics {"StartTime": 1632133876.889155, "EndTime": 1632133876.8891623, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 26}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.0165775283934483, "count": 1, "min": 0.0165775283934483, "max": 0.0165775283934483}}}
#
# #metrics {"StartTime": 1632133876.8891916, "EndTime": 1632133876.8891988, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 27}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.015363927146298202, "count": 1, "min": 0.015363927146298202, "max": 0.015363927146298202}}}
#
# #metrics {"StartTime": 1632133876.8892314, "EndTime": 1632133876.8892395, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 28}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.013144806534351416, "count": 1, "min": 0.013144806534351416, "max": 0.013144806534351416}}}
#
# #metrics {"StartTime": 1632133876.889273, "EndTime": 1632133876.8892813, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 29}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.013156181953959728, "count": 1, "min": 0.013156181953959728, "max": 0.013156181953959728}}}
#
# #metrics {"StartTime": 1632133876.8893096, "EndTime": 1632133876.8893168, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 30}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.013145586853350827, "count": 1, "min": 0.013145586853350827, "max": 0.013145586853350827}}}
#
# #metrics {"StartTime": 1632133876.8893492, "EndTime": 1632133876.8893576, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 31}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.013155478202068626, "count": 1, "min": 0.013155478202068626, "max": 0.013155478202068626}}}
#
# [09/20/2021 10:31:16 INFO 140321942804288] #quality_metric: host=algo-1, epoch=2, train binary_classification_cross_entropy_objective <loss>=0.010249469649851621
# [09/20/2021 10:31:16 INFO 140321942804288] #early_stopping_criteria_metric: host=algo-1, epoch=2, criteria=binary_classification_cross_entropy_objective, value=0.004918119254049344
# [09/20/2021 10:31:16 INFO 140321942804288] Epoch 2: Loss improved. Updating best model
# [09/20/2021 10:31:16 INFO 140321942804288] Saving model for epoch: 2
# [09/20/2021 10:31:16 INFO 140321942804288] Saved checkpoint to "/tmp/tmps3s2a40x/mx-mod-0000.params"
# [09/20/2021 10:31:16 INFO 140321942804288] #progress_metric: host=algo-1, completed 30.0 % of epochs
# #metrics {"StartTime": 1632133847.1446695, "EndTime": 1632133876.904387, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 610092.0, "count": 1, "min": 610092, "max": 610092}, "Total Batches Seen": {"sum": 612.0, "count": 1, "min": 612, "max": 612}, "Max Records Seen Between Resets": {"sum": 199364.0, "count": 1, "min": 199364, "max": 199364}, "Max Batches Seen Between Resets": {"sum": 200.0, "count": 1, "min": 200, "max": 200}, "Reset Count": {"sum": 5.0, "count": 1, "min": 5, "max": 5}, "Number of Records Since Last Reset": {"sum": 199364.0, "count": 1, "min": 199364, "max": 199364}, "Number of Batches Since Last Reset": {"sum": 200.0, "count": 1, "min": 200, "max": 200}}}
#
# [09/20/2021 10:31:16 INFO 140321942804288] #throughput_metric: host=algo-1, train throughput=6699.100145060487 records/second
# [2021-09-20 10:31:46.640] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 9, "duration": 29735, "num_examples": 200, "num_bytes": 33493152}
# #metrics {"StartTime": 1632133906.6401415, "EndTime": 1632133906.640203, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 0}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.007960710554266694, "count": 1, "min": 0.007960710554266694, "max": 0.007960710554266694}}}
#
# #metrics {"StartTime": 1632133906.640283, "EndTime": 1632133906.640297, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 1}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.006608913767876937, "count": 1, "min": 0.006608913767876937, "max": 0.006608913767876937}}}
#
# #metrics {"StartTime": 1632133906.6403358, "EndTime": 1632133906.640343, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 2}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.007957083736232776, "count": 1, "min": 0.007957083736232776, "max": 0.007957083736232776}}}
#
# #metrics {"StartTime": 1632133906.6403732, "EndTime": 1632133906.6403823, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 3}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.0066104845006262234, "count": 1, "min": 0.0066104845006262234, "max": 0.0066104845006262234}}}
#
# ...
#
# #metrics {"StartTime": 1632134084.761978, "EndTime": 1632134084.761986, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 9, "model": 3}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.004363289042633382, "count": 1, "min": 0.004363289042633382, "max": 0.004363289042633382}}}
#
# #metrics {"StartTime": 1632134084.762012, "EndTime": 1632134084.7620196, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 9, "model": 4}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.0042582856896309996, "count": 1, "min": 0.0042582856896309996, "max": 0.0042582856896309996}}}
#
# #metrics {"StartTime": 1632134084.7620473, "EndTime": 1632134084.762055, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 9, "model": 5}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.005372135753102188, "count": 1, "min": 0.005372135753102188, "max": 0.005372135753102188}}}
#
# #metrics {"StartTime": 1632134084.7620883, "EndTime": 1632134084.7620971, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 9, "model": 6}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.004226420863938691, "count": 1, "min": 0.004226420863938691, "max": 0.004226420863938691}}}
#
# #metrics {"StartTime": 1632134084.7621253, "EndTime": 1632134084.7621326, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 9, "model": 7}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.005512768081403408, "count": 1, "min": 0.005512768081403408, "max": 0.005512768081403408}}}
#
# #metrics {"StartTime": 1632134084.7621627, "EndTime": 1632134084.7621703, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 9, "model": 8}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.005814565002918244, "count": 1, "min": 0.005814565002918244, "max": 0.005814565002918244}}}
#
# #metrics {"StartTime": 1632134084.7622008, "EndTime": 1632134084.7622082, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 9, "model": 9}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.005203934738084898, "count": 1, "min": 0.005203934738084898, "max": 0.005203934738084898}}}
#
# #metrics {"StartTime": 1632134084.7622364, "EndTime": 1632134084.7622437, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 9, "model": 10}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.005815549342177022, "count": 1, "min": 0.005815549342177022, "max": 0.005815549342177022}}}
#
# #metrics {"StartTime": 1632134084.7622716, "EndTime": 1632134084.7622788, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 9, "model": 11}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.005203671823194878, "count": 1, "min": 0.005203671823194878, "max": 0.005203671823194878}}}
#
# #metrics {"StartTime": 1632134084.762305, "EndTime": 1632134084.7623127, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 9, "model": 12}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.0051988108460627605, "count": 1, "min": 0.0051988108460627605, "max": 0.0051988108460627605}}}
#
# #metrics {"StartTime": 1632134084.7623382, "EndTime": 1632134084.7623458, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 9, "model": 13}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.005592380854801916, "count": 1, "min": 0.005592380854801916, "max": 0.005592380854801916}}}
#
# #metrics {"StartTime": 1632134084.7623777, "EndTime": 1632134084.7623858, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 9, "model": 14}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.005197920887389375, "count": 1, "min": 0.005197920887389375, "max": 0.005197920887389375}}}
#
# #metrics {"StartTime": 1632134084.7624156, "EndTime": 1632134084.762423, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 9, "model": 15}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.005594979524163145, "count": 1, "min": 0.005594979524163145, "max": 0.005594979524163145}}}
#
# #metrics {"StartTime": 1632134084.7624485, "EndTime": 1632134084.7624564, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 9, "model": 16}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.012274922032152588, "count": 1, "min": 0.012274922032152588, "max": 0.012274922032152588}}}
#
# #metrics {"StartTime": 1632134084.7624812, "EndTime": 1632134084.7624886, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 9, "model": 17}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.0120510175553099, "count": 1, "min": 0.0120510175553099, "max": 0.0120510175553099}}}
#
# #metrics {"StartTime": 1632134084.7625132, "EndTime": 1632134084.7625206, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 9, "model": 18}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.01227521650455705, "count": 1, "min": 0.01227521650455705, "max": 0.01227521650455705}}}
#
# #metrics {"StartTime": 1632134084.762545, "EndTime": 1632134084.7625525, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 9, "model": 19}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.012051567992972368, "count": 1, "min": 0.012051567992972368, "max": 0.012051567992972368}}}
#
# #metrics {"StartTime": 1632134084.762578, "EndTime": 1632134084.7625852, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 9, "model": 20}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.012006970596822661, "count": 1, "min": 0.012006970596822661, "max": 0.012006970596822661}}}
#
# #metrics {"StartTime": 1632134084.7626104, "EndTime": 1632134084.762618, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 9, "model": 21}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.012165758089129649, "count": 1, "min": 0.012165758089129649, "max": 0.012165758089129649}}}
#
# #metrics {"StartTime": 1632134084.76265, "EndTime": 1632134084.7626586, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 9, "model": 22}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.012006662839621155, "count": 1, "min": 0.012006662839621155, "max": 0.012006662839621155}}}
#
# #metrics {"StartTime": 1632134084.762687, "EndTime": 1632134084.7626944, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 9, "model": 23}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.012164851203411068, "count": 1, "min": 0.012164851203411068, "max": 0.012164851203411068}}}
#
# #metrics {"StartTime": 1632134084.7627196, "EndTime": 1632134084.7627273, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 9, "model": 24}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.013300977661681535, "count": 1, "min": 0.013300977661681535, "max": 0.013300977661681535}}}
#
# #metrics {"StartTime": 1632134084.762759, "EndTime": 1632134084.7627673, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 9, "model": 25}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.013129347929103889, "count": 1, "min": 0.013129347929103889, "max": 0.013129347929103889}}}
#
# #metrics {"StartTime": 1632134084.762793, "EndTime": 1632134084.7628007, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 9, "model": 26}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.013301086272726107, "count": 1, "min": 0.013301086272726107, "max": 0.013301086272726107}}}
#
# #metrics {"StartTime": 1632134084.7628324, "EndTime": 1632134084.7628405, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 9, "model": 27}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.013129787432188964, "count": 1, "min": 0.013129787432188964, "max": 0.013129787432188964}}}
#
# #metrics {"StartTime": 1632134084.762874, "EndTime": 1632134084.762882, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 9, "model": 28}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.013142530095786904, "count": 1, "min": 0.013142530095786904, "max": 0.013142530095786904}}}
#
# #metrics {"StartTime": 1632134084.7629151, "EndTime": 1632134084.7629235, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 9, "model": 29}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.013223914261589097, "count": 1, "min": 0.013223914261589097, "max": 0.013223914261589097}}}
#
# #metrics {"StartTime": 1632134084.7629538, "EndTime": 1632134084.7629614, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 9, "model": 30}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.013142305586505774, "count": 1, "min": 0.013142305586505774, "max": 0.013142305586505774}}}
#
# #metrics {"StartTime": 1632134084.7629936, "EndTime": 1632134084.763002, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 9, "model": 31}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.013220851825110277, "count": 1, "min": 0.013220851825110277, "max": 0.013220851825110277}}}
#
# [09/20/2021 10:34:44 INFO 140321942804288] #quality_metric: host=algo-1, epoch=9, train binary_classification_cross_entropy_objective <loss>=0.005176235068233768
# [09/20/2021 10:34:44 INFO 140321942804288] #early_stopping_criteria_metric: host=algo-1, epoch=9, criteria=binary_classification_cross_entropy_objective, value=0.004226420863938691
# [09/20/2021 10:34:44 INFO 140321942804288] Epoch 9: Loss improved. Updating best model
# [09/20/2021 10:34:44 INFO 140321942804288] Saving model for epoch: 9
# [09/20/2021 10:34:44 INFO 140321942804288] Saved checkpoint to "/tmp/tmpf0ms9s6p/mx-mod-0000.params"
# [09/20/2021 10:34:44 INFO 140321942804288] #progress_metric: host=algo-1, completed 100.0 % of epochs
# #metrics {"StartTime": 1632134055.245451, "EndTime": 1632134084.7784603, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 9, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 2005640.0, "count": 1, "min": 2005640, "max": 2005640}, "Total Batches Seen": {"sum": 2012.0, "count": 1, "min": 2012, "max": 2012}, "Max Records Seen Between Resets": {"sum": 199364.0, "count": 1, "min": 199364, "max": 199364}, "Max Batches Seen Between Resets": {"sum": 200.0, "count": 1, "min": 200, "max": 200}, "Reset Count": {"sum": 12.0, "count": 1, "min": 12, "max": 12}, "Number of Records Since Last Reset": {"sum": 199364.0, "count": 1, "min": 199364, "max": 199364}, "Number of Batches Since Last Reset": {"sum": 200.0, "count": 1, "min": 200, "max": 200}}}
#
# [09/20/2021 10:34:44 INFO 140321942804288] #throughput_metric: host=algo-1, train throughput=6750.524947226484 records/second
# [09/20/2021 10:34:44 WARNING 140321942804288] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [09/20/2021 10:34:44 WARNING 140321942804288] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [2021-09-20 10:34:44.782] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 23, "duration": 3, "num_examples": 1, "num_bytes": 168000}
# [2021-09-20 10:34:45.405] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 26, "duration": 620, "num_examples": 200, "num_bytes": 33493152}
# [2021-09-20 10:34:46.533] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 28, "duration": 1061, "num_examples": 200, "num_bytes": 33493152}
# [09/20/2021 10:34:46 INFO 140321942804288] #train_score (algo-1) : ('binary_classification_cross_entropy_objective', 0.003955219415968162)
# [09/20/2021 10:34:46 INFO 140321942804288] #train_score (algo-1) : ('binary_classification_accuracy', 0.9992927509480147)
# [09/20/2021 10:34:46 INFO 140321942804288] #train_score (algo-1) : ('binary_f_1.000', 0.8011283497884344)
# [09/20/2021 10:34:46 INFO 140321942804288] #train_score (algo-1) : ('precision', 0.8068181818181818)
# [09/20/2021 10:34:46 INFO 140321942804288] #train_score (algo-1) : ('recall', 0.7955182072829131)
# [09/20/2021 10:34:46 INFO 140321942804288] #train_score (algo-1) : ('roc_auc_score', 0.9773347499466505)
# [09/20/2021 10:34:46 INFO 140321942804288] #quality_metric: host=algo-1, train binary_classification_cross_entropy_objective <loss>=0.003955219415968162
# [09/20/2021 10:34:46 INFO 140321942804288] #quality_metric: host=algo-1, train binary_classification_accuracy <score>=0.9992927509480147
# [09/20/2021 10:34:46 INFO 140321942804288] #quality_metric: host=algo-1, train binary_f_1.000 <score>=0.8011283497884344
# [09/20/2021 10:34:46 INFO 140321942804288] #quality_metric: host=algo-1, train precision <score>=0.8068181818181818
# [09/20/2021 10:34:46 INFO 140321942804288] #quality_metric: host=algo-1, train recall <score>=0.7955182072829131
# [09/20/2021 10:34:46 INFO 140321942804288] #quality_metric: host=algo-1, train roc_auc_score <score>=0.9773347499466505
# [09/20/2021 10:34:46 INFO 140321942804288] Best model found for hyperparameters: {"optimizer": "adam", "learning_rate": 0.1, "wd": 0.0001, "l1": 0.0, "lr_scheduler_step": 10, "lr_scheduler_factor": 0.99, "lr_scheduler_minimum_lr": 0.0001}
# [09/20/2021 10:34:46 INFO 140321942804288] Saved checkpoint to "/tmp/tmp1imt5_4v/mx-mod-0000.params"
# [09/20/2021 10:34:46 INFO 140321942804288] Test data is not provided.
# #metrics {"StartTime": 1632133771.2415402, "EndTime": 1632134086.6072266, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training"}, "Metrics": {"initialize.time": {"sum": 16632.262229919434, "count": 1, "min": 16632.262229919434, "max": 16632.262229919434}, "epochs": {"sum": 10.0, "count": 1, "min": 10, "max": 10}, "check_early_stopping.time": {"sum": 10.2996826171875, "count": 10, "min": 0.957489013671875, "max": 1.1105537414550781}, "update.time": {"sum": 296861.1710071564, "count": 10, "min": 29530.465126037598, "max": 29777.74977684021}, "finalize.time": {"sum": 1817.4502849578857, "count": 1, "min": 1817.4502849578857, "max": 1817.4502849578857}, "setuptime": {"sum": 23.975849151611328, "count": 1, "min": 23.975849151611328, "max": 23.975849151611328}, "totaltime": {"sum": 315579.79369163513, "count": 1, "min": 315579.79369163513, "max": 315579.79369163513}}}
# 2021-09-20 10:35:12 Uploading - Uploading generated training model
# 2021-09-20 10:35:12 Completed - Training job completed
# ProfilerReport-1632133567: NoIssuesFound
# Training seconds: 376
# Billable seconds: 376
# CPU times: user 1.23 s, sys: 47.7 ms, total: 1.28 s
# Wall time: 9min 16s

# %% [markdown]
# ### EXERCISE: Deploy the trained model
#
# Deploy your model to create a predictor. We'll use this to make predictions on our test data and evaluate the model.

# %%
# %%time 
# deploy and create a predictor
linear_predictor = LinLearner.deploy(
    initial_instance_count=1,
    instance_type="ml.m4.xlarge"
)
# Out:
# Defaulting to the only supported framework/algorithm version: 1. Ignoring framework/algorithm version: 1.
# -------------!CPU times: user 237 ms, sys: 4.46 ms, total: 242 ms
# Wall time: 6min 31s

# %% [markdown]
# ---
# # Evaluating Your Model
#
# Once your model is deployed, you can see how it performs when applied to the test data.
#
# According to the deployed [predictor documentation](https://sagemaker.readthedocs.io/en/stable/linear_learner.html#sagemaker.LinearLearnerPredictor), this predictor expects an `ndarray` of input features and returns a list of Records.
# > "The prediction is stored in the "predicted_label" key of the `Record.label` field."
#
# Let's first test our model on just one test point, to see the resulting list.

# %%
# test one prediction
test_x_np = test_features.astype('float32')
result = linear_predictor.predict(test_x_np.iloc[0].to_numpy())
#test_x_np.iloc[0].to_numpy()
print(result)
# Out:
# [label {
#   key: "predicted_label"
#   value {
#     float32_tensor {
#       values: 0.0
#     }
#   }
# }
# label {
#   key: "score"
#   value {
#     float32_tensor {
#       values: 0.0002565080358181149
#     }
#   }
# }
# ]

# %% [markdown]
# ### Helper function for evaluation
#
#
# The provided function below, takes in a deployed predictor, some test features and labels, and returns a dictionary of metrics; calculating false negatives and positives as well as recall, precision, and accuracy.

# %%
# code to evaluate the endpoint on test data
# returns a variety of model metrics
def evaluate(predictor, test_features, test_labels, verbose=True):
    """
    Evaluate a model on a test set given the prediction endpoint.  
    Return binary classification metrics.
    :param predictor: A prediction endpoint
    :param test_features: Test features
    :param test_labels: Class labels for test data
    :param verbose: If True, prints a table of all performance metrics
    :return: A dictionary of performance metrics.
    """
    
    # We have a lot of test data, so we'll split it into batches of 100
    # split the test data set into batches and evaluate using prediction endpoint    
    prediction_batches = [predictor.predict(batch) for batch in np.array_split(test_features, 100)]
    
    # LinearLearner produces a `predicted_label` for each data point in a batch
    # get the 'predicted_label' for every point in a batch
    test_preds = np.concatenate([np.array([x.label['predicted_label'].float32_tensor.values[0] for x in batch]) 
                                 for batch in prediction_batches])
    
    # calculate true positives, false positives, true negatives, false negatives
    tp = np.logical_and(test_labels, test_preds).sum()
    fp = np.logical_and(1-test_labels, test_preds).sum()
    tn = np.logical_and(1-test_labels, 1-test_preds).sum()
    fn = np.logical_and(test_labels, 1-test_preds).sum()
    
    # calculate binary classification metrics
    recall = tp / (tp + fn)
    precision = tp / (tp + fp)
    accuracy = (tp + tn) / (tp + fp + tn + fn)
    
    # printing a table of metrics
    if verbose:
        print(pd.crosstab(test_labels, test_preds, rownames=['actual (row)'], colnames=['prediction (col)']))
        print("\n{:<11} {:.3f}".format('Recall:', recall))
        print("{:<11} {:.3f}".format('Precision:', precision))
        print("{:<11} {:.3f}".format('Accuracy:', accuracy))
        print()
        
    return {'TP': tp, 'FP': fp, 'FN': fn, 'TN': tn, 
            'Precision': precision, 'Recall': recall, 'Accuracy': accuracy}

# %% [markdown]
# ### Test Results
#
# The cell below runs the `evaluate` function.
#
# The code assumes that you have a defined `predictor` and `test_features` and `test_labels` from previously-run cells.

# %%
print('Metrics for simple, LinearLearner.\n')

# get metrics for linear predictor
metrics = evaluate(linear_predictor, 
                   test_features.astype('float32').to_numpy(), 
                   test_labels.astype('float32').to_numpy(), 
                   verbose=True) # verbose means we'll print out the metrics
# Out:
# Metrics for simple, LinearLearner.
#
# prediction (col)    0.0  1.0
# actual (row)
# 0.0               85281   27
# 1.0                  36   99
#
# Recall:     0.733
# Precision:  0.786
# Accuracy:   0.999

# %% [markdown]
# ## Delete the Endpoint
#
# I've added a convenience function to delete prediction endpoints after we're done with them. And if you're done evaluating the model, you should delete your model endpoint!

# %%
# Deletes a precictor.endpoint
def delete_endpoint(predictor):
        try:
            boto3.client('sagemaker').delete_endpoint(EndpointName=predictor.endpoint)
            print('Deleted {}'.format(predictor.endpoint))
        except:
            print('Already deleted: {}'.format(predictor.endpoint))

# %%
# delete the predictor endpoint 
#delete_endpoint(linear_predictor)
sagemaker_session.delete_endpoint(linear_predictor.endpoint)
# Out:
# The endpoint attribute has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.

# %% [markdown]
# ---
#
# # Model Improvements
#
# The default LinearLearner got a high accuracy, but still classified fraudulent and valid data points incorrectly. Specifically classifying more than 30 points as false negatives (incorrectly labeled, fraudulent transactions), and a little over 30 points as false positives (incorrectly labeled, valid transactions). Let's think about what, during training, could cause this behavior and what we could improve.
#
# **1. Model optimization**
# * If we imagine that we are designing this model for use in a bank application, we know that users do *not* want any valid transactions to be categorized as fraudulent. That is, we want to have as few **false positives** (0s classified as 1s) as possible.
# * On the other hand, if our bank manager asks for an application that will catch almost *all* cases of fraud, even if it means a higher number of false positives, then we'd want as few **false negatives** as possible.
# * To train according to specific product demands and goals, we do not want to optimize for accuracy only. Instead, we want to optimize for a metric that can help us decrease the number of false positives or negatives.
#
# <img src='notebook_ims/precision_recall.png' width=40% />
#
# In this notebook, we'll look at different cases for tuning a model and make an optimization decision, accordingly.
#
# **2. Imbalanced training data**
# * At the start of this notebook, we saw that only about 0.17% of the training data was labeled as fraudulent. So, even if a model labels **all** of our data as valid, it will still have a high accuracy.
# * This may result in some overfitting towards valid data, which accounts for some **false negatives**; cases in which fraudulent data (1) is incorrectly characterized as valid (0).
#
# So, let's address these issues in order; first, tuning our model and optimizing for a specific metric during training, and second, accounting for class imbalance in the training set.

# %% [markdown]
# ## Improvement: Model Tuning
#
# Optimizing according to a specific metric is called **model tuning**, and SageMaker provides a number of ways to automatically tune a model.
#
#
# ### Create a LinearLearner and tune for higher precision
#
# **Scenario:**
# * A bank has asked you to build a model that detects cases of fraud with an accuracy of about 85%.
#
# In this case, we want to build a model that has as many true positives and as few false negatives, as possible. This corresponds to a model with a high **recall**: true positives / (true positives + false negatives).
#
# To aim for a specific metric, LinearLearner offers the hyperparameter `binary_classifier_model_selection_criteria`, which is the model evaluation criteria for the training dataset. A reference to this parameter is in [LinearLearner's documentation](https://sagemaker.readthedocs.io/en/stable/linear_learner.html#sagemaker.LinearLearner). We'll also have to further specify the exact value we want to aim for; read more about the details of the parameters, [here](https://docs.aws.amazon.com/sagemaker/latest/dg/ll_hyperparameters.html).
#
# I will assume that performance on a training set will be within about 5% of the performance on a test set. So, for a recall of about 85%, I'll aim for a bit higher, 90%.

# %%
prefix = 'fraud'
output_path='s3://{}/{}/'.format(bucket, prefix)
print(f'Training artifacts will be uploaded to: \n{output_path}')

# instantiate a LinearLearner
# tune the model for a higher recall
from sagemaker import LinearLearner

linear_recall = LinearLearner(role=role,
                              train_instance_count=1, 
                              train_instance_type='ml.p3.8xlarge',
                              predictor_type='binary_classifier',
                              output_path=output_path,
                              sagemaker_session=sagemaker_session,
                              epochs=15,
                              binary_classifier_model_selection_criteria='precision_at_target_recall', # target recall
                              target_recall=0.9) # 90% recall
# Out:
# train_instance_count has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# train_instance_type has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# Training artifacts will be uploaded to:
# s3://sagemaker-eu-central-1-092764612399/fraud/

# %% [markdown]
# ### Train the tuned estimator
#
# Fit the new, tuned estimator on the formatted training data.

# %%
# %%time 

# create RecordSet of training data
formatted_train_data = linear_recall.record_set(
    train=train_features.astype('float32').to_numpy(),
    labels=train_labels.astype('float32').to_numpy()
)
# train the estimator on formatted training data
linear_recall.fit(formatted_train_data)
# Out:
# Defaulting to the only supported framework/algorithm version: 1. Ignoring framework/algorithm version: 1.
# Defaulting to the only supported framework/algorithm version: 1. Ignoring framework/algorithm version: 1.
# 2021-09-21 04:08:27 Starting - Starting the training job...
# 2021-09-21 04:08:50 Starting - Launching requested ML instancesProfilerReport-1632197307: InProgress
# ......
# 2021-09-21 04:09:50 Starting - Preparing the instances for training.........
# 2021-09-21 04:11:11 Downloading - Downloading input data...
# 2021-09-21 04:11:51 Training - Training image download completed. Training in progress.Docker entrypoint called with argument(s): train
# Running default environment configuration script
# [09/21/2021 04:11:49 INFO 140286115153728] Reading default configuration from /opt/amazon/lib/python3.7/site-packages/algorithm/resources/default-input.json: {'mini_batch_size': '1000', 'epochs': '15', 'feature_dim': 'auto', 'use_bias': 'true', 'binary_classifier_model_selection_criteria': 'accuracy', 'f_beta': '1.0', 'target_recall': '0.8', 'target_precision': '0.8', 'num_models': 'auto', 'num_calibration_samples': '10000000', 'init_method': 'uniform', 'init_scale': '0.07', 'init_sigma': '0.01', 'init_bias': '0.0', 'optimizer': 'auto', 'loss': 'auto', 'margin': '1.0', 'quantile': '0.5', 'loss_insensitivity': '0.01', 'huber_delta': '1.0', 'num_classes': '1', 'accuracy_top_k': '3', 'wd': 'auto', 'l1': 'auto', 'momentum': 'auto', 'learning_rate': 'auto', 'beta_1': 'auto', 'beta_2': 'auto', 'bias_lr_mult': 'auto', 'bias_wd_mult': 'auto', 'use_lr_scheduler': 'true', 'lr_scheduler_step': 'auto', 'lr_scheduler_factor': 'auto', 'lr_scheduler_minimum_lr': 'auto', 'positive_example_weight_mult': '1.0', 'balance_multiclass_weights': 'false', 'normalize_data': 'true', 'normalize_label': 'auto', 'unbias_data': 'auto', 'unbias_label': 'auto', 'num_point_for_scaler': '10000', '_kvstore': 'auto', '_num_gpus': 'auto', '_num_kv_servers': 'auto', '_log_level': 'info', '_tuning_objective_metric': '', 'early_stopping_patience': '3', 'early_stopping_tolerance': '0.001', '_enable_profiler': 'false'}
# [09/21/2021 04:11:49 INFO 140286115153728] Merging with provided configuration from /opt/ml/input/config/hyperparameters.json: {'feature_dim': '30', 'predictor_type': 'binary_classifier', 'epochs': '15', 'target_recall': '0.9', 'binary_classifier_model_selection_criteria': 'precision_at_target_recall', 'mini_batch_size': '1000'}
# [09/21/2021 04:11:49 INFO 140286115153728] Final configuration: {'mini_batch_size': '1000', 'epochs': '15', 'feature_dim': '30', 'use_bias': 'true', 'binary_classifier_model_selection_criteria': 'precision_at_target_recall', 'f_beta': '1.0', 'target_recall': '0.9', 'target_precision': '0.8', 'num_models': 'auto', 'num_calibration_samples': '10000000', 'init_method': 'uniform', 'init_scale': '0.07', 'init_sigma': '0.01', 'init_bias': '0.0', 'optimizer': 'auto', 'loss': 'auto', 'margin': '1.0', 'quantile': '0.5', 'loss_insensitivity': '0.01', 'huber_delta': '1.0', 'num_classes': '1', 'accuracy_top_k': '3', 'wd': 'auto', 'l1': 'auto', 'momentum': 'auto', 'learning_rate': 'auto', 'beta_1': 'auto', 'beta_2': 'auto', 'bias_lr_mult': 'auto', 'bias_wd_mult': 'auto', 'use_lr_scheduler': 'true', 'lr_scheduler_step': 'auto', 'lr_scheduler_factor': 'auto', 'lr_scheduler_minimum_lr': 'auto', 'positive_example_weight_mult': '1.0', 'balance_multiclass_weights': 'false', 'normalize_data': 'true', 'normalize_label': 'auto', 'unbias_data': 'auto', 'unbias_label': 'auto', 'num_point_for_scaler': '10000', '_kvstore': 'auto', '_num_gpus': 'auto', '_num_kv_servers': 'auto', '_log_level': 'info', '_tuning_objective_metric': '', 'early_stopping_patience': '3', 'early_stopping_tolerance': '0.001', '_enable_profiler': 'false', 'predictor_type': 'binary_classifier'}
# [09/21/2021 04:11:49 WARNING 140286115153728] Loggers have already been setup.
# Process 1 is a worker.
# [09/21/2021 04:11:49 INFO 140286115153728] Using default worker.
# [09/21/2021 04:11:50 INFO 140286115153728] Checkpoint loading and saving are disabled.
# [2021-09-21 04:11:50.081] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 0, "duration": 20, "num_examples": 1, "num_bytes": 168000}
# [09/21/2021 04:11:50 INFO 140286115153728] Create Store: local
# [2021-09-21 04:11:50.149] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 1, "duration": 67, "num_examples": 11, "num_bytes": 1848000}
# [09/21/2021 04:11:50 INFO 140286115153728] Scaler algorithm parameters
#  <algorithm.scaler.ScalerAlgorithmStable object at 0x7f965b103510>
# [09/21/2021 04:11:50 INFO 140286115153728] Scaling model computed with parameters:
#  {'stdev_label': None, 'stdev_weight':
# [4.7823008e+04 1.8987731e+00 1.5821997e+00 1.5291911e+00 1.4364978e+00
#  1.3388461e+00 1.2955806e+00 1.1771069e+00 1.2127448e+00 1.0843055e+00
#  1.0475702e+00 1.0230465e+00 1.0090139e+00 1.0057642e+00 9.5122164e-01
#  9.2613727e-01 8.7072927e-01 8.6057234e-01 8.3151484e-01 8.2762748e-01
#  7.1313608e-01 7.3347980e-01 7.2524083e-01 5.6213826e-01 6.0201687e-01
#  5.1174247e-01 4.8000538e-01 3.7595215e-01 2.7081874e-01 2.3656270e+02]
# <NDArray 30 @cpu(0)>, 'mean_label': None, 'mean_weight':
# [ 9.4275984e+04 -1.7378727e-02  1.5538026e-02  2.5005125e-02
#   3.3166975e-02  1.8197566e-02  1.7799012e-03  6.9396999e-03
#   9.8540336e-03 -3.0757964e-02 -1.2736557e-02  4.0434714e-04
#  -1.4243029e-02  1.6704608e-02  2.2619881e-02 -9.6982103e-03
#  -4.7834702e-03 -1.6767335e-04 -9.0120723e-03 -3.0407687e-03
#   4.6031545e-03 -4.0078526e-03 -1.2586080e-04  1.2784966e-03
#   3.7617318e-03 -3.1254767e-03 -8.2200055e-04  3.4045519e-03
#  -1.0332187e-03  8.7559837e+01]
# <NDArray 30 @cpu(0)>}
# [09/21/2021 04:11:50 INFO 140286115153728] nvidia-smi: took 0.056 seconds to run.
# [09/21/2021 04:11:50 INFO 140286115153728] nvidia-smi identified 4 GPUs.
# [09/21/2021 04:11:50 INFO 140286115153728] Number of GPUs being used: 4
# #metrics {"StartTime": 1632197525.0390918, "EndTime": 1632197525.039128, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "Meta": "init_train_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 12000.0, "count": 1, "min": 12000, "max": 12000}, "Total Batches Seen": {"sum": 12.0, "count": 1, "min": 12, "max": 12}, "Max Records Seen Between Resets": {"sum": 11000.0, "count": 1, "min": 11000, "max": 11000}, "Max Batches Seen Between Resets": {"sum": 11.0, "count": 1, "min": 11, "max": 11}, "Reset Count": {"sum": 2.0, "count": 1, "min": 2, "max": 2}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
#
# [2021-09-21 04:12:35.707] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 3, "duration": 30666, "num_examples": 200, "num_bytes": 33493152}
# #metrics {"StartTime": 1632197555.7078238, "EndTime": 1632197555.707925, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 0}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.1202384072979491, "count": 1, "min": 0.1202384072979491, "max": 0.1202384072979491}}}
#
# #metrics {"StartTime": 1632197555.708012, "EndTime": 1632197555.7080355, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 1}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.11756252731150718, "count": 1, "min": 0.11756252731150718, "max": 0.11756252731150718}}}
#
# #metrics {"StartTime": 1632197555.7080948, "EndTime": 1632197555.7081125, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 2}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.12012009826497216, "count": 1, "min": 0.12012009826497216, "max": 0.12012009826497216}}}
#
# #metrics {"StartTime": 1632197555.7081718, "EndTime": 1632197555.7081873, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 3}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.11766779355427727, "count": 1, "min": 0.11766779355427727, "max": 0.11766779355427727}}}
#
# #metrics {"StartTime": 1632197555.7082403, "EndTime": 1632197555.7082562, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 4}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.012220082487059223, "count": 1, "min": 0.012220082487059223, "max": 0.012220082487059223}}}
#
# #metrics {"StartTime": 1632197555.7083104, "EndTime": 1632197555.7083259, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 5}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.01217558026043277, "count": 1, "min": 0.01217558026043277, "max": 0.01217558026043277}}}
#
# #metrics {"StartTime": 1632197555.7083857, "EndTime": 1632197555.7084014, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 6}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.012201708267335241, "count": 1, "min": 0.012201708267335241, "max": 0.012201708267335241}}}
#
# #metrics {"StartTime": 1632197555.7084527, "EndTime": 1632197555.708468, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 7}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.012345535695206505, "count": 1, "min": 0.012345535695206505, "max": 0.012345535695206505}}}
#
# #metrics {"StartTime": 1632197555.7085185, "EndTime": 1632197555.7085345, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 8}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.12014251559942811, "count": 1, "min": 0.12014251559942811, "max": 0.12014251559942811}}}
#
# #metrics {"StartTime": 1632197555.7085829, "EndTime": 1632197555.7085984, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 9}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.11776210112068522, "count": 1, "min": 0.11776210112068522, "max": 0.11776210112068522}}}
#
# #metrics {"StartTime": 1632197555.7086577, "EndTime": 1632197555.708673, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 10}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.12038166165711292, "count": 1, "min": 0.12038166165711292, "max": 0.12038166165711292}}}
#
# #metrics {"StartTime": 1632197555.7087579, "EndTime": 1632197555.7087755, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 11}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.1177079151766983, "count": 1, "min": 0.1177079151766983, "max": 0.1177079151766983}}}
#
# #metrics {"StartTime": 1632197555.7088337, "EndTime": 1632197555.7088497, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 12}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.012612578637958808, "count": 1, "min": 0.012612578637958808, "max": 0.012612578637958808}}}
#
# #metrics {"StartTime": 1632197555.7089112, "EndTime": 1632197555.7089272, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 13}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.012488340914647221, "count": 1, "min": 0.012488340914647221, "max": 0.012488340914647221}}}
#
# #metrics {"StartTime": 1632197555.7089767, "EndTime": 1632197555.7089922, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 14}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.012396600629586783, "count": 1, "min": 0.012396600629586783, "max": 0.012396600629586783}}}
#
# #metrics {"StartTime": 1632197555.7090468, "EndTime": 1632197555.709062, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 15}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.012499406318816745, "count": 1, "min": 0.012499406318816745, "max": 0.012499406318816745}}}
#
# #metrics {"StartTime": 1632197555.7091143, "EndTime": 1632197555.7091298, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 16}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.12282504722940263, "count": 1, "min": 0.12282504722940263, "max": 0.12282504722940263}}}
#
# #metrics {"StartTime": 1632197555.7091835, "EndTime": 1632197555.7091994, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 17}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.12008383033503241, "count": 1, "min": 0.12008383033503241, "max": 0.12008383033503241}}}
#
# #metrics {"StartTime": 1632197555.7092505, "EndTime": 1632197555.7092667, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 18}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.12283358869121302, "count": 1, "min": 0.12283358869121302, "max": 0.12283358869121302}}}
#
# #metrics {"StartTime": 1632197555.7093234, "EndTime": 1632197555.7093394, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 19}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.12025849870700932, "count": 1, "min": 0.12025849870700932, "max": 0.12025849870700932}}}
#
# #metrics {"StartTime": 1632197555.7093873, "EndTime": 1632197555.709403, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 20}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.0199439034713479, "count": 1, "min": 0.0199439034713479, "max": 0.0199439034713479}}}
#
# #metrics {"StartTime": 1632197555.7094612, "EndTime": 1632197555.7094772, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 21}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.01993385882793584, "count": 1, "min": 0.01993385882793584, "max": 0.01993385882793584}}}
#
# #metrics {"StartTime": 1632197555.7095368, "EndTime": 1632197555.7095525, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 22}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.01998765197312038, "count": 1, "min": 0.01998765197312038, "max": 0.01998765197312038}}}
#
# #metrics {"StartTime": 1632197555.7096114, "EndTime": 1632197555.7096272, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 23}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.019844267460756265, "count": 1, "min": 0.019844267460756265, "max": 0.019844267460756265}}}
#
# #metrics {"StartTime": 1632197555.7096748, "EndTime": 1632197555.7096908, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 24}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.12367209566058825, "count": 1, "min": 0.12367209566058825, "max": 0.12367209566058825}}}
#
# #metrics {"StartTime": 1632197555.7097461, "EndTime": 1632197555.7097619, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 25}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.12108522278819252, "count": 1, "min": 0.12108522278819252, "max": 0.12108522278819252}}}
#
# #metrics {"StartTime": 1632197555.709822, "EndTime": 1632197555.7098377, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 26}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.12374423367773468, "count": 1, "min": 0.12374423367773468, "max": 0.12374423367773468}}}
#
# #metrics {"StartTime": 1632197555.7098973, "EndTime": 1632197555.709913, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 27}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.12116944743880076, "count": 1, "min": 0.12116944743880076, "max": 0.12116944743880076}}}
#
# #metrics {"StartTime": 1632197555.709965, "EndTime": 1632197555.709981, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 28}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.021039976484053324, "count": 1, "min": 0.021039976484053324, "max": 0.021039976484053324}}}
#
# #metrics {"StartTime": 1632197555.710038, "EndTime": 1632197555.7100537, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 29}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.020920196507790655, "count": 1, "min": 0.020920196507790655, "max": 0.020920196507790655}}}
#
# #metrics {"StartTime": 1632197555.710113, "EndTime": 1632197555.7101295, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 30}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.021012824368986053, "count": 1, "min": 0.021012824368986053, "max": 0.021012824368986053}}}
#
# #metrics {"StartTime": 1632197555.710171, "EndTime": 1632197555.7101858, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 31}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.02103140465546418, "count": 1, "min": 0.02103140465546418, "max": 0.02103140465546418}}}
#
# [09/21/2021 04:12:35 INFO 140286115153728] #quality_metric: host=algo-1, epoch=0, train binary_classification_cross_entropy_objective <loss>=0.1202384072979491
# [09/21/2021 04:12:35 INFO 140286115153728] #early_stopping_criteria_metric: host=algo-1, epoch=0, criteria=binary_classification_cross_entropy_objective, value=0.01217558026043277
# [09/21/2021 04:12:35 INFO 140286115153728] Epoch 0: Loss improved. Updating best model
# [09/21/2021 04:12:35 INFO 140286115153728] Saving model for epoch: 0
# [09/21/2021 04:12:35 INFO 140286115153728] Saved checkpoint to "/tmp/tmpqo7zygxl/mx-mod-0000.params"
# [09/21/2021 04:12:35 INFO 140286115153728] #progress_metric: host=algo-1, completed 6.666666666666667 % of epochs
# #metrics {"StartTime": 1632197525.0394087, "EndTime": 1632197555.7310238, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 211364.0, "count": 1, "min": 211364, "max": 211364}, "Total Batches Seen": {"sum": 212.0, "count": 1, "min": 212, "max": 212}, "Max Records Seen Between Resets": {"sum": 199364.0, "count": 1, "min": 199364, "max": 199364}, "Max Batches Seen Between Resets": {"sum": 200.0, "count": 1, "min": 200, "max": 200}, "Reset Count": {"sum": 3.0, "count": 1, "min": 3, "max": 3}, "Number of Records Since Last Reset": {"sum": 199364.0, "count": 1, "min": 199364, "max": 199364}, "Number of Batches Since Last Reset": {"sum": 200.0, "count": 1, "min": 200, "max": 200}}}
#
# [09/21/2021 04:12:35 INFO 140286115153728] #throughput_metric: host=algo-1, train throughput=6495.694358774649 records/second
# [2021-09-21 04:13:06.429] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 5, "duration": 30698, "num_examples": 200, "num_bytes": 33493152}
# #metrics {"StartTime": 1632197586.430045, "EndTime": 1632197586.430109, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 0}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.016883339488925647, "count": 1, "min": 0.016883339488925647, "max": 0.016883339488925647}}}
#
# #metrics {"StartTime": 1632197586.430186, "EndTime": 1632197586.430201, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 1}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.014893327731582987, "count": 1, "min": 0.014893327731582987, "max": 0.014893327731582987}}}
#
# #metrics {"StartTime": 1632197586.4302452, "EndTime": 1632197586.4302552, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 2}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.016874810682469276, "count": 1, "min": 0.016874810682469276, "max": 0.016874810682469276}}}
#
# #metrics {"StartTime": 1632197586.4303, "EndTime": 1632197586.4303155, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 3}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.014889016261052846, "count": 1, "min": 0.014889016261052846, "max": 0.014889016261052846}}}
#
# #metrics {"StartTime": 1632197586.4303641, "EndTime": 1632197586.4303744, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 4}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.005409128546864543, "count": 1, "min": 0.005409128546864543, "max": 0.005409128546864543}}}
#
# #metrics {"StartTime": 1632197586.4304113, "EndTime": 1632197586.4304204, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 5}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.00559416226288257, "count": 1, "min": 0.00559416226288257, "max": 0.00559416226288257}}}
#
# #metrics {"StartTime": 1632197586.4304552, "EndTime": 1632197586.4304643, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 6}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.0055170558129236024, "count": 1, "min": 0.0055170558129236024, "max": 0.0055170558129236024}}}
#
# #metrics {"StartTime": 1632197586.430499, "EndTime": 1632197586.4305074, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 7}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.0055664076106295216, "count": 1, "min": 0.0055664076106295216, "max": 0.0055664076106295216}}}
#
# #metrics {"StartTime": 1632197586.4305406, "EndTime": 1632197586.4305482, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 8}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.017040394183978364, "count": 1, "min": 0.017040394183978364, "max": 0.017040394183978364}}}
#
# #metrics {"StartTime": 1632197586.4305751, "EndTime": 1632197586.4305825, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 9}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.015086053429536485, "count": 1, "min": 0.015086053429536485, "max": 0.015086053429536485}}}
#
# #metrics {"StartTime": 1632197586.4306078, "EndTime": 1632197586.4306157, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 10}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.017052275439602645, "count": 1, "min": 0.017052275439602645, "max": 0.017052275439602645}}}
#
# #metrics {"StartTime": 1632197586.4306412, "EndTime": 1632197586.4306488, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 11}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.015078011933882631, "count": 1, "min": 0.015078011933882631, "max": 0.015078011933882631}}}
#
# #metrics {"StartTime": 1632197586.4306755, "EndTime": 1632197586.4306831, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 12}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.005623061836963922, "count": 1, "min": 0.005623061836963922, "max": 0.005623061836963922}}}
#
# #metrics {"StartTime": 1632197586.430708, "EndTime": 1632197586.4307153, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 13}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.005685889038383661, "count": 1, "min": 0.005685889038383661, "max": 0.005685889038383661}}}
#
# #metrics {"StartTime": 1632197586.4307482, "EndTime": 1632197586.4307563, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 14}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.005619973801525693, "count": 1, "min": 0.005619973801525693, "max": 0.005619973801525693}}}
#
# #metrics {"StartTime": 1632197586.4307904, "EndTime": 1632197586.4307985, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 15}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.005672148282429082, "count": 1, "min": 0.005672148282429082, "max": 0.005672148282429082}}}
#
# #metrics {"StartTime": 1632197586.4308321, "EndTime": 1632197586.4308426, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 16}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.021269874167801746, "count": 1, "min": 0.021269874167801746, "max": 0.021269874167801746}}}
#
# #metrics {"StartTime": 1632197586.430901, "EndTime": 1632197586.4309177, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 17}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.019476390371370556, "count": 1, "min": 0.019476390371370556, "max": 0.019476390371370556}}}
#
# #metrics {"StartTime": 1632197586.4309804, "EndTime": 1632197586.4309964, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 18}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.021271081124118824, "count": 1, "min": 0.021271081124118824, "max": 0.021271081124118824}}}
#
# #metrics {"StartTime": 1632197586.4310558, "EndTime": 1632197586.43107, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 19}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.019488520303563257, "count": 1, "min": 0.019488520303563257, "max": 0.019488520303563257}}}
#
# #metrics {"StartTime": 1632197586.4311275, "EndTime": 1632197586.4311414, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 20}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.012074755961421746, "count": 1, "min": 0.012074755961421746, "max": 0.012074755961421746}}}
#
# #metrics {"StartTime": 1632197586.431196, "EndTime": 1632197586.4312088, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 21}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.012111119677822793, "count": 1, "min": 0.012111119677822793, "max": 0.012111119677822793}}}
#
# #metrics {"StartTime": 1632197586.431263, "EndTime": 1632197586.4312782, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 22}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.012079157429274602, "count": 1, "min": 0.012079157429274602, "max": 0.012079157429274602}}}
#
# #metrics {"StartTime": 1632197586.4313416, "EndTime": 1632197586.4313571, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 23}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.012108201941503352, "count": 1, "min": 0.012108201941503352, "max": 0.012108201941503352}}}
#
# #metrics {"StartTime": 1632197586.431418, "EndTime": 1632197586.431432, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 24}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.02229813467677514, "count": 1, "min": 0.02229813467677514, "max": 0.02229813467677514}}}
#
# #metrics {"StartTime": 1632197586.4314854, "EndTime": 1632197586.4314952, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 25}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.020528923723565875, "count": 1, "min": 0.020528923723565875, "max": 0.020528923723565875}}}
#
# #metrics {"StartTime": 1632197586.431523, "EndTime": 1632197586.4315307, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 26}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.02230176045307562, "count": 1, "min": 0.02230176045307562, "max": 0.02230176045307562}}}
#
# #metrics {"StartTime": 1632197586.431559, "EndTime": 1632197586.4315665, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 27}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.020534939849796006, "count": 1, "min": 0.020534939849796006, "max": 0.020534939849796006}}}
#
# #metrics {"StartTime": 1632197586.4315994, "EndTime": 1632197586.4316075, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 28}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.013144132435321807, "count": 1, "min": 0.013144132435321807, "max": 0.013144132435321807}}}
#
# #metrics {"StartTime": 1632197586.4316347, "EndTime": 1632197586.431642, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 29}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.013147845989196145, "count": 1, "min": 0.013147845989196145, "max": 0.013147845989196145}}}
#
# #metrics {"StartTime": 1632197586.431675, "EndTime": 1632197586.431683, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 30}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.013144269544575083, "count": 1, "min": 0.013144269544575083, "max": 0.013144269544575083}}}
#
# #metrics {"StartTime": 1632197586.4317148, "EndTime": 1632197586.4317222, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 31}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.013148174451823211, "count": 1, "min": 0.013148174451823211, "max": 0.013148174451823211}}}
#
# [09/21/2021 04:13:06 INFO 140286115153728] #quality_metric: host=algo-1, epoch=1, train binary_classification_cross_entropy_objective <loss>=0.016883339488925647
# [09/21/2021 04:13:06 INFO 140286115153728] #early_stopping_criteria_metric: host=algo-1, epoch=1, criteria=binary_classification_cross_entropy_objective, value=0.005409128546864543
# [09/21/2021 04:13:06 INFO 140286115153728] Epoch 1: Loss improved. Updating best model
# [09/21/2021 04:13:06 INFO 140286115153728] Saving model for epoch: 1
# [09/21/2021 04:13:06 INFO 140286115153728] Saved checkpoint to "/tmp/tmprraojyex/mx-mod-0000.params"
# [09/21/2021 04:13:06 INFO 140286115153728] #progress_metric: host=algo-1, completed 13.333333333333334 % of epochs
# #metrics {"StartTime": 1632197555.7312493, "EndTime": 1632197586.4471874, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 410728.0, "count": 1, "min": 410728, "max": 410728}, "Total Batches Seen": {"sum": 412.0, "count": 1, "min": 412, "max": 412}, "Max Records Seen Between Resets": {"sum": 199364.0, "count": 1, "min": 199364, "max": 199364}, "Max Batches Seen Between Resets": {"sum": 200.0, "count": 1, "min": 200, "max": 200}, "Reset Count": {"sum": 4.0, "count": 1, "min": 4, "max": 4}, "Number of Records Since Last Reset": {"sum": 199364.0, "count": 1, "min": 199364, "max": 199364}, "Number of Batches Since Last Reset": {"sum": 200.0, "count": 1, "min": 200, "max": 200}}}
#
# [09/21/2021 04:13:06 INFO 140286115153728] #throughput_metric: host=algo-1, train throughput=6490.549681951174 records/second
# [2021-09-21 04:13:37.155] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 7, "duration": 30707, "num_examples": 200, "num_bytes": 33493152}
# #metrics {"StartTime": 1632197617.1553836, "EndTime": 1632197617.155471, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 0}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.010249469649851621, "count": 1, "min": 0.010249469649851621, "max": 0.010249469649851621}}}
#
# #metrics {"StartTime": 1632197617.1555574, "EndTime": 1632197617.155581, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 1}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.008671593240158043, "count": 1, "min": 0.008671593240158043, "max": 0.008671593240158043}}}
#
# #metrics {"StartTime": 1632197617.1556227, "EndTime": 1632197617.1556334, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 2}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.010244106330464233, "count": 1, "min": 0.010244106330464233, "max": 0.010244106330464233}}}
#
# #metrics {"StartTime": 1632197617.1556625, "EndTime": 1632197617.155673, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 3}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.008672056543767152, "count": 1, "min": 0.008672056543767152, "max": 0.008672056543767152}}}
#
# #metrics {"StartTime": 1632197617.1557338, "EndTime": 1632197617.1557448, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 4}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.004918119254049344, "count": 1, "min": 0.004918119254049344, "max": 0.004918119254049344}}}
#
# #metrics {"StartTime": 1632197617.1557932, "EndTime": 1632197617.1558046, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 5}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.0056512911585183, "count": 1, "min": 0.0056512911585183, "max": 0.0056512911585183}}}
#
# #metrics {"StartTime": 1632197617.155834, "EndTime": 1632197617.1558418, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 6}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.004927347601714296, "count": 1, "min": 0.004927347601714296, "max": 0.004927347601714296}}}
#
# #metrics {"StartTime": 1632197617.15587, "EndTime": 1632197617.1558783, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 7}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.005514238939812435, "count": 1, "min": 0.005514238939812435, "max": 0.005514238939812435}}}
#
# #metrics {"StartTime": 1632197617.1559258, "EndTime": 1632197617.155942, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 8}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.010515944311966249, "count": 1, "min": 0.010515944311966249, "max": 0.010515944311966249}}}
#
# #metrics {"StartTime": 1632197617.1559885, "EndTime": 1632197617.1559985, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 9}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.009003221600498986, "count": 1, "min": 0.009003221600498986, "max": 0.009003221600498986}}}
#
# #metrics {"StartTime": 1632197617.156037, "EndTime": 1632197617.1560464, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 10}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.010521823818959183, "count": 1, "min": 0.010521823818959183, "max": 0.010521823818959183}}}
#
# #metrics {"StartTime": 1632197617.1560867, "EndTime": 1632197617.156102, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 11}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.008999886714034344, "count": 1, "min": 0.008999886714034344, "max": 0.008999886714034344}}}
#
# #metrics {"StartTime": 1632197617.1561477, "EndTime": 1632197617.1561577, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 12}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.005593624009708664, "count": 1, "min": 0.005593624009708664, "max": 0.005593624009708664}}}
#
# #metrics {"StartTime": 1632197617.1561952, "EndTime": 1632197617.1562073, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 13}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.005721277655219313, "count": 1, "min": 0.005721277655219313, "max": 0.005721277655219313}}}
#
# #metrics {"StartTime": 1632197617.1562653, "EndTime": 1632197617.156276, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 14}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.0055466306109224735, "count": 1, "min": 0.0055466306109224735, "max": 0.0055466306109224735}}}
#
# #metrics {"StartTime": 1632197617.1563249, "EndTime": 1632197617.1563349, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 15}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.00571299303513975, "count": 1, "min": 0.00571299303513975, "max": 0.00571299303513975}}}
#
# #metrics {"StartTime": 1632197617.156363, "EndTime": 1632197617.1563704, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 16}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.015533093286519075, "count": 1, "min": 0.015533093286519075, "max": 0.015533093286519075}}}
#
# #metrics {"StartTime": 1632197617.1563993, "EndTime": 1632197617.1564095, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 17}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.014290418466730933, "count": 1, "min": 0.014290418466730933, "max": 0.014290418466730933}}}
#
# #metrics {"StartTime": 1632197617.1564589, "EndTime": 1632197617.1564748, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 18}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.015534086321466533, "count": 1, "min": 0.015534086321466533, "max": 0.015534086321466533}}}
#
# #metrics {"StartTime": 1632197617.1565168, "EndTime": 1632197617.1565263, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 19}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.014295967544742565, "count": 1, "min": 0.014295967544742565, "max": 0.014295967544742565}}}
#
# #metrics {"StartTime": 1632197617.1565533, "EndTime": 1632197617.156561, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 20}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.01207214400711371, "count": 1, "min": 0.01207214400711371, "max": 0.01207214400711371}}}
#
# #metrics {"StartTime": 1632197617.1566012, "EndTime": 1632197617.1566167, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 21}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.012130517083346544, "count": 1, "min": 0.012130517083346544, "max": 0.012130517083346544}}}
#
# #metrics {"StartTime": 1632197617.156667, "EndTime": 1632197617.1566768, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 22}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.012072038061504987, "count": 1, "min": 0.012072038061504987, "max": 0.012072038061504987}}}
#
# #metrics {"StartTime": 1632197617.156754, "EndTime": 1632197617.1567655, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 23}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.01212600906410409, "count": 1, "min": 0.01212600906410409, "max": 0.01212600906410409}}}
#
# #metrics {"StartTime": 1632197617.156796, "EndTime": 1632197617.1568038, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 24}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.016575735966763903, "count": 1, "min": 0.016575735966763903, "max": 0.016575735966763903}}}
#
# #metrics {"StartTime": 1632197617.1568491, "EndTime": 1632197617.1568654, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 25}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.015361840303818784, "count": 1, "min": 0.015361840303818784, "max": 0.015361840303818784}}}
#
# #metrics {"StartTime": 1632197617.1569057, "EndTime": 1632197617.1569152, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 26}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.0165775283934483, "count": 1, "min": 0.0165775283934483, "max": 0.0165775283934483}}}
#
# #metrics {"StartTime": 1632197617.1569421, "EndTime": 1632197617.15695, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 27}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.015363927146298202, "count": 1, "min": 0.015363927146298202, "max": 0.015363927146298202}}}
#
# #metrics {"StartTime": 1632197617.1569808, "EndTime": 1632197617.1569963, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 28}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.013144806534351416, "count": 1, "min": 0.013144806534351416, "max": 0.013144806534351416}}}
#
# #metrics {"StartTime": 1632197617.157049, "EndTime": 1632197617.157059, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 29}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.013156181953959728, "count": 1, "min": 0.013156181953959728, "max": 0.013156181953959728}}}
#
# #metrics {"StartTime": 1632197617.1571069, "EndTime": 1632197617.1571171, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 30}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.013145586853350827, "count": 1, "min": 0.013145586853350827, "max": 0.013145586853350827}}}
#
# #metrics {"StartTime": 1632197617.1571453, "EndTime": 1632197617.1571531, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 31}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.013155478202068626, "count": 1, "min": 0.013155478202068626, "max": 0.013155478202068626}}}
#
# [09/21/2021 04:13:37 INFO 140286115153728] #quality_metric: host=algo-1, epoch=2, train binary_classification_cross_entropy_objective <loss>=0.010249469649851621
# [09/21/2021 04:13:37 INFO 140286115153728] #early_stopping_criteria_metric: host=algo-1, epoch=2, criteria=binary_classification_cross_entropy_objective, value=0.004918119254049344
# [09/21/2021 04:13:37 INFO 140286115153728] Epoch 2: Loss improved. Updating best model
# [09/21/2021 04:13:37 INFO 140286115153728] Saving model for epoch: 2
# [09/21/2021 04:13:37 INFO 140286115153728] Saved checkpoint to "/tmp/tmpiweiyh_b/mx-mod-0000.params"
# [09/21/2021 04:13:37 INFO 140286115153728] #progress_metric: host=algo-1, completed 20.0 % of epochs
# #metrics {"StartTime": 1632197586.4474077, "EndTime": 1632197617.1734388, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 610092.0, "count": 1, "min": 610092, "max": 610092}, "Total Batches Seen": {"sum": 612.0, "count": 1, "min": 612, "max": 612}, "Max Records Seen Between Resets": {"sum": 199364.0, "count": 1, "min": 199364, "max": 199364}, "Max Batches Seen Between Resets": {"sum": 200.0, "count": 1, "min": 200, "max": 200}, "Reset Count": {"sum": 5.0, "count": 1, "min": 5, "max": 5}, "Number of Records Since Last Reset": {"sum": 199364.0, "count": 1, "min": 199364, "max": 199364}, "Number of Batches Since Last Reset": {"sum": 200.0, "count": 1, "min": 200, "max": 200}}}
#
# [09/21/2021 04:13:37 INFO 140286115153728] #throughput_metric: host=algo-1, train throughput=6488.41624534749 records/second
# [2021-09-21 04:14:08.014] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 9, "duration": 30840, "num_examples": 200, "num_bytes": 33493152}
# #metrics {"StartTime": 1632197648.0146713, "EndTime": 1632197648.0147336, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 0}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.007960710554266694, "count": 1, "min": 0.007960710554266694, "max": 0.007960710554266694}}}
#
# #metrics {"StartTime": 1632197648.0148118, "EndTime": 1632197648.0148265, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 1}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.006608913767876937, "count": 1, "min": 0.006608913767876937, "max": 0.006608913767876937}}}
#
# #metrics {"StartTime": 1632197648.0148623, "EndTime": 1632197648.0148718, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 2}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.007957083736232776, "count": 1, "min": 0.007957083736232776, "max": 0.007957083736232776}}}
#
# ...
#
# #metrics {"StartTime": 1632197986.7499435, "EndTime": 1632197986.7499526, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 3}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.004135193807620499, "count": 1, "min": 0.004135193807620499, "max": 0.004135193807620499}}}
#
# #metrics {"StartTime": 1632197986.749985, "EndTime": 1632197986.7499928, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 4}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.004030334404889663, "count": 1, "min": 0.004030334404889663, "max": 0.004030334404889663}}}
#
# #metrics {"StartTime": 1632197986.7500196, "EndTime": 1632197986.7500274, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 5}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.005396836533374972, "count": 1, "min": 0.005396836533374972, "max": 0.005396836533374972}}}
#
# #metrics {"StartTime": 1632197986.7500613, "EndTime": 1632197986.7500699, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 6}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.004042779862468865, "count": 1, "min": 0.004042779862468865, "max": 0.004042779862468865}}}
#
# #metrics {"StartTime": 1632197986.750102, "EndTime": 1632197986.7501094, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 7}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.0054695692266988095, "count": 1, "min": 0.0054695692266988095, "max": 0.0054695692266988095}}}
#
# #metrics {"StartTime": 1632197986.7501433, "EndTime": 1632197986.7501516, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 8}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.005507124568199992, "count": 1, "min": 0.005507124568199992, "max": 0.005507124568199992}}}
#
# #metrics {"StartTime": 1632197986.7501862, "EndTime": 1632197986.7501948, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 9}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.005093599338702221, "count": 1, "min": 0.005093599338702221, "max": 0.005093599338702221}}}
#
# #metrics {"StartTime": 1632197986.7502213, "EndTime": 1632197986.7502286, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 10}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.005507833578478751, "count": 1, "min": 0.005507833578478751, "max": 0.005507833578478751}}}
#
# #metrics {"StartTime": 1632197986.7502615, "EndTime": 1632197986.75027, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 11}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.005093542188331111, "count": 1, "min": 0.005093542188331111, "max": 0.005093542188331111}}}
#
# #metrics {"StartTime": 1632197986.7503011, "EndTime": 1632197986.7503088, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 12}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.005099071950394304, "count": 1, "min": 0.005099071950394304, "max": 0.005099071950394304}}}
#
# #metrics {"StartTime": 1632197986.750335, "EndTime": 1632197986.7503424, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 13}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.005519994685622915, "count": 1, "min": 0.005519994685622915, "max": 0.005519994685622915}}}
#
# #metrics {"StartTime": 1632197986.7503755, "EndTime": 1632197986.7503836, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 14}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.005098994586860115, "count": 1, "min": 0.005098994586860115, "max": 0.005098994586860115}}}
#
# #metrics {"StartTime": 1632197986.7504182, "EndTime": 1632197986.7504263, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 15}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.005520632763341743, "count": 1, "min": 0.005520632763341743, "max": 0.005520632763341743}}}
#
# #metrics {"StartTime": 1632197986.7504601, "EndTime": 1632197986.7504683, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 16}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.012167769633345867, "count": 1, "min": 0.012167769633345867, "max": 0.012167769633345867}}}
#
# #metrics {"StartTime": 1632197986.7505035, "EndTime": 1632197986.750512, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 17}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.012054018880254659, "count": 1, "min": 0.012054018880254659, "max": 0.012054018880254659}}}
#
# #metrics {"StartTime": 1632197986.750543, "EndTime": 1632197986.7505505, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 18}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.012167777413099854, "count": 1, "min": 0.012167777413099854, "max": 0.012167777413099854}}}
#
# #metrics {"StartTime": 1632197986.750584, "EndTime": 1632197986.750592, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 19}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.012054238668788018, "count": 1, "min": 0.012054238668788018, "max": 0.012054238668788018}}}
#
# #metrics {"StartTime": 1632197986.7506263, "EndTime": 1632197986.7506344, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 20}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.01203998202789369, "count": 1, "min": 0.01203998202789369, "max": 0.01203998202789369}}}
#
# #metrics {"StartTime": 1632197986.7506688, "EndTime": 1632197986.750677, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 21}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.01218919539811024, "count": 1, "min": 0.01218919539811024, "max": 0.01218919539811024}}}
#
# #metrics {"StartTime": 1632197986.7507086, "EndTime": 1632197986.7507162, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 22}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.012040088719309274, "count": 1, "min": 0.012040088719309274, "max": 0.012040088719309274}}}
#
# #metrics {"StartTime": 1632197986.7507493, "EndTime": 1632197986.7507577, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 23}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.012187875734726388, "count": 1, "min": 0.012187875734726388, "max": 0.012187875734726388}}}
#
# #metrics {"StartTime": 1632197986.7507918, "EndTime": 1632197986.7508, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 24}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.013193742042510354, "count": 1, "min": 0.013193742042510354, "max": 0.013193742042510354}}}
#
# #metrics {"StartTime": 1632197986.7508347, "EndTime": 1632197986.7508428, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 25}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.013127850112304017, "count": 1, "min": 0.013127850112304017, "max": 0.013127850112304017}}}
#
# #metrics {"StartTime": 1632197986.7508721, "EndTime": 1632197986.7508795, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 26}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.013193773904637475, "count": 1, "min": 0.013193773904637475, "max": 0.013193773904637475}}}
#
# #metrics {"StartTime": 1632197986.7509122, "EndTime": 1632197986.7509205, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 27}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.013127679182955968, "count": 1, "min": 0.013127679182955968, "max": 0.013127679182955968}}}
#
# #metrics {"StartTime": 1632197986.7509549, "EndTime": 1632197986.750963, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 28}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.013136238540237273, "count": 1, "min": 0.013136238540237273, "max": 0.013136238540237273}}}
#
# #metrics {"StartTime": 1632197986.7509975, "EndTime": 1632197986.751006, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 29}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.013259210552327597, "count": 1, "min": 0.013259210552327597, "max": 0.013259210552327597}}}
#
# #metrics {"StartTime": 1632197986.7510366, "EndTime": 1632197986.751044, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 30}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.013136125199908586, "count": 1, "min": 0.013136125199908586, "max": 0.013136125199908586}}}
#
# #metrics {"StartTime": 1632197986.7510772, "EndTime": 1632197986.7510855, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 31}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.013257810815719504, "count": 1, "min": 0.013257810815719504, "max": 0.013257810815719504}}}
#
# [09/21/2021 04:19:46 INFO 140286115153728] #quality_metric: host=algo-1, epoch=14, train binary_classification_cross_entropy_objective <loss>=0.0047962426988024205
# [09/21/2021 04:19:46 INFO 140286115153728] #early_stopping_criteria_metric: host=algo-1, epoch=14, criteria=binary_classification_cross_entropy_objective, value=0.004030334404889663
# [09/21/2021 04:19:46 INFO 140286115153728] Epoch 14: Loss improved. Updating best model
# [09/21/2021 04:19:46 INFO 140286115153728] Saving model for epoch: 14
# [09/21/2021 04:19:46 INFO 140286115153728] Saved checkpoint to "/tmp/tmpmwf7y75z/mx-mod-0000.params"
# [09/21/2021 04:19:46 INFO 140286115153728] #progress_metric: host=algo-1, completed 100.0 % of epochs
# #metrics {"StartTime": 1632197955.9322832, "EndTime": 1632197986.7670276, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 3002460.0, "count": 1, "min": 3002460, "max": 3002460}, "Total Batches Seen": {"sum": 3012.0, "count": 1, "min": 3012, "max": 3012}, "Max Records Seen Between Resets": {"sum": 199364.0, "count": 1, "min": 199364, "max": 199364}, "Max Batches Seen Between Resets": {"sum": 200.0, "count": 1, "min": 200, "max": 200}, "Reset Count": {"sum": 17.0, "count": 1, "min": 17, "max": 17}, "Number of Records Since Last Reset": {"sum": 199364.0, "count": 1, "min": 199364, "max": 199364}, "Number of Batches Since Last Reset": {"sum": 200.0, "count": 1, "min": 200, "max": 200}}}
#
# [09/21/2021 04:19:46 INFO 140286115153728] #throughput_metric: host=algo-1, train throughput=6465.542009349163 records/second
# [09/21/2021 04:19:46 WARNING 140286115153728] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [09/21/2021 04:19:46 WARNING 140286115153728] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [2021-09-21 04:19:46.771] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 33, "duration": 3, "num_examples": 1, "num_bytes": 168000}
# [2021-09-21 04:19:47.453] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 36, "duration": 679, "num_examples": 200, "num_bytes": 33493152}
# [2021-09-21 04:19:48.649] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 38, "duration": 1123, "num_examples": 200, "num_bytes": 33493152}
# [09/21/2021 04:19:48 INFO 140286115153728] #train_score (algo-1) : ('binary_classification_cross_entropy_objective', 0.003960911900292995)
# [09/21/2021 04:19:48 INFO 140286115153728] #train_score (algo-1) : ('binary_classification_accuracy', 0.9879416544611865)
# [09/21/2021 04:19:48 INFO 140286115153728] #train_score (algo-1) : ('binary_f_1.000', 0.21180327868852458)
# [09/21/2021 04:19:48 INFO 140286115153728] #train_score (algo-1) : ('precision', 0.11994058670627553)
# [09/21/2021 04:19:48 INFO 140286115153728] #train_score (algo-1) : ('recall', 0.9047619047619048)
# [09/21/2021 04:19:48 INFO 140286115153728] #train_score (algo-1) : ('roc_auc_score', 0.9790894283112854)
# [09/21/2021 04:19:48 INFO 140286115153728] #quality_metric: host=algo-1, train binary_classification_cross_entropy_objective <loss>=0.003960911900292995
# [09/21/2021 04:19:48 INFO 140286115153728] #quality_metric: host=algo-1, train binary_classification_accuracy <score>=0.9879416544611865
# [09/21/2021 04:19:48 INFO 140286115153728] #quality_metric: host=algo-1, train binary_f_1.000 <score>=0.21180327868852458
# [09/21/2021 04:19:48 INFO 140286115153728] #quality_metric: host=algo-1, train precision <score>=0.11994058670627553
# [09/21/2021 04:19:48 INFO 140286115153728] #quality_metric: host=algo-1, train recall <score>=0.9047619047619048
# [09/21/2021 04:19:48 INFO 140286115153728] #quality_metric: host=algo-1, train roc_auc_score <score>=0.9790894283112854
# [09/21/2021 04:19:48 INFO 140286115153728] Best model found for hyperparameters: {"optimizer": "adam", "learning_rate": 0.1, "wd": 0.0001, "l1": 0.0, "lr_scheduler_step": 10, "lr_scheduler_factor": 0.99, "lr_scheduler_minimum_lr": 1e-05}
# [09/21/2021 04:19:48 INFO 140286115153728] Saved checkpoint to "/tmp/tmplw0cmbdd/mx-mod-0000.params"
# [09/21/2021 04:19:48 INFO 140286115153728] Test data is not provided.
# #metrics {"StartTime": 1632197510.060484, "EndTime": 1632197988.7253954, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training"}, "Metrics": {"initialize.time": {"sum": 14974.69449043274, "count": 1, "min": 14974.69449043274, "max": 14974.69449043274}, "epochs": {"sum": 15.0, "count": 1, "min": 15, "max": 15}, "check_early_stopping.time": {"sum": 15.556097030639648, "count": 15, "min": 0.9481906890869141, "max": 1.2769699096679688}, "update.time": {"sum": 461680.7436943054, "count": 15, "min": 30602.60033607483, "max": 30900.936603546143}, "finalize.time": {"sum": 1946.4879035949707, "count": 1, "min": 1946.4879035949707, "max": 1946.4879035949707}, "setuptime": {"sum": 23.777484893798828, "count": 1, "min": 23.777484893798828, "max": 23.777484893798828}, "totaltime": {"sum": 478890.0315761566, "count": 1, "min": 478890.0315761566, "max": 478890.0315761566}}}
# 2021-09-21 04:20:02 Uploading - Uploading generated training model
# 2021-09-21 04:20:02 Completed - Training job completed
# Training seconds: 539
# Billable seconds: 539
# CPU times: user 6.05 s, sys: 182 ms, total: 6.23 s
# Wall time: 11min 55s

# %% [markdown]
# ### Deploy and evaluate the tuned estimator
#
# Deploy the tuned predictor and evaluate it.
#
# We hypothesized that a tuned model, optimized for a higher recall, would have fewer false negatives (fraudulent transactions incorrectly labeled as valid); did the number of false negatives get reduced after tuning the model?

# %%
# %%time 
# deploy and create a predictor
recall_predictor = linear_recall.deploy(initial_instance_count=1, 
                                        instance_type='ml.t2.medium')
# Out:
# Defaulting to the only supported framework/algorithm version: 1. Ignoring framework/algorithm version: 1.
# -------------------!CPU times: user 313 ms, sys: 13.7 ms, total: 326 ms
# Wall time: 9min 32s

# %%
print('Metrics for tuned (recall), LinearLearner.\n')

# get metrics for tuned predictor
metrics = evaluate(recall_predictor, 
                   test_features.astype('float32').to_numpy(), 
                   test_labels.astype('float32').to_numpy(), 
                   verbose=True)
# Out:
# Metrics for tuned (recall), LinearLearner.
#
# prediction (col)    0.0  1.0
# actual (row)
# 0.0               84317  991
# 1.0                  20  115
#
# Recall:     0.852
# Precision:  0.104
# Accuracy:   0.988

# %% [markdown]
# ## Delete the endpoint
#
# As always, when you're done evaluating a model, you should delete the endpoint. Below, I'm using the `delete_endpoint` helper function I defined earlier.

# %%
# delete the predictor endpoint 
sagemaker_session.delete_endpoint(recall_predictor.endpoint)
# Out:
# The endpoint attribute has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.

# %% [markdown]
# ---
# ## Improvement: Managing Class Imbalance
#
# We have a model that is tuned to get a higher recall, which aims to reduce the number of false negatives. Earlier, we discussed how class imbalance may actually bias our model towards predicting that all transactions are valid, resulting in higher false negatives and true negatives. It stands to reason that this model could be further improved if we account for this imbalance.
#
# To account for class imbalance during training of a binary classifier, LinearLearner offers the hyperparameter, `positive_example_weight_mult`, which is the weight assigned to positive (1, fraudulent) examples when training a binary classifier. The weight of negative examples (0, valid) is fixed at 1.
#
# ### EXERCISE: Create a LinearLearner with a `positive_example_weight_mult` parameter
#
# In **addition** to tuning a model for higher recall (you may use `linear_recall` as a starting point), you should *add* a parameter that helps account for class imbalance. From the [hyperparameter documentation](https://docs.aws.amazon.com/sagemaker/latest/dg/ll_hyperparameters.html) on `positive_example_weight_mult`, it reads:
# > "If you want the algorithm to choose a weight so that errors in classifying negative vs. positive examples have equal impact on training loss, specify `balanced`."
#
# You could also put in a specific float value, in which case you'd want to weight positive examples more heavily than negative examples, since there are fewer of them.

# %%
# instantiate a LinearLearner

# include params for tuning for higher recall
# *and* account for class imbalance in training data
linear_balanced = LinearLearner(role=role,
                                train_instance_count=1, 
                                train_instance_type='ml.p3.8xlarge',
                                predictor_type='binary_classifier',
                                output_path=output_path,
                                sagemaker_session=sagemaker_session,
                                epochs=15,
                                binary_classifier_model_selection_criteria='precision_at_target_recall',
                                target_recall=0.9,
                                positive_example_weight_mult="balanced")
# Out:
# train_instance_count has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# train_instance_type has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.

# %% [markdown]
# ### EXERCISE: Train the balanced estimator
#
# Fit the new, balanced estimator on the formatted training data.

# %%
# %%time 
# train the estimator on formatted training data
linear_balanced.fit(formatted_train_data)
# Out:
# Defaulting to the only supported framework/algorithm version: 1. Ignoring framework/algorithm version: 1.
# Defaulting to the only supported framework/algorithm version: 1. Ignoring framework/algorithm version: 1.
# 2021-09-21 04:34:59 Starting - Starting the training job...
# 2021-09-21 04:35:22 Starting - Launching requested ML instancesProfilerReport-1632198899: InProgress
# .........
# 2021-09-21 04:36:42 Starting - Preparing the instances for training......
# 2021-09-21 04:37:58 Downloading - Downloading input data
# 2021-09-21 04:37:58 Training - Downloading the training image...
# 2021-09-21 04:38:22 Training - Training image download completed. Training in progress.Docker entrypoint called with argument(s): train
# Running default environment configuration script
# [09/21/2021 04:38:19 INFO 140580980139840] Reading default configuration from /opt/amazon/lib/python3.7/site-packages/algorithm/resources/default-input.json: {'mini_batch_size': '1000', 'epochs': '15', 'feature_dim': 'auto', 'use_bias': 'true', 'binary_classifier_model_selection_criteria': 'accuracy', 'f_beta': '1.0', 'target_recall': '0.8', 'target_precision': '0.8', 'num_models': 'auto', 'num_calibration_samples': '10000000', 'init_method': 'uniform', 'init_scale': '0.07', 'init_sigma': '0.01', 'init_bias': '0.0', 'optimizer': 'auto', 'loss': 'auto', 'margin': '1.0', 'quantile': '0.5', 'loss_insensitivity': '0.01', 'huber_delta': '1.0', 'num_classes': '1', 'accuracy_top_k': '3', 'wd': 'auto', 'l1': 'auto', 'momentum': 'auto', 'learning_rate': 'auto', 'beta_1': 'auto', 'beta_2': 'auto', 'bias_lr_mult': 'auto', 'bias_wd_mult': 'auto', 'use_lr_scheduler': 'true', 'lr_scheduler_step': 'auto', 'lr_scheduler_factor': 'auto', 'lr_scheduler_minimum_lr': 'auto', 'positive_example_weight_mult': '1.0', 'balance_multiclass_weights': 'false', 'normalize_data': 'true', 'normalize_label': 'auto', 'unbias_data': 'auto', 'unbias_label': 'auto', 'num_point_for_scaler': '10000', '_kvstore': 'auto', '_num_gpus': 'auto', '_num_kv_servers': 'auto', '_log_level': 'info', '_tuning_objective_metric': '', 'early_stopping_patience': '3', 'early_stopping_tolerance': '0.001', '_enable_profiler': 'false'}
# [09/21/2021 04:38:19 INFO 140580980139840] Merging with provided configuration from /opt/ml/input/config/hyperparameters.json: {'positive_example_weight_mult': 'balanced', 'feature_dim': '30', 'predictor_type': 'binary_classifier', 'epochs': '15', 'target_recall': '0.9', 'binary_classifier_model_selection_criteria': 'precision_at_target_recall', 'mini_batch_size': '1000'}
# [09/21/2021 04:38:19 INFO 140580980139840] Final configuration: {'mini_batch_size': '1000', 'epochs': '15', 'feature_dim': '30', 'use_bias': 'true', 'binary_classifier_model_selection_criteria': 'precision_at_target_recall', 'f_beta': '1.0', 'target_recall': '0.9', 'target_precision': '0.8', 'num_models': 'auto', 'num_calibration_samples': '10000000', 'init_method': 'uniform', 'init_scale': '0.07', 'init_sigma': '0.01', 'init_bias': '0.0', 'optimizer': 'auto', 'loss': 'auto', 'margin': '1.0', 'quantile': '0.5', 'loss_insensitivity': '0.01', 'huber_delta': '1.0', 'num_classes': '1', 'accuracy_top_k': '3', 'wd': 'auto', 'l1': 'auto', 'momentum': 'auto', 'learning_rate': 'auto', 'beta_1': 'auto', 'beta_2': 'auto', 'bias_lr_mult': 'auto', 'bias_wd_mult': 'auto', 'use_lr_scheduler': 'true', 'lr_scheduler_step': 'auto', 'lr_scheduler_factor': 'auto', 'lr_scheduler_minimum_lr': 'auto', 'positive_example_weight_mult': 'balanced', 'balance_multiclass_weights': 'false', 'normalize_data': 'true', 'normalize_label': 'auto', 'unbias_data': 'auto', 'unbias_label': 'auto', 'num_point_for_scaler': '10000', '_kvstore': 'auto', '_num_gpus': 'auto', '_num_kv_servers': 'auto', '_log_level': 'info', '_tuning_objective_metric': '', 'early_stopping_patience': '3', 'early_stopping_tolerance': '0.001', '_enable_profiler': 'false', 'predictor_type': 'binary_classifier'}
# [09/21/2021 04:38:19 WARNING 140580980139840] Loggers have already been setup.
# Process 1 is a worker.
# [09/21/2021 04:38:19 INFO 140580980139840] Using default worker.
# [09/21/2021 04:38:19 INFO 140580980139840] Checkpoint loading and saving are disabled.
# [2021-09-21 04:38:19.881] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 0, "duration": 20, "num_examples": 1, "num_bytes": 168000}
# [09/21/2021 04:38:19 INFO 140580980139840] Create Store: local
# [2021-09-21 04:38:19.961] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 1, "duration": 78, "num_examples": 11, "num_bytes": 1848000}
# [09/21/2021 04:38:19 INFO 140580980139840] Scaler algorithm parameters
#  <algorithm.scaler.ScalerAlgorithmStable object at 0x7fdb02075f10>
# [09/21/2021 04:38:19 INFO 140580980139840] Scaling model computed with parameters:
#  {'stdev_label': None, 'stdev_weight':
# [4.7823008e+04 1.8987731e+00 1.5821997e+00 1.5291911e+00 1.4364978e+00
#  1.3388461e+00 1.2955806e+00 1.1771069e+00 1.2127448e+00 1.0843055e+00
#  1.0475702e+00 1.0230465e+00 1.0090139e+00 1.0057642e+00 9.5122164e-01
#  9.2613727e-01 8.7072927e-01 8.6057234e-01 8.3151484e-01 8.2762748e-01
#  7.1313608e-01 7.3347980e-01 7.2524083e-01 5.6213826e-01 6.0201687e-01
#  5.1174247e-01 4.8000538e-01 3.7595215e-01 2.7081874e-01 2.3656270e+02]
# <NDArray 30 @cpu(0)>, 'mean_label': None, 'mean_weight':
# [ 9.4275984e+04 -1.7378727e-02  1.5538026e-02  2.5005125e-02
#   3.3166975e-02  1.8197566e-02  1.7799012e-03  6.9396999e-03
#   9.8540336e-03 -3.0757964e-02 -1.2736557e-02  4.0434714e-04
#  -1.4243029e-02  1.6704608e-02  2.2619881e-02 -9.6982103e-03
#  -4.7834702e-03 -1.6767335e-04 -9.0120723e-03 -3.0407687e-03
#   4.6031545e-03 -4.0078526e-03 -1.2586080e-04  1.2784966e-03
#   3.7617318e-03 -3.1254767e-03 -8.2200055e-04  3.4045519e-03
#  -1.0332187e-03  8.7559837e+01]
# <NDArray 30 @cpu(0)>}
# [09/21/2021 04:38:20 INFO 140580980139840] nvidia-smi: took 0.108 seconds to run.
# [09/21/2021 04:38:20 INFO 140580980139840] nvidia-smi identified 4 GPUs.
# [09/21/2021 04:38:20 INFO 140580980139840] Number of GPUs being used: 4
# #metrics {"StartTime": 1632199115.2750585, "EndTime": 1632199115.2750976, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "Meta": "init_train_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 12000.0, "count": 1, "min": 12000, "max": 12000}, "Total Batches Seen": {"sum": 12.0, "count": 1, "min": 12, "max": 12}, "Max Records Seen Between Resets": {"sum": 11000.0, "count": 1, "min": 11000, "max": 11000}, "Max Batches Seen Between Resets": {"sum": 11.0, "count": 1, "min": 11, "max": 11}, "Reset Count": {"sum": 2.0, "count": 1, "min": 2, "max": 2}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
#
# [2021-09-21 04:39:08.621] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 3, "duration": 33344, "num_examples": 200, "num_bytes": 33493152}
# #metrics {"StartTime": 1632199148.6214845, "EndTime": 1632199148.6215632, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 0}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.5791407192747796, "count": 1, "min": 0.5791407192747796, "max": 0.5791407192747796}}}
#
# #metrics {"StartTime": 1632199148.6216674, "EndTime": 1632199148.621684, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 1}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.4759549256137867, "count": 1, "min": 0.4759549256137867, "max": 0.4759549256137867}}}
#
# #metrics {"StartTime": 1632199148.6217315, "EndTime": 1632199148.6217425, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 2}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.49483542709733974, "count": 1, "min": 0.49483542709733974, "max": 0.49483542709733974}}}
#
# #metrics {"StartTime": 1632199148.6217763, "EndTime": 1632199148.6217856, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 3}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.5374999543386488, "count": 1, "min": 0.5374999543386488, "max": 0.5374999543386488}}}
#
# #metrics {"StartTime": 1632199148.621816, "EndTime": 1632199148.6218243, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 4}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.6132989762488322, "count": 1, "min": 0.6132989762488322, "max": 0.6132989762488322}}}
#
# #metrics {"StartTime": 1632199148.6218612, "EndTime": 1632199148.6218705, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 5}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.6502422953083288, "count": 1, "min": 0.6502422953083288, "max": 0.6502422953083288}}}
#
# #metrics {"StartTime": 1632199148.621901, "EndTime": 1632199148.6219087, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 6}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.6198759537408101, "count": 1, "min": 0.6198759537408101, "max": 0.6198759537408101}}}
#
# #metrics {"StartTime": 1632199148.6219454, "EndTime": 1632199148.6219542, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 7}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.6427633412255713, "count": 1, "min": 0.6427633412255713, "max": 0.6427633412255713}}}
#
# #metrics {"StartTime": 1632199148.6219857, "EndTime": 1632199148.621994, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 8}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.4923872086606433, "count": 1, "min": 0.4923872086606433, "max": 0.4923872086606433}}}
#
# #metrics {"StartTime": 1632199148.6220303, "EndTime": 1632199148.6220396, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 9}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.5910773383864206, "count": 1, "min": 0.5910773383864206, "max": 0.5910773383864206}}}
#
# #metrics {"StartTime": 1632199148.6220713, "EndTime": 1632199148.6220791, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 10}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.5660034274192312, "count": 1, "min": 0.5660034274192312, "max": 0.5660034274192312}}}
#
# #metrics {"StartTime": 1632199148.622116, "EndTime": 1632199148.6221251, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 11}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.5708667391484706, "count": 1, "min": 0.5708667391484706, "max": 0.5708667391484706}}}
#
# #metrics {"StartTime": 1632199148.6221635, "EndTime": 1632199148.6221724, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 12}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.6031004597793272, "count": 1, "min": 0.6031004597793272, "max": 0.6031004597793272}}}
#
# #metrics {"StartTime": 1632199148.622204, "EndTime": 1632199148.622212, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 13}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.6313092414637906, "count": 1, "min": 0.6313092414637906, "max": 0.6313092414637906}}}
#
# #metrics {"StartTime": 1632199148.6222398, "EndTime": 1632199148.6222475, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 14}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.6069122802348592, "count": 1, "min": 0.6069122802348592, "max": 0.6069122802348592}}}
#
# #metrics {"StartTime": 1632199148.6222835, "EndTime": 1632199148.6222925, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 15}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.6302708693233566, "count": 1, "min": 0.6302708693233566, "max": 0.6302708693233566}}}
#
# #metrics {"StartTime": 1632199148.6223245, "EndTime": 1632199148.6223323, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 16}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.62743599635752, "count": 1, "min": 0.62743599635752, "max": 0.62743599635752}}}
#
# #metrics {"StartTime": 1632199148.6223645, "EndTime": 1632199148.6223724, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 17}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.5127698768922432, "count": 1, "min": 0.5127698768922432, "max": 0.5127698768922432}}}
#
# #metrics {"StartTime": 1632199148.6223998, "EndTime": 1632199148.6224077, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 18}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.5364223178882694, "count": 1, "min": 0.5364223178882694, "max": 0.5364223178882694}}}
#
# #metrics {"StartTime": 1632199148.6224432, "EndTime": 1632199148.6224523, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 19}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.5448161275278983, "count": 1, "min": 0.5448161275278983, "max": 0.5448161275278983}}}
#
# #metrics {"StartTime": 1632199148.622486, "EndTime": 1632199148.6224942, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 20}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.5403329482989095, "count": 1, "min": 0.5403329482989095, "max": 0.5403329482989095}}}
#
# #metrics {"StartTime": 1632199148.6225297, "EndTime": 1632199148.6225388, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 21}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.541313403351223, "count": 1, "min": 0.541313403351223, "max": 0.541313403351223}}}
#
# #metrics {"StartTime": 1632199148.6225677, "EndTime": 1632199148.6225755, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 22}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.5368096341284077, "count": 1, "min": 0.5368096341284077, "max": 0.5368096341284077}}}
#
# #metrics {"StartTime": 1632199148.6226118, "EndTime": 1632199148.6226206, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 23}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.535626786236787, "count": 1, "min": 0.535626786236787, "max": 0.535626786236787}}}
#
# #metrics {"StartTime": 1632199148.6226513, "EndTime": 1632199148.6226597, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 24}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 1.0813574128654135, "count": 1, "min": 1.0813574128654135, "max": 1.0813574128654135}}}
#
# #metrics {"StartTime": 1632199148.622724, "EndTime": 1632199148.6227348, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 25}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 1.0807654675047602, "count": 1, "min": 1.0807654675047602, "max": 1.0807654675047602}}}
#
# #metrics {"StartTime": 1632199148.622766, "EndTime": 1632199148.6227741, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 26}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 1.107846767022981, "count": 1, "min": 1.107846767022981, "max": 1.107846767022981}}}
#
# #metrics {"StartTime": 1632199148.6228018, "EndTime": 1632199148.6228096, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 27}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 1.0852037539841541, "count": 1, "min": 1.0852037539841541, "max": 1.0852037539841541}}}
#
# #metrics {"StartTime": 1632199148.6228385, "EndTime": 1632199148.6228461, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 28}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 1.2230319167381556, "count": 1, "min": 1.2230319167381556, "max": 1.2230319167381556}}}
#
# #metrics {"StartTime": 1632199148.6228826, "EndTime": 1632199148.6228914, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 29}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 1.2402642569997202, "count": 1, "min": 1.2402642569997202, "max": 1.2402642569997202}}}
#
# #metrics {"StartTime": 1632199148.6229293, "EndTime": 1632199148.6229386, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 30}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 1.2185808306746746, "count": 1, "min": 1.2185808306746746, "max": 1.2185808306746746}}}
#
# #metrics {"StartTime": 1632199148.622969, "EndTime": 1632199148.6229773, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 31}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 1.2268015252884907, "count": 1, "min": 1.2268015252884907, "max": 1.2268015252884907}}}
#
# [09/21/2021 04:39:08 INFO 140580980139840] #quality_metric: host=algo-1, epoch=0, train binary_classification_weighted_cross_entropy_objective <loss>=0.5791407192747796
# [09/21/2021 04:39:08 INFO 140580980139840] #early_stopping_criteria_metric: host=algo-1, epoch=0, criteria=binary_classification_weighted_cross_entropy_objective, value=0.4759549256137867
# [09/21/2021 04:39:08 INFO 140580980139840] Epoch 0: Loss improved. Updating best model
# [09/21/2021 04:39:08 INFO 140580980139840] Saving model for epoch: 0
# [09/21/2021 04:39:08 INFO 140580980139840] Saved checkpoint to "/tmp/tmpff3xjkpa/mx-mod-0000.params"
# [09/21/2021 04:39:08 INFO 140580980139840] #progress_metric: host=algo-1, completed 6.666666666666667 % of epochs
# #metrics {"StartTime": 1632199115.2754796, "EndTime": 1632199148.6453848, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 211364.0, "count": 1, "min": 211364, "max": 211364}, "Total Batches Seen": {"sum": 212.0, "count": 1, "min": 212, "max": 212}, "Max Records Seen Between Resets": {"sum": 199364.0, "count": 1, "min": 199364, "max": 199364}, "Max Batches Seen Between Resets": {"sum": 200.0, "count": 1, "min": 200, "max": 200}, "Reset Count": {"sum": 3.0, "count": 1, "min": 3, "max": 3}, "Number of Records Since Last Reset": {"sum": 199364.0, "count": 1, "min": 199364, "max": 199364}, "Number of Batches Since Last Reset": {"sum": 200.0, "count": 1, "min": 200, "max": 200}}}
#
# [09/21/2021 04:39:08 INFO 140580980139840] #throughput_metric: host=algo-1, train throughput=5974.33918826177 records/second
# [2021-09-21 04:39:41.809] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 5, "duration": 33163, "num_examples": 200, "num_bytes": 33493152}
# #metrics {"StartTime": 1632199181.8091202, "EndTime": 1632199181.8091943, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 0}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.37623333197742254, "count": 1, "min": 0.37623333197742254, "max": 0.37623333197742254}}}
#
# #metrics {"StartTime": 1632199181.809306, "EndTime": 1632199181.8093238, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 1}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.34520775269743187, "count": 1, "min": 0.34520775269743187, "max": 0.34520775269743187}}}
#
# #metrics {"StartTime": 1632199181.809384, "EndTime": 1632199181.8094015, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 2}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.3545212235762246, "count": 1, "min": 0.3545212235762246, "max": 0.3545212235762246}}}
#
# #metrics {"StartTime": 1632199181.8094692, "EndTime": 1632199181.809487, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 3}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.3582820484793965, "count": 1, "min": 0.3582820484793965, "max": 0.3582820484793965}}}
#
# #metrics {"StartTime": 1632199181.8095593, "EndTime": 1632199181.8095772, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 4}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.5038555324820417, "count": 1, "min": 0.5038555324820417, "max": 0.5038555324820417}}}
#
# #metrics {"StartTime": 1632199181.8096478, "EndTime": 1632199181.809665, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 5}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.5762883565569643, "count": 1, "min": 0.5762883565569643, "max": 0.5762883565569643}}}
#
# #metrics {"StartTime": 1632199181.8097346, "EndTime": 1632199181.8097522, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 6}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.5095616876683643, "count": 1, "min": 0.5095616876683643, "max": 0.5095616876683643}}}
#
# #metrics {"StartTime": 1632199181.809824, "EndTime": 1632199181.809841, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 7}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.5621733793541415, "count": 1, "min": 0.5621733793541415, "max": 0.5621733793541415}}}
#
# #metrics {"StartTime": 1632199181.8099022, "EndTime": 1632199181.8099144, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 8}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.3560817902531456, "count": 1, "min": 0.3560817902531456, "max": 0.3560817902531456}}}
#
# #metrics {"StartTime": 1632199181.809977, "EndTime": 1632199181.8099935, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 9}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.37639001987208076, "count": 1, "min": 0.37639001987208076, "max": 0.37639001987208076}}}
#
# #metrics {"StartTime": 1632199181.810059, "EndTime": 1632199181.8100753, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 10}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.37347357561121036, "count": 1, "min": 0.37347357561121036, "max": 0.37347357561121036}}}
#
# #metrics {"StartTime": 1632199181.8101447, "EndTime": 1632199181.8101614, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 11}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.3714105776206932, "count": 1, "min": 0.3714105776206932, "max": 0.3714105776206932}}}
#
# #metrics {"StartTime": 1632199181.8102224, "EndTime": 1632199181.8102345, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 12}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.49682515797782784, "count": 1, "min": 0.49682515797782784, "max": 0.49682515797782784}}}
#
# #metrics {"StartTime": 1632199181.8102877, "EndTime": 1632199181.8103027, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 13}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.5793348213368325, "count": 1, "min": 0.5793348213368325, "max": 0.5793348213368325}}}
#
# #metrics {"StartTime": 1632199181.8103683, "EndTime": 1632199181.8103852, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 14}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.5010429393729972, "count": 1, "min": 0.5010429393729972, "max": 0.5010429393729972}}}
#
# #metrics {"StartTime": 1632199181.8104522, "EndTime": 1632199181.8104687, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 15}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.5806286056053699, "count": 1, "min": 0.5806286056053699, "max": 0.5806286056053699}}}
#
# #metrics {"StartTime": 1632199181.8105378, "EndTime": 1632199181.8105555, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 16}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.4595948208756183, "count": 1, "min": 0.4595948208756183, "max": 0.4595948208756183}}}
#
# #metrics {"StartTime": 1632199181.810621, "EndTime": 1632199181.8106375, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 17}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.4522146887467734, "count": 1, "min": 0.4522146887467734, "max": 0.4522146887467734}}}
#
# #metrics {"StartTime": 1632199181.8107243, "EndTime": 1632199181.8107424, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 18}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.45107530821987135, "count": 1, "min": 0.45107530821987135, "max": 0.45107530821987135}}}
#
# #metrics {"StartTime": 1632199181.8108094, "EndTime": 1632199181.8108268, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 19}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.45293790970615405, "count": 1, "min": 0.45293790970615405, "max": 0.45293790970615405}}}
#
# #metrics {"StartTime": 1632199181.810895, "EndTime": 1632199181.8109126, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 20}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.5139886356622131, "count": 1, "min": 0.5139886356622131, "max": 0.5139886356622131}}}
#
# #metrics {"StartTime": 1632199181.8109732, "EndTime": 1632199181.8109841, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 21}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.5301195149637347, "count": 1, "min": 0.5301195149637347, "max": 0.5301195149637347}}}
#
# #metrics {"StartTime": 1632199181.811023, "EndTime": 1632199181.8110328, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 22}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.5141575622199169, "count": 1, "min": 0.5141575622199169, "max": 0.5141575622199169}}}
#
# #metrics {"StartTime": 1632199181.811095, "EndTime": 1632199181.8111117, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 23}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.5306000953032144, "count": 1, "min": 0.5306000953032144, "max": 0.5306000953032144}}}
#
# #metrics {"StartTime": 1632199181.8111682, "EndTime": 1632199181.8111784, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 24}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 1.0809531591597514, "count": 1, "min": 1.0809531591597514, "max": 1.0809531591597514}}}
#
# #metrics {"StartTime": 1632199181.811233, "EndTime": 1632199181.8112493, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 25}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 1.080615774298433, "count": 1, "min": 1.080615774298433, "max": 1.080615774298433}}}
#
# #metrics {"StartTime": 1632199181.811318, "EndTime": 1632199181.8113353, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 26}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 1.0811927883972474, "count": 1, "min": 1.0811927883972474, "max": 1.0811927883972474}}}
#
# #metrics {"StartTime": 1632199181.8113902, "EndTime": 1632199181.8114061, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 27}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 1.0806420247063564, "count": 1, "min": 1.0806420247063564, "max": 1.0806420247063564}}}
#
# #metrics {"StartTime": 1632199181.81145, "EndTime": 1632199181.8114595, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 28}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 1.1822309941430786, "count": 1, "min": 1.1822309941430786, "max": 1.1822309941430786}}}
#
# #metrics {"StartTime": 1632199181.811489, "EndTime": 1632199181.8115034, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 29}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 1.2228483868316191, "count": 1, "min": 1.2228483868316191, "max": 1.2228483868316191}}}
#
# #metrics {"StartTime": 1632199181.8115528, "EndTime": 1632199181.8115673, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 30}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 1.1816888784859048, "count": 1, "min": 1.1816888784859048, "max": 1.1816888784859048}}}
#
# #metrics {"StartTime": 1632199181.8116338, "EndTime": 1632199181.8116524, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 31}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 1.2195926845684721, "count": 1, "min": 1.2195926845684721, "max": 1.2195926845684721}}}
#
# [09/21/2021 04:39:41 INFO 140580980139840] #quality_metric: host=algo-1, epoch=1, train binary_classification_weighted_cross_entropy_objective <loss>=0.37623333197742254
# [09/21/2021 04:39:41 INFO 140580980139840] #early_stopping_criteria_metric: host=algo-1, epoch=1, criteria=binary_classification_weighted_cross_entropy_objective, value=0.34520775269743187
# [09/21/2021 04:39:41 INFO 140580980139840] Epoch 1: Loss improved. Updating best model
# [09/21/2021 04:39:41 INFO 140580980139840] Saving model for epoch: 1
# [09/21/2021 04:39:41 INFO 140580980139840] Saved checkpoint to "/tmp/tmp441hnh1l/mx-mod-0000.params"
# [09/21/2021 04:39:41 INFO 140580980139840] #progress_metric: host=algo-1, completed 13.333333333333334 % of epochs
# #metrics {"StartTime": 1632199148.6456351, "EndTime": 1632199181.8294344, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 410728.0, "count": 1, "min": 410728, "max": 410728}, "Total Batches Seen": {"sum": 412.0, "count": 1, "min": 412, "max": 412}, "Max Records Seen Between Resets": {"sum": 199364.0, "count": 1, "min": 199364, "max": 199364}, "Max Batches Seen Between Resets": {"sum": 200.0, "count": 1, "min": 200, "max": 200}, "Reset Count": {"sum": 4.0, "count": 1, "min": 4, "max": 4}, "Number of Records Since Last Reset": {"sum": 199364.0, "count": 1, "min": 199364, "max": 199364}, "Number of Batches Since Last Reset": {"sum": 200.0, "count": 1, "min": 200, "max": 200}}}
#
# [09/21/2021 04:39:41 INFO 140580980139840] #throughput_metric: host=algo-1, train throughput=6007.847400473816 records/second
# [2021-09-21 04:40:14.936] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 7, "duration": 33106, "num_examples": 200, "num_bytes": 33493152}
# #metrics {"StartTime": 1632199214.9366064, "EndTime": 1632199214.9366758, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 0}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.33911492241327484, "count": 1, "min": 0.33911492241327484, "max": 0.33911492241327484}}}
#
# #metrics {"StartTime": 1632199214.9367707, "EndTime": 1632199214.9367857, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 1}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.3195404088101794, "count": 1, "min": 0.3195404088101794, "max": 0.3195404088101794}}}
#
# #metrics {"StartTime": 1632199214.9368312, "EndTime": 1632199214.9368415, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 2}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.326985577396412, "count": 1, "min": 0.326985577396412, "max": 0.326985577396412}}}
#
# #metrics {"StartTime": 1632199214.9368813, "EndTime": 1632199214.9368906, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 3}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.3274032878684039, "count": 1, "min": 0.3274032878684039, "max": 0.3274032878684039}}}
#
# #metrics {"StartTime": 1632199214.9369214, "EndTime": 1632199214.9369295, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 4}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.4777964997105862, "count": 1, "min": 0.4777964997105862, "max": 0.4777964997105862}}}
#
# #metrics {"StartTime": 1632199214.9369578, "EndTime": 1632199214.936966, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 5}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.5906326504981697, "count": 1, "min": 0.5906326504981697, "max": 0.5906326504981697}}}
#
# #metrics {"StartTime": 1632199214.937001, "EndTime": 1632199214.9370096, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 6}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.4825325806823807, "count": 1, "min": 0.4825325806823807, "max": 0.4825325806823807}}}
#
# #metrics {"StartTime": 1632199214.937039, "EndTime": 1632199214.9370465, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 7}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.6031271131775487, "count": 1, "min": 0.6031271131775487, "max": 0.6031271131775487}}}
#
# #metrics {"StartTime": 1632199214.937073, "EndTime": 1632199214.9370804, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 8}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.3290663220295355, "count": 1, "min": 0.3290663220295355, "max": 0.3290663220295355}}}
#
# #metrics {"StartTime": 1632199214.9371145, "EndTime": 1632199214.937123, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 9}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.33843335055825696, "count": 1, "min": 0.33843335055825696, "max": 0.33843335055825696}}}
#
# #metrics {"StartTime": 1632199214.9371545, "EndTime": 1632199214.9371622, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 10}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.339534029984594, "count": 1, "min": 0.339534029984594, "max": 0.339534029984594}}}
#
# #metrics {"StartTime": 1632199214.937188, "EndTime": 1632199214.9371953, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 11}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.3347382452308233, "count": 1, "min": 0.3347382452308233, "max": 0.3347382452308233}}}
#
# #metrics {"StartTime": 1632199214.9372294, "EndTime": 1632199214.937238, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 12}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.4336978731263223, "count": 1, "min": 0.4336978731263223, "max": 0.4336978731263223}}}
#
# #metrics {"StartTime": 1632199214.9372668, "EndTime": 1632199214.9372745, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 13}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.5582932576258578, "count": 1, "min": 0.5582932576258578, "max": 0.5582932576258578}}}
#
# #metrics {"StartTime": 1632199214.937301, "EndTime": 1632199214.9373083, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 14}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.4099244736283269, "count": 1, "min": 0.4099244736283269, "max": 0.4099244736283269}}}
#
# #metrics {"StartTime": 1632199214.9373348, "EndTime": 1632199214.9373422, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 15}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.5464451009795893, "count": 1, "min": 0.5464451009795893, "max": 0.5464451009795893}}}
#
# #metrics {"StartTime": 1632199214.9373763, "EndTime": 1632199214.9373846, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 16}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.4480129064435336, "count": 1, "min": 0.4480129064435336, "max": 0.4480129064435336}}}
#
# #metrics {"StartTime": 1632199214.9374175, "EndTime": 1632199214.937425, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 17}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.45073129659681466, "count": 1, "min": 0.45073129659681466, "max": 0.45073129659681466}}}
#
# #metrics {"StartTime": 1632199214.9374592, "EndTime": 1632199214.9374678, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 18}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.44716085828848223, "count": 1, "min": 0.44716085828848223, "max": 0.44716085828848223}}}
#
# #metrics {"StartTime": 1632199214.937501, "EndTime": 1632199214.9375083, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 19}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.45064839239455945, "count": 1, "min": 0.45064839239455945, "max": 0.45064839239455945}}}
#
# #metrics {"StartTime": 1632199214.937543, "EndTime": 1632199214.9375513, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 20}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.5034817777902038, "count": 1, "min": 0.5034817777902038, "max": 0.5034817777902038}}}
#
# #metrics {"StartTime": 1632199214.9375832, "EndTime": 1632199214.9375906, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 21}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.5302559567408346, "count": 1, "min": 0.5302559567408346, "max": 0.5302559567408346}}}
#
# #metrics {"StartTime": 1632199214.9376163, "EndTime": 1632199214.9376237, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 22}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.5034230921879486, "count": 1, "min": 0.5034230921879486, "max": 0.5034230921879486}}}
#
# #metrics {"StartTime": 1632199214.9376583, "EndTime": 1632199214.9376671, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 23}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.5318763725865426, "count": 1, "min": 0.5318763725865426, "max": 0.5318763725865426}}}
#
# #metrics {"StartTime": 1632199214.937703, "EndTime": 1632199214.9377117, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 24}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 1.0804852361247768, "count": 1, "min": 1.0804852361247768, "max": 1.0804852361247768}}}
#
# #metrics {"StartTime": 1632199214.9377446, "EndTime": 1632199214.937752, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 25}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 1.0806065441879196, "count": 1, "min": 1.0806065441879196, "max": 1.0806065441879196}}}
#
# #metrics {"StartTime": 1632199214.9377863, "EndTime": 1632199214.937795, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 26}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 1.0803472794959295, "count": 1, "min": 1.0803472794959295, "max": 1.0803472794959295}}}
#
# #metrics {"StartTime": 1632199214.9378304, "EndTime": 1632199214.937839, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 27}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 1.080706813026313, "count": 1, "min": 1.080706813026313, "max": 1.080706813026313}}}
#
# #metrics {"StartTime": 1632199214.9378679, "EndTime": 1632199214.9378753, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 28}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 1.1454150200273523, "count": 1, "min": 1.1454150200273523, "max": 1.1454150200273523}}}
#
# #metrics {"StartTime": 1632199214.9379098, "EndTime": 1632199214.9379182, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 29}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 1.21392916904622, "count": 1, "min": 1.21392916904622, "max": 1.21392916904622}}}
#
# #metrics {"StartTime": 1632199214.9379537, "EndTime": 1632199214.9379623, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 30}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 1.1451639124041226, "count": 1, "min": 1.1451639124041226, "max": 1.1451639124041226}}}
#
# #metrics {"StartTime": 1632199214.9379938, "EndTime": 1632199214.9380014, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 31}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 1.2131926463716594, "count": 1, "min": 1.2131926463716594, "max": 1.2131926463716594}}}
#
# [09/21/2021 04:40:14 INFO 140580980139840] #quality_metric: host=algo-1, epoch=2, train binary_classification_weighted_cross_entropy_objective <loss>=0.33911492241327484
# [09/21/2021 04:40:14 INFO 140580980139840] #early_stopping_criteria_metric: host=algo-1, epoch=2, criteria=binary_classification_weighted_cross_entropy_objective, value=0.3195404088101794
# [09/21/2021 04:40:14 INFO 140580980139840] Epoch 2: Loss improved. Updating best model
# [09/21/2021 04:40:14 INFO 140580980139840] Saving model for epoch: 2
# [09/21/2021 04:40:14 INFO 140580980139840] Saved checkpoint to "/tmp/tmpg9m9a22w/mx-mod-0000.params"
# [09/21/2021 04:40:14 INFO 140580980139840] #progress_metric: host=algo-1, completed 20.0 % of epochs
# #metrics {"StartTime": 1632199181.8297276, "EndTime": 1632199214.9569569, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 610092.0, "count": 1, "min": 610092, "max": 610092}, "Total Batches Seen": {"sum": 612.0, "count": 1, "min": 612, "max": 612}, "Max Records Seen Between Resets": {"sum": 199364.0, "count": 1, "min": 199364, "max": 199364}, "Max Batches Seen Between Resets": {"sum": 200.0, "count": 1, "min": 200, "max": 200}, "Reset Count": {"sum": 5.0, "count": 1, "min": 5, "max": 5}, "Number of Records Since Last Reset": {"sum": 199364.0, "count": 1, "min": 199364, "max": 199364}, "Number of Batches Since Last Reset": {"sum": 200.0, "count": 1, "min": 200, "max": 200}}}
#
# [09/21/2021 04:40:14 INFO 140580980139840] #throughput_metric: host=algo-1, train throughput=6018.109060520868 records/second
# [2021-09-21 04:40:48.196] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 9, "duration": 33238, "num_examples": 200, "num_bytes": 33493152}
# #metrics {"StartTime": 1632199248.1961155, "EndTime": 1632199248.196221, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 0}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.3222659787029477, "count": 1, "min": 0.3222659787029477, "max": 0.3222659787029477}}}
#
# #metrics {"StartTime": 1632199248.1963205, "EndTime": 1632199248.196343, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 1}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.30747335430126094, "count": 1, "min": 0.30747335430126094, "max": 0.30747335430126094}}}
#
# ...
#
# #metrics {"StartTime": 1632199612.6745806, "EndTime": 1632199612.6745894, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 3}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.28635954702080196, "count": 1, "min": 0.28635954702080196, "max": 0.28635954702080196}}}
#
# #metrics {"StartTime": 1632199612.6746228, "EndTime": 1632199612.6746309, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 4}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.2837358742191564, "count": 1, "min": 0.2837358742191564, "max": 0.2837358742191564}}}
#
# #metrics {"StartTime": 1632199612.6746664, "EndTime": 1632199612.6746755, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 5}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.5330788976535126, "count": 1, "min": 0.5330788976535126, "max": 0.5330788976535126}}}
#
# #metrics {"StartTime": 1632199612.6747446, "EndTime": 1632199612.6747541, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 6}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.28378993870624947, "count": 1, "min": 0.28378993870624947, "max": 0.28378993870624947}}}
#
# #metrics {"StartTime": 1632199612.6747825, "EndTime": 1632199612.6747901, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 7}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.47326178480871955, "count": 1, "min": 0.47326178480871955, "max": 0.47326178480871955}}}
#
# #metrics {"StartTime": 1632199612.6748257, "EndTime": 1632199612.6748345, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 8}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.29130650250995577, "count": 1, "min": 0.29130650250995577, "max": 0.29130650250995577}}}
#
# #metrics {"StartTime": 1632199612.6748707, "EndTime": 1632199612.6748796, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 9}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.2911465912536161, "count": 1, "min": 0.2911465912536161, "max": 0.2911465912536161}}}
#
# #metrics {"StartTime": 1632199612.6749074, "EndTime": 1632199612.6749148, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 10}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.2935376149757424, "count": 1, "min": 0.2935376149757424, "max": 0.2935376149757424}}}
#
# #metrics {"StartTime": 1632199612.6749494, "EndTime": 1632199612.6749578, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 11}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.29087950297216675, "count": 1, "min": 0.29087950297216675, "max": 0.29087950297216675}}}
#
# #metrics {"StartTime": 1632199612.6749945, "EndTime": 1632199612.6750028, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 12}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.29149418042532765, "count": 1, "min": 0.29149418042532765, "max": 0.29149418042532765}}}
#
# #metrics {"StartTime": 1632199612.6750393, "EndTime": 1632199612.6750474, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 13}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.48701864726818983, "count": 1, "min": 0.48701864726818983, "max": 0.48701864726818983}}}
#
# #metrics {"StartTime": 1632199612.6750772, "EndTime": 1632199612.6750846, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 14}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.2914134504759132, "count": 1, "min": 0.2914134504759132, "max": 0.2914134504759132}}}
#
# #metrics {"StartTime": 1632199612.6751187, "EndTime": 1632199612.675127, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 15}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.49398932667114026, "count": 1, "min": 0.49398932667114026, "max": 0.49398932667114026}}}
#
# #metrics {"StartTime": 1632199612.675163, "EndTime": 1632199612.6751716, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 16}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.4376009696308692, "count": 1, "min": 0.4376009696308692, "max": 0.4376009696308692}}}
#
# #metrics {"StartTime": 1632199612.6752074, "EndTime": 1632199612.675216, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 17}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.4484181478299088, "count": 1, "min": 0.4484181478299088, "max": 0.4484181478299088}}}
#
# #metrics {"StartTime": 1632199612.675245, "EndTime": 1632199612.6752524, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 18}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.4376271188247144, "count": 1, "min": 0.4376271188247144, "max": 0.4376271188247144}}}
#
# #metrics {"StartTime": 1632199612.6752777, "EndTime": 1632199612.6752853, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 19}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.44841469309437815, "count": 1, "min": 0.44841469309437815, "max": 0.44841469309437815}}}
#
# #metrics {"StartTime": 1632199612.6753159, "EndTime": 1632199612.6753237, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 20}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.45202173284789426, "count": 1, "min": 0.45202173284789426, "max": 0.45202173284789426}}}
#
# #metrics {"StartTime": 1632199612.6753583, "EndTime": 1632199612.6753669, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 21}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.5203195841132696, "count": 1, "min": 0.5203195841132696, "max": 0.5203195841132696}}}
#
# #metrics {"StartTime": 1632199612.6754022, "EndTime": 1632199612.6754107, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 22}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.4520227517362815, "count": 1, "min": 0.4520227517362815, "max": 0.4520227517362815}}}
#
# #metrics {"StartTime": 1632199612.6754382, "EndTime": 1632199612.6754456, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 23}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.5202868016976208, "count": 1, "min": 0.5202868016976208, "max": 0.5202868016976208}}}
#
# #metrics {"StartTime": 1632199612.67548, "EndTime": 1632199612.6754882, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 24}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 1.0734474137656054, "count": 1, "min": 1.0734474137656054, "max": 1.0734474137656054}}}
#
# #metrics {"StartTime": 1632199612.6755157, "EndTime": 1632199612.675523, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 25}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 1.0808105382104616, "count": 1, "min": 1.0808105382104616, "max": 1.0808105382104616}}}
#
# #metrics {"StartTime": 1632199612.6755576, "EndTime": 1632199612.6755662, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 26}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 1.0734464635034302, "count": 1, "min": 1.0734464635034302, "max": 1.0734464635034302}}}
#
# #metrics {"StartTime": 1632199612.6755965, "EndTime": 1632199612.6756039, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 27}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 1.0808158069399734, "count": 1, "min": 1.0808158069399734, "max": 1.0808158069399734}}}
#
# #metrics {"StartTime": 1632199612.6756382, "EndTime": 1632199612.675647, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 28}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 1.081110006284474, "count": 1, "min": 1.081110006284474, "max": 1.081110006284474}}}
#
# #metrics {"StartTime": 1632199612.675674, "EndTime": 1632199612.6756814, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 29}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 1.1788196838992324, "count": 1, "min": 1.1788196838992324, "max": 1.1788196838992324}}}
#
# #metrics {"StartTime": 1632199612.6757064, "EndTime": 1632199612.6757135, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 30}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 1.0811094362268496, "count": 1, "min": 1.0811094362268496, "max": 1.0811094362268496}}}
#
# #metrics {"StartTime": 1632199612.6757436, "EndTime": 1632199612.675751, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 31}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 1.1788132824538342, "count": 1, "min": 1.1788132824538342, "max": 1.1788132824538342}}}
#
# [09/21/2021 04:46:52 INFO 140580980139840] #quality_metric: host=algo-1, epoch=14, train binary_classification_weighted_cross_entropy_objective <loss>=0.2906830832898317
# [09/21/2021 04:46:52 INFO 140580980139840] #early_stopping_criteria_metric: host=algo-1, epoch=14, criteria=binary_classification_weighted_cross_entropy_objective, value=0.2837358742191564
# [09/21/2021 04:46:52 INFO 140580980139840] Epoch 14: Loss improved. Updating best model
# [09/21/2021 04:46:52 INFO 140580980139840] Saving model for epoch: 14
# [09/21/2021 04:46:52 INFO 140580980139840] Saved checkpoint to "/tmp/tmp7994n0cu/mx-mod-0000.params"
# [09/21/2021 04:46:52 INFO 140580980139840] #progress_metric: host=algo-1, completed 100.0 % of epochs
# #metrics {"StartTime": 1632199579.7470322, "EndTime": 1632199612.6936617, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 3002460.0, "count": 1, "min": 3002460, "max": 3002460}, "Total Batches Seen": {"sum": 3012.0, "count": 1, "min": 3012, "max": 3012}, "Max Records Seen Between Resets": {"sum": 199364.0, "count": 1, "min": 199364, "max": 199364}, "Max Batches Seen Between Resets": {"sum": 200.0, "count": 1, "min": 200, "max": 200}, "Reset Count": {"sum": 17.0, "count": 1, "min": 17, "max": 17}, "Number of Records Since Last Reset": {"sum": 199364.0, "count": 1, "min": 199364, "max": 199364}, "Number of Batches Since Last Reset": {"sum": 200.0, "count": 1, "min": 200, "max": 200}}}
#
# [09/21/2021 04:46:52 INFO 140580980139840] #throughput_metric: host=algo-1, train throughput=6051.098844212662 records/second
# [09/21/2021 04:46:52 WARNING 140580980139840] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [09/21/2021 04:46:52 WARNING 140580980139840] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [2021-09-21 04:46:52.698] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 33, "duration": 3, "num_examples": 1, "num_bytes": 168000}
# [2021-09-21 04:46:53.593] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 36, "duration": 892, "num_examples": 200, "num_bytes": 33493152}
# [2021-09-21 04:46:54.977] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 38, "duration": 1312, "num_examples": 200, "num_bytes": 33493152}
# [09/21/2021 04:46:55 INFO 140580980139840] #train_score (algo-1) : ('binary_classification_weighted_cross_entropy_objective', 0.26874823277591836)
# [09/21/2021 04:46:55 INFO 140580980139840] #train_score (algo-1) : ('binary_classification_accuracy', 0.9913173892979675)
# [09/21/2021 04:46:55 INFO 140580980139840] #train_score (algo-1) : ('binary_f_1.000', 0.27177114009255365)
# [09/21/2021 04:46:55 INFO 140580980139840] #train_score (algo-1) : ('precision', 0.1599009900990099)
# [09/21/2021 04:46:55 INFO 140580980139840] #train_score (algo-1) : ('recall', 0.9047619047619048)
# [09/21/2021 04:46:55 INFO 140580980139840] #train_score (algo-1) : ('roc_auc_score', 0.9883345741578928)
# [09/21/2021 04:46:55 INFO 140580980139840] #quality_metric: host=algo-1, train binary_classification_weighted_cross_entropy_objective <loss>=0.26874823277591836
# [09/21/2021 04:46:55 INFO 140580980139840] #quality_metric: host=algo-1, train binary_classification_accuracy <score>=0.9913173892979675
# [09/21/2021 04:46:55 INFO 140580980139840] #quality_metric: host=algo-1, train binary_f_1.000 <score>=0.27177114009255365
# [09/21/2021 04:46:55 INFO 140580980139840] #quality_metric: host=algo-1, train precision <score>=0.1599009900990099
# [09/21/2021 04:46:55 INFO 140580980139840] #quality_metric: host=algo-1, train recall <score>=0.9047619047619048
# [09/21/2021 04:46:55 INFO 140580980139840] #quality_metric: host=algo-1, train roc_auc_score <score>=0.9883345741578928
# [09/21/2021 04:46:55 INFO 140580980139840] Best model found for hyperparameters: {"optimizer": "adam", "learning_rate": 0.1, "wd": 0.0001, "l1": 0.0, "lr_scheduler_step": 10, "lr_scheduler_factor": 0.99, "lr_scheduler_minimum_lr": 1e-05}
# [09/21/2021 04:46:55 INFO 140580980139840] Saved checkpoint to "/tmp/tmpoj9gh01p/mx-mod-0000.params"
# [09/21/2021 04:46:55 INFO 140580980139840] Test data is not provided.
# #metrics {"StartTime": 1632199099.8603423, "EndTime": 1632199615.0741932, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training"}, "Metrics": {"initialize.time": {"sum": 15411.13543510437, "count": 1, "min": 15411.13543510437, "max": 15411.13543510437}, "epochs": {"sum": 15.0, "count": 1, "min": 15, "max": 15}, "check_early_stopping.time": {"sum": 16.24274253845215, "count": 15, "min": 1.026153564453125, "max": 1.2216567993164062}, "update.time": {"sum": 497364.5489215851, "count": 15, "min": 32836.71188354492, "max": 33363.2869720459}, "finalize.time": {"sum": 2346.9319343566895, "count": 1, "min": 2346.9319343566895, "max": 2346.9319343566895}, "setuptime": {"sum": 25.11906623840332, "count": 1, "min": 25.11906623840332, "max": 25.11906623840332}, "totaltime": {"sum": 515430.278301239, "count": 1, "min": 515430.278301239, "max": 515430.278301239}}}
# 2021-09-21 04:47:08 Uploading - Uploading generated training model
# 2021-09-21 04:47:08 Completed - Training job completed
# Training seconds: 572
# Billable seconds: 572
# CPU times: user 1.6 s, sys: 68.7 ms, total: 1.67 s
# Wall time: 12min 20s

# %% [markdown]
# ### EXERCISE: Deploy and evaluate the balanced estimator
#
# Deploy the balanced predictor and evaluate it. Do the results match with your expectations?

# %%
# %%time 
# deploy and create a predictor
balanced_predictor = linear_balanced.deploy(initial_instance_count=1, 
                                        instance_type='ml.t2.medium')
# Out:
# Defaulting to the only supported framework/algorithm version: 1. Ignoring framework/algorithm version: 1.
# -------------

# %%
print('Metrics for balanced, LinearLearner.\n')

# get metrics for balanced predictor
metrics = evaluate(balanced_predictor, 
                   test_features.astype('float32').to_numpy(), 
                   test_labels.astype('float32').to_numpy(), 
                   verbose=True)

# %% [markdown]
# ## Delete the endpoint
#
# When you're done evaluating a model, you should delete the endpoint.

# %%
# delete the predictor endpoint 
sagemaker_session.delete_endpoint(balanced_predictor.endpoint)

# %% [markdown]
# A note on metric variability:
#
# The above model is tuned for the best possible precision with recall fixed at about 90%. The recall is fixed at 90% during training, but may vary when we apply our trained model to a test set of data.

# %% [markdown]
# ---
# ## Model Design
#
# Now that you've seen how to tune and balance a LinearLearner. Create, train and deploy your own model. This exercise is meant to be more open-ended, so that you get practice with the steps involved in designing a model and deploying it.
#
# ### EXERCISE: Train and deploy a LinearLearner with appropriate hyperparameters, according to the given scenario
#
# **Scenario:**
# * A bank has asked you to build a model that optimizes for a good user experience; users should only ever have up to about 15% of their valid transactions flagged as fraudulent.
#
# This requires that you make a design decision: Given the above scenario, what metric (and value) should you aim for during training?
#
# You may assume that performance on a training set will be within about 5-10% of the performance on a test set. For example, if you get 80% on a training set, you can assume that you'll get between about 70-90% accuracy on a test set.
#
# Your final model should account for class imbalance and be appropriately tuned.

# %%
# %%time

# instantiate and train a LinearLearner
from sagemaker import LinearLearner

# include params for tuning for higher precision
# *and* account for class imbalance in training data
linear_specific = LinearLearner(role=role,
                                train_instance_count=1, 
                                train_instance_type='ml.p3.8xlarge',
                                predictor_type='binary_classifier',
                                output_path=output_path,
                                sagemaker_session=sagemaker_session,
                                epochs=15,
                                binary_classifier_model_selection_criteria='recall_at_target_precision',
                                target_precision=0.9,
                                positive_example_weight_mult="balanced")
# Out:
# train_instance_count has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# train_instance_type has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# CPU times: user 598 µs, sys: 4.04 ms, total: 4.64 ms
# Wall time: 3.54 ms

# %%
# %%time
formatted_train_data = linear_specific.record_set(
    train=train_features.astype('float32').to_numpy(),
    labels=train_labels.astype('float32').to_numpy()
)
# train the estimator on formatted training data
linear_specific.fit(formatted_train_data)
# Out:
# Defaulting to the only supported framework/algorithm version: 1. Ignoring framework/algorithm version: 1.
# Defaulting to the only supported framework/algorithm version: 1. Ignoring framework/algorithm version: 1.
# 2021-09-21 05:24:57 Starting - Starting the training job...
# 2021-09-21 05:25:20 Starting - Launching requested ML instancesProfilerReport-1632201897: InProgress
# .........
# 2021-09-21 05:26:50 Starting - Preparing the instances for training.........
# 2021-09-21 05:28:20 Downloading - Downloading input data
# 2021-09-21 05:28:20 Training - Downloading the training image.Docker entrypoint called with argument(s): train
# Running default environment configuration script
# [09/21/2021 05:28:34 INFO 140156943357760] Reading default configuration from /opt/amazon/lib/python3.7/site-packages/algorithm/resources/default-input.json: {'mini_batch_size': '1000', 'epochs': '15', 'feature_dim': 'auto', 'use_bias': 'true', 'binary_classifier_model_selection_criteria': 'accuracy', 'f_beta': '1.0', 'target_recall': '0.8', 'target_precision': '0.8', 'num_models': 'auto', 'num_calibration_samples': '10000000', 'init_method': 'uniform', 'init_scale': '0.07', 'init_sigma': '0.01', 'init_bias': '0.0', 'optimizer': 'auto', 'loss': 'auto', 'margin': '1.0', 'quantile': '0.5', 'loss_insensitivity': '0.01', 'huber_delta': '1.0', 'num_classes': '1', 'accuracy_top_k': '3', 'wd': 'auto', 'l1': 'auto', 'momentum': 'auto', 'learning_rate': 'auto', 'beta_1': 'auto', 'beta_2': 'auto', 'bias_lr_mult': 'auto', 'bias_wd_mult': 'auto', 'use_lr_scheduler': 'true', 'lr_scheduler_step': 'auto', 'lr_scheduler_factor': 'auto', 'lr_scheduler_minimum_lr': 'auto', 'positive_example_weight_mult': '1.0', 'balance_multiclass_weights': 'false', 'normalize_data': 'true', 'normalize_label': 'auto', 'unbias_data': 'auto', 'unbias_label': 'auto', 'num_point_for_scaler': '10000', '_kvstore': 'auto', '_num_gpus': 'auto', '_num_kv_servers': 'auto', '_log_level': 'info', '_tuning_objective_metric': '', 'early_stopping_patience': '3', 'early_stopping_tolerance': '0.001', '_enable_profiler': 'false'}
# [09/21/2021 05:28:34 INFO 140156943357760] Merging with provided configuration from /opt/ml/input/config/hyperparameters.json: {'positive_example_weight_mult': 'balanced', 'feature_dim': '30', 'predictor_type': 'binary_classifier', 'target_precision': '0.9', 'epochs': '15', 'binary_classifier_model_selection_criteria': 'recall_at_target_precision', 'mini_batch_size': '1000'}
# [09/21/2021 05:28:34 INFO 140156943357760] Final configuration: {'mini_batch_size': '1000', 'epochs': '15', 'feature_dim': '30', 'use_bias': 'true', 'binary_classifier_model_selection_criteria': 'recall_at_target_precision', 'f_beta': '1.0', 'target_recall': '0.8', 'target_precision': '0.9', 'num_models': 'auto', 'num_calibration_samples': '10000000', 'init_method': 'uniform', 'init_scale': '0.07', 'init_sigma': '0.01', 'init_bias': '0.0', 'optimizer': 'auto', 'loss': 'auto', 'margin': '1.0', 'quantile': '0.5', 'loss_insensitivity': '0.01', 'huber_delta': '1.0', 'num_classes': '1', 'accuracy_top_k': '3', 'wd': 'auto', 'l1': 'auto', 'momentum': 'auto', 'learning_rate': 'auto', 'beta_1': 'auto', 'beta_2': 'auto', 'bias_lr_mult': 'auto', 'bias_wd_mult': 'auto', 'use_lr_scheduler': 'true', 'lr_scheduler_step': 'auto', 'lr_scheduler_factor': 'auto', 'lr_scheduler_minimum_lr': 'auto', 'positive_example_weight_mult': 'balanced', 'balance_multiclass_weights': 'false', 'normalize_data': 'true', 'normalize_label': 'auto', 'unbias_data': 'auto', 'unbias_label': 'auto', 'num_point_for_scaler': '10000', '_kvstore': 'auto', '_num_gpus': 'auto', '_num_kv_servers': 'auto', '_log_level': 'info', '_tuning_objective_metric': '', 'early_stopping_patience': '3', 'early_stopping_tolerance': '0.001', '_enable_profiler': 'false', 'predictor_type': 'binary_classifier'}
# [09/21/2021 05:28:34 WARNING 140156943357760] Loggers have already been setup.
# Process 1 is a worker.
# [09/21/2021 05:28:34 INFO 140156943357760] Using default worker.
# [09/21/2021 05:28:34 INFO 140156943357760] Checkpoint loading and saving are disabled.
# [2021-09-21 05:28:34.756] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 0, "duration": 25, "num_examples": 1, "num_bytes": 168000}
# [09/21/2021 05:28:34 INFO 140156943357760] Create Store: local
# [2021-09-21 05:28:34.841] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 1, "duration": 84, "num_examples": 11, "num_bytes": 1848000}
# [09/21/2021 05:28:34 INFO 140156943357760] Scaler algorithm parameters
#  <algorithm.scaler.ScalerAlgorithmStable object at 0x7f7881188b10>
# [09/21/2021 05:28:34 INFO 140156943357760] Scaling model computed with parameters:
#  {'stdev_label': None, 'stdev_weight':
# [4.7823008e+04 1.8987731e+00 1.5821997e+00 1.5291911e+00 1.4364978e+00
#  1.3388461e+00 1.2955806e+00 1.1771069e+00 1.2127448e+00 1.0843055e+00
#  1.0475702e+00 1.0230465e+00 1.0090139e+00 1.0057642e+00 9.5122164e-01
#  9.2613727e-01 8.7072927e-01 8.6057234e-01 8.3151484e-01 8.2762748e-01
#  7.1313608e-01 7.3347980e-01 7.2524083e-01 5.6213826e-01 6.0201687e-01
#  5.1174247e-01 4.8000538e-01 3.7595215e-01 2.7081874e-01 2.3656270e+02]
# <NDArray 30 @cpu(0)>, 'mean_label': None, 'mean_weight':
# [ 9.4275984e+04 -1.7378727e-02  1.5538026e-02  2.5005125e-02
#   3.3166975e-02  1.8197566e-02  1.7799012e-03  6.9396999e-03
#   9.8540336e-03 -3.0757964e-02 -1.2736557e-02  4.0434714e-04
#  -1.4243029e-02  1.6704608e-02  2.2619881e-02 -9.6982103e-03
#  -4.7834702e-03 -1.6767335e-04 -9.0120723e-03 -3.0407687e-03
#   4.6031545e-03 -4.0078526e-03 -1.2586080e-04  1.2784966e-03
#   3.7617318e-03 -3.1254767e-03 -8.2200055e-04  3.4045519e-03
#  -1.0332187e-03  8.7559837e+01]
# <NDArray 30 @cpu(0)>}
# [09/21/2021 05:28:34 INFO 140156943357760] nvidia-smi: took 0.082 seconds to run.
# [09/21/2021 05:28:34 INFO 140156943357760] nvidia-smi identified 4 GPUs.
# [09/21/2021 05:28:34 INFO 140156943357760] Number of GPUs being used: 4
#
# 2021-09-21 05:28:40 Training - Training image download completed. Training in progress.#metrics {"StartTime": 1632202130.812903, "EndTime": 1632202130.812947, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "Meta": "init_train_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 12000.0, "count": 1, "min": 12000, "max": 12000}, "Total Batches Seen": {"sum": 12.0, "count": 1, "min": 12, "max": 12}, "Max Records Seen Between Resets": {"sum": 11000.0, "count": 1, "min": 11000, "max": 11000}, "Max Batches Seen Between Resets": {"sum": 11.0, "count": 1, "min": 11, "max": 11}, "Reset Count": {"sum": 2.0, "count": 1, "min": 2, "max": 2}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
#
# [2021-09-21 05:29:23.807] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 3, "duration": 32992, "num_examples": 200, "num_bytes": 33493152}
# #metrics {"StartTime": 1632202163.8080106, "EndTime": 1632202163.808087, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 0}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.5791407192747796, "count": 1, "min": 0.5791407192747796, "max": 0.5791407192747796}}}
#
# #metrics {"StartTime": 1632202163.8081825, "EndTime": 1632202163.8081973, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 1}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.4759549256137867, "count": 1, "min": 0.4759549256137867, "max": 0.4759549256137867}}}
#
# #metrics {"StartTime": 1632202163.808236, "EndTime": 1632202163.8082445, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 2}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.49483542709733974, "count": 1, "min": 0.49483542709733974, "max": 0.49483542709733974}}}
#
# #metrics {"StartTime": 1632202163.808273, "EndTime": 1632202163.8082812, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 3}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.5374999543386488, "count": 1, "min": 0.5374999543386488, "max": 0.5374999543386488}}}
#
# #metrics {"StartTime": 1632202163.8083084, "EndTime": 1632202163.8083165, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 4}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.6132989762488322, "count": 1, "min": 0.6132989762488322, "max": 0.6132989762488322}}}
#
# #metrics {"StartTime": 1632202163.8083444, "EndTime": 1632202163.8083518, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 5}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.6502422953083288, "count": 1, "min": 0.6502422953083288, "max": 0.6502422953083288}}}
#
# #metrics {"StartTime": 1632202163.808377, "EndTime": 1632202163.8083842, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 6}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.6198759537408101, "count": 1, "min": 0.6198759537408101, "max": 0.6198759537408101}}}
#
# #metrics {"StartTime": 1632202163.8084183, "EndTime": 1632202163.8084273, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 7}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.6427633412255713, "count": 1, "min": 0.6427633412255713, "max": 0.6427633412255713}}}
#
# #metrics {"StartTime": 1632202163.8084588, "EndTime": 1632202163.8084662, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 8}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.4923872086606433, "count": 1, "min": 0.4923872086606433, "max": 0.4923872086606433}}}
#
# #metrics {"StartTime": 1632202163.8084912, "EndTime": 1632202163.8084984, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 9}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.5910773383864206, "count": 1, "min": 0.5910773383864206, "max": 0.5910773383864206}}}
#
# #metrics {"StartTime": 1632202163.8085277, "EndTime": 1632202163.8085349, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 10}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.5660034274192312, "count": 1, "min": 0.5660034274192312, "max": 0.5660034274192312}}}
#
# #metrics {"StartTime": 1632202163.80856, "EndTime": 1632202163.8085668, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 11}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.5708667391484706, "count": 1, "min": 0.5708667391484706, "max": 0.5708667391484706}}}
#
# #metrics {"StartTime": 1632202163.8085928, "EndTime": 1632202163.8086007, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 12}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.6031004597793272, "count": 1, "min": 0.6031004597793272, "max": 0.6031004597793272}}}
#
# #metrics {"StartTime": 1632202163.8086295, "EndTime": 1632202163.8086367, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 13}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.6313092414637906, "count": 1, "min": 0.6313092414637906, "max": 0.6313092414637906}}}
#
# #metrics {"StartTime": 1632202163.8086624, "EndTime": 1632202163.8086703, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 14}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.6069122802348592, "count": 1, "min": 0.6069122802348592, "max": 0.6069122802348592}}}
#
# #metrics {"StartTime": 1632202163.8086953, "EndTime": 1632202163.8087025, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 15}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.6302708693233566, "count": 1, "min": 0.6302708693233566, "max": 0.6302708693233566}}}
#
# #metrics {"StartTime": 1632202163.8087282, "EndTime": 1632202163.8087358, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 16}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.62743599635752, "count": 1, "min": 0.62743599635752, "max": 0.62743599635752}}}
#
# #metrics {"StartTime": 1632202163.808774, "EndTime": 1632202163.8087826, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 17}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.5127698768922432, "count": 1, "min": 0.5127698768922432, "max": 0.5127698768922432}}}
#
# #metrics {"StartTime": 1632202163.8088095, "EndTime": 1632202163.8088167, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 18}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.5364223178882694, "count": 1, "min": 0.5364223178882694, "max": 0.5364223178882694}}}
#
# #metrics {"StartTime": 1632202163.8088424, "EndTime": 1632202163.8088503, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 19}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.5448161275278983, "count": 1, "min": 0.5448161275278983, "max": 0.5448161275278983}}}
#
# #metrics {"StartTime": 1632202163.8088763, "EndTime": 1632202163.808884, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 20}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.5403329482989095, "count": 1, "min": 0.5403329482989095, "max": 0.5403329482989095}}}
#
# #metrics {"StartTime": 1632202163.808909, "EndTime": 1632202163.8089163, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 21}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.541313403351223, "count": 1, "min": 0.541313403351223, "max": 0.541313403351223}}}
#
# #metrics {"StartTime": 1632202163.8089411, "EndTime": 1632202163.808948, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 22}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.5368096341284077, "count": 1, "min": 0.5368096341284077, "max": 0.5368096341284077}}}
#
# #metrics {"StartTime": 1632202163.8089817, "EndTime": 1632202163.8089902, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 23}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.535626786236787, "count": 1, "min": 0.535626786236787, "max": 0.535626786236787}}}
#
# #metrics {"StartTime": 1632202163.8090162, "EndTime": 1632202163.8090234, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 24}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 1.0813574128654135, "count": 1, "min": 1.0813574128654135, "max": 1.0813574128654135}}}
#
# #metrics {"StartTime": 1632202163.8090522, "EndTime": 1632202163.8090594, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 25}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 1.0807654675047602, "count": 1, "min": 1.0807654675047602, "max": 1.0807654675047602}}}
#
# #metrics {"StartTime": 1632202163.8090842, "EndTime": 1632202163.809091, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 26}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 1.107846767022981, "count": 1, "min": 1.107846767022981, "max": 1.107846767022981}}}
#
# #metrics {"StartTime": 1632202163.8091166, "EndTime": 1632202163.8091247, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 27}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 1.0852037539841541, "count": 1, "min": 1.0852037539841541, "max": 1.0852037539841541}}}
#
# #metrics {"StartTime": 1632202163.8091583, "EndTime": 1632202163.8091667, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 28}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 1.2230319167381556, "count": 1, "min": 1.2230319167381556, "max": 1.2230319167381556}}}
#
# #metrics {"StartTime": 1632202163.8091946, "EndTime": 1632202163.8092027, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 29}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 1.2402642569997202, "count": 1, "min": 1.2402642569997202, "max": 1.2402642569997202}}}
#
# #metrics {"StartTime": 1632202163.8092275, "EndTime": 1632202163.8092346, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 30}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 1.2185808306746746, "count": 1, "min": 1.2185808306746746, "max": 1.2185808306746746}}}
#
# #metrics {"StartTime": 1632202163.8092592, "EndTime": 1632202163.8092663, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 31}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 1.2268015252884907, "count": 1, "min": 1.2268015252884907, "max": 1.2268015252884907}}}
#
# [09/21/2021 05:29:23 INFO 140156943357760] #quality_metric: host=algo-1, epoch=0, train binary_classification_weighted_cross_entropy_objective <loss>=0.5791407192747796
# [09/21/2021 05:29:23 INFO 140156943357760] #early_stopping_criteria_metric: host=algo-1, epoch=0, criteria=binary_classification_weighted_cross_entropy_objective, value=0.4759549256137867
# [09/21/2021 05:29:23 INFO 140156943357760] Epoch 0: Loss improved. Updating best model
# [09/21/2021 05:29:23 INFO 140156943357760] Saving model for epoch: 0
# [09/21/2021 05:29:23 INFO 140156943357760] Saved checkpoint to "/tmp/tmpw8aliidv/mx-mod-0000.params"
# [09/21/2021 05:29:23 INFO 140156943357760] #progress_metric: host=algo-1, completed 6.666666666666667 % of epochs
# #metrics {"StartTime": 1632202130.813251, "EndTime": 1632202163.8329055, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 211364.0, "count": 1, "min": 211364, "max": 211364}, "Total Batches Seen": {"sum": 212.0, "count": 1, "min": 212, "max": 212}, "Max Records Seen Between Resets": {"sum": 199364.0, "count": 1, "min": 199364, "max": 199364}, "Max Batches Seen Between Resets": {"sum": 200.0, "count": 1, "min": 200, "max": 200}, "Reset Count": {"sum": 3.0, "count": 1, "min": 3, "max": 3}, "Number of Records Since Last Reset": {"sum": 199364.0, "count": 1, "min": 199364, "max": 199364}, "Number of Batches Since Last Reset": {"sum": 200.0, "count": 1, "min": 200, "max": 200}}}
#
# [09/21/2021 05:29:23 INFO 140156943357760] #throughput_metric: host=algo-1, train throughput=6037.718912360457 records/second
# [2021-09-21 05:29:56.946] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 5, "duration": 33113, "num_examples": 200, "num_bytes": 33493152}
# #metrics {"StartTime": 1632202196.946537, "EndTime": 1632202196.9466143, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 0}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.37623333197742254, "count": 1, "min": 0.37623333197742254, "max": 0.37623333197742254}}}
#
# #metrics {"StartTime": 1632202196.9467092, "EndTime": 1632202196.9467242, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 1}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.34520775269743187, "count": 1, "min": 0.34520775269743187, "max": 0.34520775269743187}}}
#
# #metrics {"StartTime": 1632202196.9467611, "EndTime": 1632202196.9467702, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 2}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.3545212235762246, "count": 1, "min": 0.3545212235762246, "max": 0.3545212235762246}}}
#
# #metrics {"StartTime": 1632202196.9468074, "EndTime": 1632202196.9468164, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 3}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.3582820484793965, "count": 1, "min": 0.3582820484793965, "max": 0.3582820484793965}}}
#
# #metrics {"StartTime": 1632202196.9468446, "EndTime": 1632202196.9468527, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 4}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.5038555324820417, "count": 1, "min": 0.5038555324820417, "max": 0.5038555324820417}}}
#
# #metrics {"StartTime": 1632202196.9468822, "EndTime": 1632202196.9468899, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 5}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.5762883565569643, "count": 1, "min": 0.5762883565569643, "max": 0.5762883565569643}}}
#
# #metrics {"StartTime": 1632202196.9469233, "EndTime": 1632202196.9469323, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 6}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.5095616876683643, "count": 1, "min": 0.5095616876683643, "max": 0.5095616876683643}}}
#
# #metrics {"StartTime": 1632202196.9469671, "EndTime": 1632202196.9469755, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 7}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.5621733793541415, "count": 1, "min": 0.5621733793541415, "max": 0.5621733793541415}}}
#
# #metrics {"StartTime": 1632202196.9470024, "EndTime": 1632202196.94701, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 8}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.3560817902531456, "count": 1, "min": 0.3560817902531456, "max": 0.3560817902531456}}}
#
# #metrics {"StartTime": 1632202196.9470427, "EndTime": 1632202196.9470518, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 9}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.37639001987208076, "count": 1, "min": 0.37639001987208076, "max": 0.37639001987208076}}}
#
# #metrics {"StartTime": 1632202196.9470792, "EndTime": 1632202196.9470868, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 10}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.37347357561121036, "count": 1, "min": 0.37347357561121036, "max": 0.37347357561121036}}}
#
# #metrics {"StartTime": 1632202196.9471118, "EndTime": 1632202196.9471195, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 11}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.3714105776206932, "count": 1, "min": 0.3714105776206932, "max": 0.3714105776206932}}}
#
# #metrics {"StartTime": 1632202196.947155, "EndTime": 1632202196.9471638, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 12}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.49682515797782784, "count": 1, "min": 0.49682515797782784, "max": 0.49682515797782784}}}
#
# #metrics {"StartTime": 1632202196.9471986, "EndTime": 1632202196.9472077, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 13}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.5793348213368325, "count": 1, "min": 0.5793348213368325, "max": 0.5793348213368325}}}
#
# #metrics {"StartTime": 1632202196.947241, "EndTime": 1632202196.9472487, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 14}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.5010429393729972, "count": 1, "min": 0.5010429393729972, "max": 0.5010429393729972}}}
#
# #metrics {"StartTime": 1632202196.9472818, "EndTime": 1632202196.9472904, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 15}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.5806286056053699, "count": 1, "min": 0.5806286056053699, "max": 0.5806286056053699}}}
#
# #metrics {"StartTime": 1632202196.9473252, "EndTime": 1632202196.9473338, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 16}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.4595948208756183, "count": 1, "min": 0.4595948208756183, "max": 0.4595948208756183}}}
#
# #metrics {"StartTime": 1632202196.947392, "EndTime": 1632202196.9474082, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 17}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.4522146887467734, "count": 1, "min": 0.4522146887467734, "max": 0.4522146887467734}}}
#
# #metrics {"StartTime": 1632202196.9474745, "EndTime": 1632202196.9474914, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 18}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.45107530821987135, "count": 1, "min": 0.45107530821987135, "max": 0.45107530821987135}}}
#
# #metrics {"StartTime": 1632202196.9475546, "EndTime": 1632202196.9475722, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 19}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.45293790970615405, "count": 1, "min": 0.45293790970615405, "max": 0.45293790970615405}}}
#
# #metrics {"StartTime": 1632202196.947635, "EndTime": 1632202196.947651, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 20}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.5139886356622131, "count": 1, "min": 0.5139886356622131, "max": 0.5139886356622131}}}
#
# #metrics {"StartTime": 1632202196.9477153, "EndTime": 1632202196.9477317, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 21}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.5301195149637347, "count": 1, "min": 0.5301195149637347, "max": 0.5301195149637347}}}
#
# #metrics {"StartTime": 1632202196.9477923, "EndTime": 1632202196.9478028, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 22}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.5141575622199169, "count": 1, "min": 0.5141575622199169, "max": 0.5141575622199169}}}
#
# #metrics {"StartTime": 1632202196.9478323, "EndTime": 1632202196.9478402, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 23}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.5306000953032144, "count": 1, "min": 0.5306000953032144, "max": 0.5306000953032144}}}
#
# #metrics {"StartTime": 1632202196.9478667, "EndTime": 1632202196.9478738, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 24}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 1.0809531591597514, "count": 1, "min": 1.0809531591597514, "max": 1.0809531591597514}}}
#
# #metrics {"StartTime": 1632202196.9479017, "EndTime": 1632202196.947909, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 25}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 1.080615774298433, "count": 1, "min": 1.080615774298433, "max": 1.080615774298433}}}
#
# #metrics {"StartTime": 1632202196.9479337, "EndTime": 1632202196.9479408, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 26}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 1.0811927883972474, "count": 1, "min": 1.0811927883972474, "max": 1.0811927883972474}}}
#
# #metrics {"StartTime": 1632202196.9479692, "EndTime": 1632202196.9479766, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 27}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 1.0806420247063564, "count": 1, "min": 1.0806420247063564, "max": 1.0806420247063564}}}
#
# #metrics {"StartTime": 1632202196.948003, "EndTime": 1632202196.9480102, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 28}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 1.1822309941430786, "count": 1, "min": 1.1822309941430786, "max": 1.1822309941430786}}}
#
# #metrics {"StartTime": 1632202196.9480364, "EndTime": 1632202196.9480438, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 29}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 1.2228483868316191, "count": 1, "min": 1.2228483868316191, "max": 1.2228483868316191}}}
#
# #metrics {"StartTime": 1632202196.9480689, "EndTime": 1632202196.948076, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 30}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 1.1816888784859048, "count": 1, "min": 1.1816888784859048, "max": 1.1816888784859048}}}
#
# #metrics {"StartTime": 1632202196.94811, "EndTime": 1632202196.9481184, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 31}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 1.2195926845684721, "count": 1, "min": 1.2195926845684721, "max": 1.2195926845684721}}}
#
# [09/21/2021 05:29:56 INFO 140156943357760] #quality_metric: host=algo-1, epoch=1, train binary_classification_weighted_cross_entropy_objective <loss>=0.37623333197742254
# [09/21/2021 05:29:56 INFO 140156943357760] #early_stopping_criteria_metric: host=algo-1, epoch=1, criteria=binary_classification_weighted_cross_entropy_objective, value=0.34520775269743187
# [09/21/2021 05:29:56 INFO 140156943357760] Epoch 1: Loss improved. Updating best model
# [09/21/2021 05:29:56 INFO 140156943357760] Saving model for epoch: 1
# [09/21/2021 05:29:56 INFO 140156943357760] Saved checkpoint to "/tmp/tmpgo1wtzl2/mx-mod-0000.params"
# [09/21/2021 05:29:56 INFO 140156943357760] #progress_metric: host=algo-1, completed 13.333333333333334 % of epochs
# #metrics {"StartTime": 1632202163.8331382, "EndTime": 1632202196.967621, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 410728.0, "count": 1, "min": 410728, "max": 410728}, "Total Batches Seen": {"sum": 412.0, "count": 1, "min": 412, "max": 412}, "Max Records Seen Between Resets": {"sum": 199364.0, "count": 1, "min": 199364, "max": 199364}, "Max Batches Seen Between Resets": {"sum": 200.0, "count": 1, "min": 200, "max": 200}, "Reset Count": {"sum": 4.0, "count": 1, "min": 4, "max": 4}, "Number of Records Since Last Reset": {"sum": 199364.0, "count": 1, "min": 199364, "max": 199364}, "Number of Batches Since Last Reset": {"sum": 200.0, "count": 1, "min": 200, "max": 200}}}
#
# [09/21/2021 05:29:56 INFO 140156943357760] #throughput_metric: host=algo-1, train throughput=6016.793860115029 records/second
# [2021-09-21 05:30:29.724] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 7, "duration": 32756, "num_examples": 200, "num_bytes": 33493152}
# #metrics {"StartTime": 1632202229.7248402, "EndTime": 1632202229.7249122, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 0}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.33911492241327484, "count": 1, "min": 0.33911492241327484, "max": 0.33911492241327484}}}
#
# #metrics {"StartTime": 1632202229.725002, "EndTime": 1632202229.7250166, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 1}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.3195404088101794, "count": 1, "min": 0.3195404088101794, "max": 0.3195404088101794}}}
#
# #metrics {"StartTime": 1632202229.7250605, "EndTime": 1632202229.7250705, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 2}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.326985577396412, "count": 1, "min": 0.326985577396412, "max": 0.326985577396412}}}
#
# #metrics {"StartTime": 1632202229.7251065, "EndTime": 1632202229.7251146, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 3}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.3274032878684039, "count": 1, "min": 0.3274032878684039, "max": 0.3274032878684039}}}
#
# #metrics {"StartTime": 1632202229.7251413, "EndTime": 1632202229.725149, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 4}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.4777964997105862, "count": 1, "min": 0.4777964997105862, "max": 0.4777964997105862}}}
#
# #metrics {"StartTime": 1632202229.7251756, "EndTime": 1632202229.7251835, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 5}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.5906326504981697, "count": 1, "min": 0.5906326504981697, "max": 0.5906326504981697}}}
#
# #metrics {"StartTime": 1632202229.7252116, "EndTime": 1632202229.7252195, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 6}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.4825325806823807, "count": 1, "min": 0.4825325806823807, "max": 0.4825325806823807}}}
#
# #metrics {"StartTime": 1632202229.7252543, "EndTime": 1632202229.7252634, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 7}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.6031271131775487, "count": 1, "min": 0.6031271131775487, "max": 0.6031271131775487}}}
#
# #metrics {"StartTime": 1632202229.7252994, "EndTime": 1632202229.7253082, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 8}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.3290663220295355, "count": 1, "min": 0.3290663220295355, "max": 0.3290663220295355}}}
#
# #metrics {"StartTime": 1632202229.7253366, "EndTime": 1632202229.7253444, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 9}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.33843335055825696, "count": 1, "min": 0.33843335055825696, "max": 0.33843335055825696}}}
#
# #metrics {"StartTime": 1632202229.7253716, "EndTime": 1632202229.725379, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 10}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.339534029984594, "count": 1, "min": 0.339534029984594, "max": 0.339534029984594}}}
#
# #metrics {"StartTime": 1632202229.725414, "EndTime": 1632202229.7254229, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 11}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.3347382452308233, "count": 1, "min": 0.3347382452308233, "max": 0.3347382452308233}}}
#
# #metrics {"StartTime": 1632202229.7254586, "EndTime": 1632202229.7254674, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 12}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.4336978731263223, "count": 1, "min": 0.4336978731263223, "max": 0.4336978731263223}}}
#
# #metrics {"StartTime": 1632202229.725496, "EndTime": 1632202229.7255037, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 13}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.5582932576258578, "count": 1, "min": 0.5582932576258578, "max": 0.5582932576258578}}}
#
# #metrics {"StartTime": 1632202229.7255292, "EndTime": 1632202229.7255366, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 14}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.4099244736283269, "count": 1, "min": 0.4099244736283269, "max": 0.4099244736283269}}}
#
# #metrics {"StartTime": 1632202229.725561, "EndTime": 1632202229.725568, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 15}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.5464451009795893, "count": 1, "min": 0.5464451009795893, "max": 0.5464451009795893}}}
#
# #metrics {"StartTime": 1632202229.725592, "EndTime": 1632202229.7255988, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 16}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.4480129064435336, "count": 1, "min": 0.4480129064435336, "max": 0.4480129064435336}}}
#
# #metrics {"StartTime": 1632202229.7256234, "EndTime": 1632202229.7256303, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 17}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.45073129659681466, "count": 1, "min": 0.45073129659681466, "max": 0.45073129659681466}}}
#
# #metrics {"StartTime": 1632202229.725656, "EndTime": 1632202229.7256637, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 18}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.44716085828848223, "count": 1, "min": 0.44716085828848223, "max": 0.44716085828848223}}}
#
# #metrics {"StartTime": 1632202229.725691, "EndTime": 1632202229.7256985, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 19}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.45064839239455945, "count": 1, "min": 0.45064839239455945, "max": 0.45064839239455945}}}
#
# #metrics {"StartTime": 1632202229.7257326, "EndTime": 1632202229.7257414, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 20}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.5034817777902038, "count": 1, "min": 0.5034817777902038, "max": 0.5034817777902038}}}
#
# #metrics {"StartTime": 1632202229.7257688, "EndTime": 1632202229.7257764, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 21}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.5302559567408346, "count": 1, "min": 0.5302559567408346, "max": 0.5302559567408346}}}
#
# #metrics {"StartTime": 1632202229.7258103, "EndTime": 1632202229.7258189, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 22}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.5034230921879486, "count": 1, "min": 0.5034230921879486, "max": 0.5034230921879486}}}
#
# #metrics {"StartTime": 1632202229.7258458, "EndTime": 1632202229.7258532, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 23}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.5318763725865426, "count": 1, "min": 0.5318763725865426, "max": 0.5318763725865426}}}
#
# #metrics {"StartTime": 1632202229.7258778, "EndTime": 1632202229.7258852, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 24}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 1.0804852361247768, "count": 1, "min": 1.0804852361247768, "max": 1.0804852361247768}}}
#
# #metrics {"StartTime": 1632202229.725911, "EndTime": 1632202229.7259185, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 25}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 1.0806065441879196, "count": 1, "min": 1.0806065441879196, "max": 1.0806065441879196}}}
#
# #metrics {"StartTime": 1632202229.7259443, "EndTime": 1632202229.725952, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 26}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 1.0803472794959295, "count": 1, "min": 1.0803472794959295, "max": 1.0803472794959295}}}
#
# #metrics {"StartTime": 1632202229.7259765, "EndTime": 1632202229.725984, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 27}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 1.080706813026313, "count": 1, "min": 1.080706813026313, "max": 1.080706813026313}}}
#
# #metrics {"StartTime": 1632202229.7260168, "EndTime": 1632202229.7260256, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 28}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 1.1454150200273523, "count": 1, "min": 1.1454150200273523, "max": 1.1454150200273523}}}
#
# #metrics {"StartTime": 1632202229.7260535, "EndTime": 1632202229.726061, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 29}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 1.21392916904622, "count": 1, "min": 1.21392916904622, "max": 1.21392916904622}}}
#
# #metrics {"StartTime": 1632202229.7260942, "EndTime": 1632202229.7261028, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 30}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 1.1451639124041226, "count": 1, "min": 1.1451639124041226, "max": 1.1451639124041226}}}
#
# #metrics {"StartTime": 1632202229.7261624, "EndTime": 1632202229.7261722, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 31}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 1.2131926463716594, "count": 1, "min": 1.2131926463716594, "max": 1.2131926463716594}}}
#
# [09/21/2021 05:30:29 INFO 140156943357760] #quality_metric: host=algo-1, epoch=2, train binary_classification_weighted_cross_entropy_objective <loss>=0.33911492241327484
# [09/21/2021 05:30:29 INFO 140156943357760] #early_stopping_criteria_metric: host=algo-1, epoch=2, criteria=binary_classification_weighted_cross_entropy_objective, value=0.3195404088101794
# [09/21/2021 05:30:29 INFO 140156943357760] Epoch 2: Loss improved. Updating best model
# [09/21/2021 05:30:29 INFO 140156943357760] Saving model for epoch: 2
# [09/21/2021 05:30:29 INFO 140156943357760] Saved checkpoint to "/tmp/tmpiq5mctz7/mx-mod-0000.params"
# [09/21/2021 05:30:29 INFO 140156943357760] #progress_metric: host=algo-1, completed 20.0 % of epochs
# #metrics {"StartTime": 1632202196.967853, "EndTime": 1632202229.7436519, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 610092.0, "count": 1, "min": 610092, "max": 610092}, "Total Batches Seen": {"sum": 612.0, "count": 1, "min": 612, "max": 612}, "Max Records Seen Between Resets": {"sum": 199364.0, "count": 1, "min": 199364, "max": 199364}, "Max Batches Seen Between Resets": {"sum": 200.0, "count": 1, "min": 200, "max": 200}, "Reset Count": {"sum": 5.0, "count": 1, "min": 5, "max": 5}, "Number of Records Since Last Reset": {"sum": 199364.0, "count": 1, "min": 199364, "max": 199364}, "Number of Batches Since Last Reset": {"sum": 200.0, "count": 1, "min": 200, "max": 200}}}
#
# [09/21/2021 05:30:29 INFO 140156943357760] #throughput_metric: host=algo-1, train throughput=6082.639080309737 records/second
# [2021-09-21 05:31:02.813] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 9, "duration": 33069, "num_examples": 200, "num_bytes": 33493152}
# #metrics {"StartTime": 1632202262.8136947, "EndTime": 1632202262.8137932, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 0}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.3222659787029477, "count": 1, "min": 0.3222659787029477, "max": 0.3222659787029477}}}
#
# #metrics {"StartTime": 1632202262.8139076, "EndTime": 1632202262.8139305, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 1}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.30747335430126094, "count": 1, "min": 0.30747335430126094, "max": 0.30747335430126094}}}
#
# ...
#
# #metrics {"StartTime": 1632202624.4922972, "EndTime": 1632202624.4923062, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 3}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.28635954702080196, "count": 1, "min": 0.28635954702080196, "max": 0.28635954702080196}}}
#
# #metrics {"StartTime": 1632202624.4923346, "EndTime": 1632202624.4923422, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 4}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.2837358742191564, "count": 1, "min": 0.2837358742191564, "max": 0.2837358742191564}}}
#
# #metrics {"StartTime": 1632202624.492368, "EndTime": 1632202624.4923754, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 5}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.5330788976535126, "count": 1, "min": 0.5330788976535126, "max": 0.5330788976535126}}}
#
# #metrics {"StartTime": 1632202624.4924016, "EndTime": 1632202624.492409, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 6}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.28378993870624947, "count": 1, "min": 0.28378993870624947, "max": 0.28378993870624947}}}
#
# #metrics {"StartTime": 1632202624.4924352, "EndTime": 1632202624.4924424, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 7}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.47326178480871955, "count": 1, "min": 0.47326178480871955, "max": 0.47326178480871955}}}
#
# #metrics {"StartTime": 1632202624.4924686, "EndTime": 1632202624.492476, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 8}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.29130650250995577, "count": 1, "min": 0.29130650250995577, "max": 0.29130650250995577}}}
#
# #metrics {"StartTime": 1632202624.4925094, "EndTime": 1632202624.4925182, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 9}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.2911465912536161, "count": 1, "min": 0.2911465912536161, "max": 0.2911465912536161}}}
#
# #metrics {"StartTime": 1632202624.4925451, "EndTime": 1632202624.4925523, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 10}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.2935376149757424, "count": 1, "min": 0.2935376149757424, "max": 0.2935376149757424}}}
#
# #metrics {"StartTime": 1632202624.4925768, "EndTime": 1632202624.492584, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 11}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.29087950297216675, "count": 1, "min": 0.29087950297216675, "max": 0.29087950297216675}}}
#
# #metrics {"StartTime": 1632202624.4926093, "EndTime": 1632202624.4926164, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 12}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.29149418042532765, "count": 1, "min": 0.29149418042532765, "max": 0.29149418042532765}}}
#
# #metrics {"StartTime": 1632202624.4926429, "EndTime": 1632202624.49265, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 13}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.48701864726818983, "count": 1, "min": 0.48701864726818983, "max": 0.48701864726818983}}}
#
# #metrics {"StartTime": 1632202624.4926744, "EndTime": 1632202624.4926815, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 14}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.2914134504759132, "count": 1, "min": 0.2914134504759132, "max": 0.2914134504759132}}}
#
# #metrics {"StartTime": 1632202624.4927146, "EndTime": 1632202624.492723, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 15}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.49398932667114026, "count": 1, "min": 0.49398932667114026, "max": 0.49398932667114026}}}
#
# #metrics {"StartTime": 1632202624.492758, "EndTime": 1632202624.4927661, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 16}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.4376009696308692, "count": 1, "min": 0.4376009696308692, "max": 0.4376009696308692}}}
#
# #metrics {"StartTime": 1632202624.4927964, "EndTime": 1632202624.4928036, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 17}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.4484181478299088, "count": 1, "min": 0.4484181478299088, "max": 0.4484181478299088}}}
#
# #metrics {"StartTime": 1632202624.4928367, "EndTime": 1632202624.4928453, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 18}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.4376271188247144, "count": 1, "min": 0.4376271188247144, "max": 0.4376271188247144}}}
#
# #metrics {"StartTime": 1632202624.492872, "EndTime": 1632202624.4928794, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 19}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.44841469309437815, "count": 1, "min": 0.44841469309437815, "max": 0.44841469309437815}}}
#
# #metrics {"StartTime": 1632202624.4929042, "EndTime": 1632202624.4929116, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 20}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.45202173284789426, "count": 1, "min": 0.45202173284789426, "max": 0.45202173284789426}}}
#
# #metrics {"StartTime": 1632202624.492938, "EndTime": 1632202624.4929454, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 21}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.5203195841132696, "count": 1, "min": 0.5203195841132696, "max": 0.5203195841132696}}}
#
# #metrics {"StartTime": 1632202624.4929779, "EndTime": 1632202624.4929864, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 22}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.4520227517362815, "count": 1, "min": 0.4520227517362815, "max": 0.4520227517362815}}}
#
# #metrics {"StartTime": 1632202624.4930205, "EndTime": 1632202624.493029, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 23}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.5202868016976208, "count": 1, "min": 0.5202868016976208, "max": 0.5202868016976208}}}
#
# #metrics {"StartTime": 1632202624.4930632, "EndTime": 1632202624.4930713, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 24}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 1.0734474137656054, "count": 1, "min": 1.0734474137656054, "max": 1.0734474137656054}}}
#
# #metrics {"StartTime": 1632202624.4931006, "EndTime": 1632202624.4931078, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 25}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 1.0808105382104616, "count": 1, "min": 1.0808105382104616, "max": 1.0808105382104616}}}
#
# #metrics {"StartTime": 1632202624.4931374, "EndTime": 1632202624.4931443, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 26}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 1.0734464635034302, "count": 1, "min": 1.0734464635034302, "max": 1.0734464635034302}}}
#
# #metrics {"StartTime": 1632202624.4931774, "EndTime": 1632202624.4931843, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 27}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 1.0808158069399734, "count": 1, "min": 1.0808158069399734, "max": 1.0808158069399734}}}
#
# #metrics {"StartTime": 1632202624.493209, "EndTime": 1632202624.4932158, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 28}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 1.081110006284474, "count": 1, "min": 1.081110006284474, "max": 1.081110006284474}}}
#
# #metrics {"StartTime": 1632202624.493241, "EndTime": 1632202624.4932487, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 29}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 1.1788196838992324, "count": 1, "min": 1.1788196838992324, "max": 1.1788196838992324}}}
#
# #metrics {"StartTime": 1632202624.4932818, "EndTime": 1632202624.49329, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 30}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 1.0811094362268496, "count": 1, "min": 1.0811094362268496, "max": 1.0811094362268496}}}
#
# #metrics {"StartTime": 1632202624.4933164, "EndTime": 1632202624.4933238, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 31}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 1.1788132824538342, "count": 1, "min": 1.1788132824538342, "max": 1.1788132824538342}}}
#
# [09/21/2021 05:37:04 INFO 140156943357760] #quality_metric: host=algo-1, epoch=14, train binary_classification_weighted_cross_entropy_objective <loss>=0.2906830832898317
# [09/21/2021 05:37:04 INFO 140156943357760] #early_stopping_criteria_metric: host=algo-1, epoch=14, criteria=binary_classification_weighted_cross_entropy_objective, value=0.2837358742191564
# [09/21/2021 05:37:04 INFO 140156943357760] Epoch 14: Loss improved. Updating best model
# [09/21/2021 05:37:04 INFO 140156943357760] Saving model for epoch: 14
# [09/21/2021 05:37:04 INFO 140156943357760] Saved checkpoint to "/tmp/tmpse7pstce/mx-mod-0000.params"
# [09/21/2021 05:37:04 INFO 140156943357760] #progress_metric: host=algo-1, completed 100.0 % of epochs
# #metrics {"StartTime": 1632202591.715834, "EndTime": 1632202624.511795, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 3002460.0, "count": 1, "min": 3002460, "max": 3002460}, "Total Batches Seen": {"sum": 3012.0, "count": 1, "min": 3012, "max": 3012}, "Max Records Seen Between Resets": {"sum": 199364.0, "count": 1, "min": 199364, "max": 199364}, "Max Batches Seen Between Resets": {"sum": 200.0, "count": 1, "min": 200, "max": 200}, "Reset Count": {"sum": 17.0, "count": 1, "min": 17, "max": 17}, "Number of Records Since Last Reset": {"sum": 199364.0, "count": 1, "min": 199364, "max": 199364}, "Number of Batches Since Last Reset": {"sum": 200.0, "count": 1, "min": 200, "max": 200}}}
#
# [09/21/2021 05:37:04 INFO 140156943357760] #throughput_metric: host=algo-1, train throughput=6078.897036447522 records/second
# [09/21/2021 05:37:04 WARNING 140156943357760] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [09/21/2021 05:37:04 WARNING 140156943357760] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [2021-09-21 05:37:04.516] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 33, "duration": 3, "num_examples": 1, "num_bytes": 168000}
# [2021-09-21 05:37:05.399] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 36, "duration": 879, "num_examples": 200, "num_bytes": 33493152}
# [2021-09-21 05:37:06.833] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 38, "duration": 1359, "num_examples": 200, "num_bytes": 33493152}
# [09/21/2021 05:37:06 INFO 140156943357760] #train_score (algo-1) : ('binary_classification_weighted_cross_entropy_objective', 0.26874823277591836)
# [09/21/2021 05:37:06 INFO 140156943357760] #train_score (algo-1) : ('binary_classification_accuracy', 0.011767420396862021)
# [09/21/2021 05:37:06 INFO 140156943357760] #train_score (algo-1) : ('binary_f_1.000', 0.003610948152044181)
# [09/21/2021 05:37:06 INFO 140156943357760] #train_score (algo-1) : ('precision', 0.0018087397086763775)
# [09/21/2021 05:37:06 INFO 140156943357760] #train_score (algo-1) : ('recall', 1.0)
# [09/21/2021 05:37:06 INFO 140156943357760] #train_score (algo-1) : ('roc_auc_score', 0.9883345741578928)
# [09/21/2021 05:37:06 INFO 140156943357760] #quality_metric: host=algo-1, train binary_classification_weighted_cross_entropy_objective <loss>=0.26874823277591836
# [09/21/2021 05:37:06 INFO 140156943357760] #quality_metric: host=algo-1, train binary_classification_accuracy <score>=0.011767420396862021
# [09/21/2021 05:37:06 INFO 140156943357760] #quality_metric: host=algo-1, train binary_f_1.000 <score>=0.003610948152044181
# [09/21/2021 05:37:06 INFO 140156943357760] #quality_metric: host=algo-1, train precision <score>=0.0018087397086763775
# [09/21/2021 05:37:06 INFO 140156943357760] #quality_metric: host=algo-1, train recall <score>=1.0
# [09/21/2021 05:37:06 INFO 140156943357760] #quality_metric: host=algo-1, train roc_auc_score <score>=0.9883345741578928
# [09/21/2021 05:37:06 INFO 140156943357760] Best model found for hyperparameters: {"optimizer": "adam", "learning_rate": 0.1, "wd": 0.0001, "l1": 0.0, "lr_scheduler_step": 10, "lr_scheduler_factor": 0.99, "lr_scheduler_minimum_lr": 1e-05}
# [09/21/2021 05:37:06 INFO 140156943357760] Saved checkpoint to "/tmp/tmp546rstc8/mx-mod-0000.params"
# [09/21/2021 05:37:06 INFO 140156943357760] Test data is not provided.
# #metrics {"StartTime": 1632202114.730261, "EndTime": 1632202626.9298267, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training"}, "Metrics": {"initialize.time": {"sum": 16079.293012619019, "count": 1, "min": 16079.293012619019, "max": 16079.293012619019}, "epochs": {"sum": 15.0, "count": 1, "min": 15, "max": 15}, "check_early_stopping.time": {"sum": 16.066789627075195, "count": 15, "min": 0.9188652038574219, "max": 1.3163089752197266}, "update.time": {"sum": 493643.8925266266, "count": 15, "min": 32669.29793357849, "max": 33131.3214302063}, "finalize.time": {"sum": 2384.857654571533, "count": 1, "min": 2384.857654571533, "max": 2384.857654571533}, "setuptime": {"sum": 25.0704288482666, "count": 1, "min": 25.0704288482666, "max": 25.0704288482666}, "totaltime": {"sum": 512443.59970092773, "count": 1, "min": 512443.59970092773, "max": 512443.59970092773}}}
# 2021-09-21 05:37:23 Uploading - Uploading generated training model
# 2021-09-21 05:37:23 Completed - Training job completed
# Training seconds: 549
# Billable seconds: 549
# CPU times: user 6.05 s, sys: 155 ms, total: 6.2 s
# Wall time: 12min 54s

# %%
# %%time 
# deploy and evaluate a predictor
specific_predictor = linear_specific.deploy(initial_instance_count=1, 
                                        instance_type='ml.t2.medium')
# Out:
# Defaulting to the only supported framework/algorithm version: 1. Ignoring framework/algorithm version: 1.
# -----------------!CPU times: user 288 ms, sys: 12.6 ms, total: 301 ms
# Wall time: 8min 32s

# %%
# NOTE: We created probably the worst model ever.
metrics = evaluate(specific_predictor, 
                   test_features.astype('float32').to_numpy(), 
                   test_labels.astype('float32').to_numpy(), 
                   verbose=True)
# Out:
# prediction (col)  0.0    1.0
# actual (row)
# 0.0               929  84379
# 1.0                 0    135
#
# Recall:     1.000
# Precision:  0.002
# Accuracy:   0.012

# %%
## IMPORTANT
# delete the predictor endpoint after evaluation 
sagemaker_session.delete_endpoint(specific_predictor.endpoint)
# Out:
# The endpoint attribute has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.

# %% [markdown]
# ## Final Cleanup!
#
# * Double check that you have deleted all your endpoints.
# * I'd also suggest manually deleting your S3 bucket, models, and endpoint configurations directly from your AWS console.
#
# You can find thorough cleanup instructions, [in the documentation](https://docs.aws.amazon.com/sagemaker/latest/dg/ex1-cleanup.html).

# %% [markdown]
# ---
# # Conclusion
#
# In this notebook, you saw how to train and deploy a LinearLearner in SageMaker. This model is well-suited for a binary classification task that involves specific design decisions and managing class imbalance in the training set.
#
# Following the steps of a machine learning workflow, you loaded in some credit card transaction data, explored that data and prepared it for model training. Then trained, deployed, and evaluated several models, according to different design considerations!
